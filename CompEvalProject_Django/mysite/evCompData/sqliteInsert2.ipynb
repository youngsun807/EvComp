# %%
import pandas as pd
import sqlite3

# %%
#code = pd.read_csv("C:/0.ITStudy/11.Django/miniProject2/mysite/evCompData/company_codes _name.csv")

# %%
import csv

codeList=[]
with open('company_codes _name.csv', 'r', encoding="utf-8-sig") as r:
    code = csv.reader(r)
    for record in code:
        codeList.append([record[0], str(record[1].replace("r",""))])
codeList
# Out:
# [['엘에이티', '311060'],
#  ['대원모방', '311840'],
#  ['에어부산', '298690'],
#  ['비피도', '238200'],
#  ['지놈앤컴퍼니', '314130'],
#  ['키움제5호스팩', '311270'],
#  ['엔에이치스팩13호', '310840'],
#  ['유틸렉스', '263050'],
#  ['디케이티', '290550'],
#  ['미래에셋대우스팩2호', '310200'],
#  ['신영스팩4호', '307180'],
#  ['테크엔', '308700'],
#  ['삼성머스트스팩3호', '309930'],
#  ['위지윅스튜디오', '299900'],
#  ['한국제8호스팩', '310870'],
#  ['대신밸런스제6호스팩', '307750'],
#  ['에이비엘바이오', '298380'],
#  ['프로테옴텍', '303360'],
#  ['머큐리', '100590'],
#  ['전진바이오팜', '110020'],
#  ['뉴트리', '270870'],
#  ['골든브릿지이안5호', '307870'],
#  ['이노메트리', '302430'],
#  ['SK4호스팩', '307070'],
#  ['대유에이피', '290120'],
#  ['교보8호스팩', '307280'],
#  ['에코캡', '128540'],
#  ['베스파', '299910'],
#  ['비엔에프코퍼레이션', '271780'],
#  ['윙입푸드', '900340'],
#  ['하나머스트제6호스팩', '307160'],
#  ['남화산업', '111710'],
#  ['엠아이텍', '179290'],
#  ['티로보틱스', '117730'],
#  ['네오펙트', '290660'],
#  ['에이펙스인텍', '207490'],
#  ['티앤알바이오팹', '246710'],
#  ['나라소프트', '288490'],
#  ['아시아나IDT', '267850'],
#  ['디알젬', '263690'],
#  ['싸이토젠', '217330'],
#  ['아주IB투자', '027360'],
#  ['파멥신', '208340'],
#  ['디케이앤디', '263020'],
#  ['아이엘사이언스', '122050'],
#  ['디자인', '227100'],
#  ['노바렉스', '194700'],
#  ['셀리버리', '268600'],
#  ['대보마그네틱', '290670'],
#  ['노바텍', '285490'],
#  ['엘앤씨바이오', '290650'],
#  ['DB금융스팩6호', '306620'],
#  ['로보티즈', '108490'],
#  ['옵티팜', '153710'],
#  ['에스퓨얼셀', '288620'],
#  ['세아제강', '306200'],
#  ['나우아이비캐피탈', '293580'],
#  ['푸드나무', '290720'],
#  ['하나제약', '293480'],
#  ['크리스에프앤씨', '110790'],
#  ['IBKS제10호스팩', '299170'],
#  ['지티지웰니스', '219750'],
#  ['우진아이엔에스', '010400'],
#  ['명성티엔에스', '257370'],
#  ['삼성스팩2호', '291230'],
#  ['엔솔바이오사이언스', '140610'],
#  ['디지캡', '197140'],
#  ['대신밸런스제5호스팩', '303030'],
#  ['액트로', '290740'],
#  ['오파스넷', '173130'],
#  ['에이피티씨', '089970'],
#  ['바이오솔루션', '086820'],
#  ['리메드', '302550'],
#  ['더콘텐츠온', '302920'],
#  ['대유', '290380'],
#  ['엔케이맥스', '262760'],
#  ['신한알파리츠', '293940'],
#  ['디아이티', '110990'],
#  ['에스에스알', '275630'],
#  ['한일시멘트', '300720'],
#  ['휴네시온', '290270'],
#  ['티웨이항공', '091810'],
#  ['롯데정보통신', '286940'],
#  ['한국유니온제약', '080720'],
#  ['엠코르셋', '204020'],
#  ['IBKS제9호스팩', '297570'],
#  ['올릭스', '226950'],
#  ['테크트랜스', '258050'],
#  ['효성중공업', '298040'],
#  ['효성첨단소재', '298050'],
#  ['효성티앤씨', '298020'],
#  ['효성화학', '298000'],
#  ['아이큐어', '175250'],
#  ['SV인베스트먼트', '289080'],
#  ['엘리비젼', '276240'],
#  ['지앤이헬스케어', '299480'],
#  ['이리츠코크렙', '088260'],
#  ['EDGC', '245620'],
#  ['에스엠비나', '299670'],
#  ['HDC현대산업개발', '294870'],
#  ['하나금융11호스팩', '284620'],
#  ['파워넷', '037030'],
#  ['현대사료', '016790'],
#  ['세종메디칼', '258830'],
#  ['제노레이', '122310'],
#  ['디피코', '163430'],
#  ['한국제7호스팩', '291210'],
#  ['다이노나', '086080'],
#  ['유안타제3호스팩', '287410'],
#  ['에스제이켐', '217910'],
#  ['JTC', '950170'],
#  ['대신밸런스제3호스팩', '253590'],
#  ['위세아이텍', '065370'],
#  ['케어랩스', '263700'],
#  ['애경산업', '018250'],
#  ['에코마이스터', '064510'],
#  ['린드먼아시아', '277070'],
#  ['오스테오닉', '226400'],
#  ['엔지켐생명과학', '183490'],
#  ['동구바이오제약', '006620'],
#  ['아시아종묘', '154030'],
#  ['알리코제약', '260660'],
#  ['셀트리온', '068270'],
#  ['카페24', '042000'],
#  ['링크제니시스', '219420'],
#  ['배럴', '267790'],
#  ['SG', '255220'],
#  ['씨앤지하이테크', '264660'],
#  ['쿠쿠홈시스', '284740'],
#  ['SK케미칼', '285130'],
#  ['시스웍', '269620'],
#  ['TS트릴리온', '284610'],
#  ['라이프사이언스테크놀로지', '285770'],
#  ['한국제6호스팩', '281410'],
#  ['디바이스이엔지', '187870'],
#  ['바이오시네틱스', '281310'],
#  ['씨알푸드', '236030'],
#  ['동부스팩5호', '281740'],
#  ['휴럼', '284420'],
#  ['BGF리테일', '282330'],
#  ['동양피스톤', '092780'],
#  ['진에어', '272450'],
#  ['씨티케이코스메틱스', '260930'],
#  ['메카로', '241770'],
#  ['에스트래픽', '234300'],
#  ['케이씨텍', '281820'],
#  ['체리부로', '066360'],
#  ['대원', '007680'],
#  ['비즈니스온', '138580'],
#  ['동아타이어', '282690'],
#  ['삼양패키징', '272550'],
#  ['한화에이스스팩4호', '279410'],
#  ['스튜디오드래곤', '253450'],
#  ['IBKS제7호스팩', '276920'],
#  ['미디어젠', '279600'],
#  ['비디아이', '148140'],
#  ['코오롱티슈진', '950160'],
#  ['테이팩스', '055490'],
#  ['파인이엠텍', '278990'],
#  ['롯데제과', '280360'],
#  ['티에스아이', '277880'],
#  ['탑선', '180060'],
#  ['영화테크', '265560'],
#  ['세원', '234100'],
#  ['신한제4호스팩', '277480'],
#  ['상신전자', '263810'],
#  ['야스', '255440'],
#  ['인산가', '277410'],
#  ['에스엔피월드', '263920'],
#  ['신흥에스이씨', '243840'],
#  ['유티아이', '179900'],
#  ['선익시스템', '171090'],
#  ['엠플러스', '259630'],
#  ['앱클론', '174900'],
#  ['샘코', '263540'],
#  ['펄어비스', '263750'],
#  ['두원석재', '270020'],
#  ['케이피에스', '256940'],
#  ['시그넷이브이', '260870'],
#  ['덕우전자', '263600'],
#  ['명진홀딩스', '267060'],
#  ['이더블유케이', '258610'],
#  ['하나금융10호스팩', '270520'],
#  ['포인트엔지니어링', '176560'],
#  ['알에스오토메이션', '140670'],
#  ['컬러레이', '900310'],
#  ['엔에이치스팩12호', '273060'],
#  ['모트렉스', '118990'],
#  ['데이타솔루션', '263800'],
#  ['지니언스', '263860'],
#  ['디앤씨미디어', '263720'],
#  ['셀트리온헬스케어', '091990'],
#  ['이즈미디어', '181340'],
#  ['루켄테크놀러지스', '162120'],
#  ['에브리봇', '270660'],
#  ['한국제5호스팩', '271740'],
#  ['힘스', '238490'],
#  ['제일약품', '271980'],
#  ['브이원텍', '251630'],
#  ['아우딘퓨쳐스', '227610'],
#  ['이녹스첨단소재', '272290'],
#  ['카카오', '035720'],
#  ['알로이스', '271400'],
#  ['오리온', '271560'],
#  ['하림지주', '003380'],
#  ['주노콜렉션', '221670'],
#  ['메디안디노스틱', '233250'],
#  ['하나금융9호스팩', '261200'],
#  ['교보7호스팩', '267320'],
#  ['다이오진', '271850'],
#  ['에스알바이오텍', '270210'],
#  ['앤유엔터테인먼트', '266170'],
#  ['보라티알', '250000'],
#  ['한화수성스팩', '265920'],
#  ['매일유업', '267980'],
#  ['삼양옵틱스', '225190'],
#  ['IBKS제6호스팩', '264850'],
#  ['필옵틱스', '161580'],
#  ['미래에셋대우스팩1호', '265480'],
#  ['SGA임베디드', '224880'],
#  ['미원에스씨', '268280'],
#  ['경동도시가스', '267290'],
#  ['넷마블', '251270'],
#  ['오렌지라이프', '079440'],
#  ['현대건설기계', '267270'],
#  ['현대일렉트릭', '267260'],
#  ['현대중공업지주', '267250'],
#  ['엔에이치스팩10호', '256630'],
#  ['한화에이스스팩3호', '264290'],
#  ['앙츠', '267810'],
#  ['하나머티리얼즈', '166090'],
#  ['와이엠티', '251370'],
#  ['케이비제11호스팩', '258790'],
#  ['엠앤씨생명과학', '225860'],
#  ['파워풀엑스', '266870'],
#  ['크라운제과', '264900'],
#  ['AP시스템', '265520'],
#  ['유에스티', '263770'],
#  ['이엘피', '063760'],
#  ['유비쿼스', '264450'],
#  ['서진시스템', '178320'],
#  ['코미코', '183300'],
#  ['아스타', '246720'],
#  ['덴티움', '145720'],
#  ['대신밸런스제4호스팩', '262830'],
#  ['에스디생명공학', '217480'],
#  ['신신제약', '002800'],
#  ['에프엔에스테크', '083500'],
#  ['모바일어플라이언스', '087260'],
#  ['신한제3호스팩', '257730'],
#  ['피씨엘', '241820'],
#  ['호전실업', '111110'],
#  ['서플러스글로벌', '140070'],
#  ['유바이오로직스', '206650'],
#  ['케미메디', '205290'],
#  ['에스앤디', '260970'],
#  ['엔에이치스팩11호', '256840'],
#  ['오백볼트', '227420'],
#  ['전우정밀', '120780'],
#  ['피엔아이컴퍼니', '242350'],
#  ['퓨전데이타', '195440'],
#  ['DSC인베스트먼트', '241520'],
#  ['티에스인베스트먼트', '246690'],
#  ['셀젠텍', '258250'],
#  ['마이크로프랜드', '147760'],
#  ['현성바이탈', '204990'],
#  ['바이오프로테크', '199290'],
#  ['애니젠', '196300'],
#  ['유니온커뮤니티', '203450'],
#  ['신라젠', '215600'],
#  ['IBKS제5호스팩', '254120'],
#  ['핸즈코퍼레이션', '143210'],
#  ['오션브릿지', '241790'],
#  ['퓨쳐켐', '220100'],
#  ['뉴파워프라즈마', '144960'],
#  ['엘앤케이바이오', '156100'],
#  ['스템랩', '258540'],
#  ['시큐센', '232830'],
#  ['에이치엔티', '176440'],
#  ['핸디소프트', '220180'],
#  ['두산밥캣', '241560'],
#  ['SK3호스팩', '232330'],
#  ['비플라이소프트', '148780'],
#  ['수젠텍', '253840'],
#  ['삼성바이오로직스', '207940'],
#  ['클리오', '237880'],
#  ['오가닉티코스메틱', '900300'],
#  ['로고스바이오', '238120'],
#  ['세화피앤씨', '252500'],
#  ['굿센', '243870'],
#  ['인크로스', '216050'],
#  ['에이치엘사이언스', '239610'],
#  ['코스메카코리아', '241710'],
#  ['JW생명과학', '234080'],
#  ['GRT', '900290'],
#  ['안지오랩', '251280'],
#  ['골든센츄리', '900280'],
#  ['인텔리안테크', '189300'],
#  ['에이치시티', '072990'],
#  ['잉글우드랩', '950140'],
#  ['앤디포스', '238090'],
#  ['수산아이앤티', '050960'],
#  ['미투온', '201490'],
#  ['화승엔터프라이즈', '241590'],
#  ['유쎌', '252370'],
#  ['케이비제10호스팩', '250930'],
#  ['LS전선아시아', '229640'],
#  ['모두투어리츠', '204210'],
#  ['유니테크노', '241690'],
#  ['모비스', '250060'],
#  ['엠에프엠코리아', '251960'],
#  ['나무기술', '242040'],
#  ['자이글', '234920'],
#  ['일동제약', '249420'],
#  ['헝셩그룹', '900270'],
#  ['피엔에이치테크', '239890'],
#  ['제이에스피브이', '250300'],
#  ['샘표식품', '248170'],
#  ['에코마케팅', '230360'],
#  ['티케이씨', '191600'],
#  ['팍스넷', '038160'],
#  ['두올', '016740'],
#  ['엔지스테크널러지', '208860'],
#  ['우리손에프앤지', '073560'],
#  ['휴벡셀', '212310'],
#  ['에스케이씨에스', '224020'],
#  ['옵토팩', '123010'],
#  ['지노믹트리', '228760'],
#  ['제노텍', '066830'],
#  ['동서', '026960'],
#  ['장원테크', '174880'],
#  ['대유위니아', '071460'],
#  ['한국자산신탁', '123890'],
#  ['한국토지신탁', '034830'],
#  ['인프라웨어테크놀러지', '247300'],
#  ['바이오리더스', '142760'],
#  ['피앤씨테크', '237750'],
#  ['로스웰', '900260'],
#  ['에스엘에스바이오', '246250'],
#  ['씨앤에스링크', '245450'],
#  ['해성디에스', '195870'],
#  ['녹십자랩셀', '144510'],
#  ['에스티팜', '237690'],
#  ['알엔투테크놀로지', '148250'],
#  ['이비테크', '208850'],
#  ['한국4호스팩', '240540'],
#  ['줌인터넷', '229480'],
#  ['미래에셋제5호스팩', '239340'],
#  ['스페이스솔루션', '245030'],
#  ['휴온스', '243070'],
#  ['나눔테크', '244880'],
#  ['KC산업', '112190'],
#  ['용평리조트', '070960'],
#  ['영현무역', '242850'],
#  ['해태제과식품', '101530'],
#  ['원익IPS', '240810'],
#  ['엠로', '058970'],
#  ['이에스산업', '241510'],
#  ['인터코스', '240340'],
#  ['로보쓰리', '238500'],
#  ['레이언스', '228850'],
#  ['씨엠에스에듀', '225330'],
#  ['동양파일', '228340'],
#  ['대림씨엔에스', '004440'],
#  ['팬젠', '222110'],
#  ['바이옵트로', '222160'],
#  ['AP위성', '211270'],
#  ['솔트웍스', '230980'],
#  ['큐리언트', '115180'],
#  ['안트로젠', '065660'],
#  ['슈프리마', '236200'],
#  ['제이에스코퍼레이션', '194370'],
#  ['아이엠텍', '226350'],
#  ['유니트론텍', '142210'],
#  ['크리스탈신소재', '900250'],
#  ['한솔씨앤피', '221610'],
#  ['메디젠휴먼케어', '236340'],
#  ['선바이오', '067370'],
#  ['볼빅', '206950'],
#  ['이엠티', '232530'],
#  ['에스와이패널', '109610'],
#  ['질경이', '233990'],
#  ['코디엠', '224060'],
#  ['코리아오토글라스', '152330'],
#  ['잇츠한불', '226320'],
#  ['지오씨', '135160'],
#  ['크로넥스', '215570'],
#  ['와이아이케이', '232140'],
#  ['육일씨엔에쓰', '191410'],
#  ['이에스브이', '223310'],
#  ['휴젤', '145020'],
#  ['한국맥널티', '222980'],
#  ['덱스터', '206560'],
#  ['아진산업', '013310'],
#  ['강스템바이오텍', '217730'],
#  ['씨트리', '047920'],
#  ['에이원알폼', '234070'],
#  ['메가엠디', '133750'],
#  ['한국비엔씨', '226610'],
#  ['보광산업', '225530'],
#  ['파크시스템스', '140860'],
#  ['뉴트리바이오텍', '222040'],
#  ['에치에프알', '230240'],
#  ['예스티', '122640'],
#  ['라온테크', '232680'],
#  ['멕아이씨에스', '058110'],
#  ['에이치엔에스하이텍', '044990'],
#  ['미애부', '225850'],
#  ['엔에스', '217820'],
#  ['미래테크놀로지', '213090'],
#  ['세진중공업', '075580'],
#  ['하이즈항공', '221840'],
#  ['리드', '197210'],
#  ['캔서롭', '180400'],
#  ['매직마이크로', '127160'],
#  ['케이디켐', '221980'],
#  ['네오오토', '212560'],
#  ['마이크로텍', '227950'],
#  ['자비스', '230400'],
#  ['케어젠', '214370'],
#  ['아이진', '185490'],
#  ['인카금융서비스', '211050'],
#  ['나무가', '190510'],
#  ['유앤아이', '056090'],
#  ['금호에이치티', '214330'],
#  ['제주항공', '089590'],
#  ['본느', '226340'],
#  ['파마리서치바이오', '217950'],
#  ['더블유게임즈', '192080'],
#  ['연우', '115960'],
#  ['럭스피아', '092590'],
#  ['노브메타파마', '229500'],
#  ['젠큐릭스', '229000'],
#  ['에이티젠', '182400'],
#  ['현대코퍼레이션홀딩스', '227840'],
#  ['엑시콘', '092870'],
#  ['이엑스티', '226360'],
#  ['티씨엠생명과학', '228180'],
#  ['엄지하우스', '224810'],
#  ['메디쎄이', '200580'],
#  ['에치디프로', '214870'],
#  ['케이엠제약', '225430'],
#  ['한송네오텍', '226440'],
#  ['패션플랫폼', '225590'],
#  ['LIG넥스원', '079550'],
#  ['넷게임즈', '225570'],
#  ['제너셈', '217190'],
#  ['타이거일렉', '219130'],
#  ['HDC아이콘트롤스', '039570'],
#  ['동일제강', '002690'],
#  ['인포마크', '175140'],
#  ['카이노스메드', '220250'],
#  ['쿠첸', '225650'],
#  ['씨아이에스', '222080'],
#  ['해마로푸드서비스', '220630'],
#  ['에이텍티앤', '224110'],
#  ['웹스', '196700'],
#  ['AJ네트웍스', '095570'],
#  ['파인텍', '131760'],
#  ['한류에이아이센터', '222810'],
#  ['심텍', '222800'],
#  ['흥국에프엔비', '189980'],
#  ['쎄노텍', '222420'],
#  ['칩스앤미디어', '094360'],
#  ['제놀루션', '225220'],
#  ['아시아경제', '127710'],
#  ['엔에스컴퍼니', '224760'],
#  ['아이쓰리시스템', '214430'],
#  ['로지시스', '067730'],
#  ['플럼라인생명과학', '222670'],
#  ['켐트로스', '220260'],
#  ['파마리서치프로덕트', '214450'],
#  ['MP한강', '219550'],
#  ['펩트론', '087010'],
#  ['이노션', '214320'],
#  ['토니모리', '214420'],
#  ['네추럴FNP', '086220'],
#  ['아이피몬스터', '223220'],
#  ['미래에셋생명', '085620'],
#  ['RFHIC', '218410'],
#  ['동운아나텍', '094170'],
#  ['민앤지', '214180'],
#  ['유테크', '178780'],
#  ['경보제약', '214390'],
#  ['바이오코아', '216400'],
#  ['유투바이오', '221800'],
#  ['에스엔텍', '160600'],
#  ['켐온', '217600'],
#  ['코아스템', '166480'],
#  ['세미콘라이트', '214310'],
#  ['드림티엔터테인먼트', '220110'],
#  ['SK디앤디', '210980'],
#  ['미코바이오메드', '214610'],
#  ['씨앗', '103660'],
#  ['베셀', '177350'],
#  ['넵튠', '217270'],
#  ['미래생명자원', '218150'],
#  ['싸이맥스', '160980'],
#  ['러셀', '217500'],
#  ['픽셀플러스', '087600'],
#  ['디딤', '217620'],
#  ['제노포커스', '187420'],
#  ['틸론', '217880'],
#  ['관악산업', '076340'],
#  ['우정바이오', '215380'],
#  ['토박스코리아', '215480'],
#  ['이노인스트루먼트', '215790'],
#  ['우리산업', '215360'],
#  ['메가스터디교육', '215200'],
#  ['썬테크', '217320'],
#  ['원텍', '216280'],
#  ['한컴유니맥스', '215090'],
#  ['로보로보', '215100'],
#  ['디알텍', '214680'],
#  ['유지인트', '195990'],
#  ['골프존', '215000'],
#  ['클래시스', '214150'],
#  ['비엔디생활건강', '215050'],
#  ['엔에스쇼핑', '138250'],
#  ['퓨쳐스트림네트웍스', '214270'],
#  ['세화아이엠씨', '145210'],
#  ['포시에스', '189690'],
#  ['덕산네오룩스', '213420'],
#  ['한솔제지', '213500'],
#  ['디와이파워', '210540'],
#  ['국일신동', '060480'],
#  ['듀켐바이오', '176750'],
#  ['바디텍메드', '206640'],
#  ['썸에이지', '208640'],
#  ['와이제이엠게임즈', '193250'],
#  ['화이브라더스코리아', '204630'],
#  ['하이셈', '200470'],
#  ['휴메딕스', '200670'],
#  ['래몽래인', '200350'],
#  ['바이오로그디바이스', '208710'],
#  ['서전기전', '189860'],
#  ['아스트', '067390'],
#  ['오킨스전자', '080580'],
#  ['지란지교시큐리티', '208350'],
#  ['NEW', '160550'],
#  ['아이티센', '124500'],
#  ['삼성물산', '028260'],
#  ['소프트캠프', '210610'],
#  ['에듀파트너', '208890'],
#  ['녹십자엠에스', '142280'],
#  ['디티앤씨', '187220'],
#  ['세종머티리얼즈', '135270'],
#  ['셀바스헬스케어', '208370'],
#  ['정다운', '208140'],
#  ['하이로닉', '149980'],
#  ['랩지노믹스', '084650'],
#  ['빅텐츠', '210120'],
#  ['에이디테크놀로지', '200710'],
#  ['비씨월드제약', '200780'],
#  ['미스터블루', '207760'],
#  ['알테오젠', '196170'],
#  ['엔터메이트', '206400'],
#  ['SKC코오롱PI', '178920'],
#  ['대창스틸', '140520'],
#  ['피노텍', '150440'],
#  ['에프엔씨엔터', '173940'],
#  ['휴마시스', '205470'],
#  ['씨에스윈드', '112610'],
#  ['텔콘RF제약', '200230'],
#  ['파티게임즈', '194510'],
#  ['지엘팜텍', '204840'],
#  ['글로벌텍스프리', '204620'],
#  ['디에이테크놀로지', '196490'],
#  ['우리은행', '000030'],
#  ['삼성에스디에스', '018260'],
#  ['아이케이세미콘', '149010'],
#  ['액션스퀘어', '205500'],
#  ['엑셈', '205100'],
#  ['테고사이언스', '191420'],
#  ['슈피겐코리아', '192440'],
#  ['테라셈', '182690'],
#  ['영우디에스피', '143540'],
#  ['유니포인트', '121060'],
#  ['드림시큐리티', '203650'],
#  ['메디아나', '041920'],
#  ['데브시스터즈', '194480'],
#  ['만도', '204320'],
#  ['프로스테믹스', '203690'],
#  ['감마누', '192410'],
#  ['고려시멘트', '198440'],
#  ['판도라티비', '202960'],
#  ['서연이화', '200880'],
#  ['신화콘텍', '187270'],
#  ['쿠쿠홀딩스', '192400'],
#  ['파버나인', '177830'],
#  ['덕신하우징', '090410'],
#  ['창해에탄올', '004650'],
#  ['윈하이텍', '192390'],
#  ['아진엑스텍', '059120'],
#  ['콜마비앤에이치', '200130'],
#  ['화인베스틸', '133820'],
#  ['에이비온', '203400'],
#  ['트루윈', '105550'],
#  ['큐엠씨', '136660'],
#  ['데이터스트림즈', '199150'],
#  ['툴젠', '199800'],
#  ['텔루스', '196450'],
#  ['캐스텍코리아', '071850'],
#  ['BGF', '027410'],
#  ['나노', '187790'],
#  ['케이사인', '192250'],
#  ['코스맥스', '192820'],
#  ['오이솔루션', '138080'],
#  ['인터파크', '108790'],
#  ['한국정보인증', '053300'],
#  ['유비온', '084440'],
#  ['솔루에타', '154040'],
#  ['이지웰페어', '090850'],
#  ['위월드', '140660'],
#  ['씨이랩', '189330'],
#  ['씨티네트웍스', '189540'],
#  ['코셋', '189350'],
#  ['SGA솔루션즈', '184230'],
#  ['그린플러스', '186230'],
#  ['대동고려삼', '178600'],
#  ['청광종건', '140290'],
#  ['기가레인', '049080'],
#  ['인트로메딕', '150840'],
#  ['한중엔시에스', '107640'],
#  ['알티캐스트', '085810'],
#  ['종근당', '185750'],
#  ['현대공업', '170030'],
#  ['엔브이에이치코리아', '067570'],
#  ['디엠티', '134580'],
#  ['신송홀딩스', '006880'],
#  ['큐브엔터', '182360'],
#  ['라이온켐텍', '171120'],
#  ['램테크놀러지', '171010'],
#  ['THE MIDONG', '161570'],
#  ['골프존데카', '183410'],
#  ['에이씨티', '138360'],
#  ['아세아시멘트', '183190'],
#  ['해성옵틱스', '076610'],
#  ['내츄럴엔도텍', '168330'],
#  ['현대로템', '064350'],
#  ['수프로', '185190'],
#  ['테스나', '131970'],
#  ['파수닷컴', '150900'],
#  ['엘피케이', '183350'],
#  ['엘티씨', '170920'],
#  ['지엔씨에너지', '119850'],
#  ['한진칼', '180640'],
#  ['아미코젠', '092040'],
#  ['NHN엔터테인먼트', '181710'],
#  ['GH신소재', '130500'],
#  ['파이오링크', '170790'],
#  ['KG ETS', '151860'],
#  ['JB금융지주', '175330'],
#  ['나스미디어', '089600'],
#  ['하이골드12호', '172580'],
#  ['대주이엔티', '114920'],
#  ['비나텍', '126340'],
#  ['에스에이티이엔지', '158300'],
#  ['에스엔피제네틱스', '086460'],
#  ['에프앤가이드', '064850'],
#  ['옐로페이', '179720'],
#  ['이엔드디', '101360'],
#  ['태양기계', '116100'],
#  ['엑세스바이오', '950130'],
#  ['DSR', '155660'],
#  ['레고켐바이오', '141080'],
#  ['한국패러랠', '168490'],
#  ['동아에스티', '170900'],
#  ['인터불스', '158310'],
#  ['윈팩', '097800'],
#  ['코렌텍', '104540'],
#  ['제로투세븐', '159580'],
#  ['아이원스', '114810'],
#  ['우리이앤엘', '153490'],
#  ['아이센스', '099190'],
#  ['포티스', '141020'],
#  ['스킨앤스킨', '159910'],
#  ['SBI핀테크솔루션즈', '950110'],
#  ['우리로', '046970'],
#  ['디젠스', '113810'],
#  ['지엠비코리아', '013870'],
#  ['맥스로텍', '141070'],
#  ['와이엠씨', '155650'],
#  ['CJ헬로', '037560'],
#  ['아바텍', '149950'],
#  ['동일고무벨트', '163560'],
#  ['한국콜마', '161890'],
#  ['한국타이어', '161390'],
#  ['코이즈', '121850'],
#  ['모다', '149940'],
#  ['애경유화', '161000'],
#  ['하이골드8호', '159650'],
#  ['나노스', '151910'],
#  ['AJ렌터카', '068400'],
#  ['엠씨넥스', '097520'],
#  ['네이블커뮤니케이션즈', '153460'],
#  ['디지탈옵틱', '106520'],
#  ['피엔티', '137400'],
#  ['바다로19호', '155900'],
#  ['사조씨푸드', '014710'],
#  ['비아트론', '141000'],
#  ['하이골드3호', '153360'],
#  ['코오롱머티리얼', '144620'],
#  ['빛샘전자', '072950'],
#  ['한국ANKOR유전', '152550'],
#  ['휴비스', '079980'],
#  ['사람인에이치알', '143240'],
#  ['뉴로스', '126870'],
#  ['제룡산업', '147830'],
#  ['남화토건', '091590'],
#  ['케이탑리츠', '145270'],
#  ['메지온', '140410'],
#  ['원익머트리얼즈', '104830'],
#  ['디엔에이링크', '127120'],
#  ['GS리테일', '007070'],
#  ['나이스디앤비', '130580'],
#  ['시큐브', '131090'],
#  ['서암기계공업', '100660'],
#  ['인터지스', '129260'],
#  ['씨유메디칼', '115480'],
#  ['STC', '123260'],
#  ['삼양사', '145990'],
#  ['넥스트리밍', '139670'],
#  ['비덴트', '121800'],
#  ['에스에프씨', '112240'],
#  ['신진에스엠', '138070'],
#  ['이엠넷', '123570'],
#  ['와이지엔터테인먼트', '122870'],
#  ['쎄미시스코', '136510'],
#  ['에이티세미콘', '089530'],
#  ['테크윙', '089030'],
#  ['씨큐브', '101240'],
#  ['에스엠코어', '007820'],
#  ['씨엔플러스', '115530'],
#  ['원익테라세미콘', '123100'],
#  ['하나투어', '039130'],
#  ['케이맥', '043290'],
#  ['로보스타', '090360'],
#  ['대한과학', '131220'],
#  ['트러스제7호', '140890'],
#  ['피앤이솔루션', '131390'],
#  ['아이디스', '143160'],
#  ['에이블씨엔씨', '078520'],
#  ['화진', '134780'],
#  ['제이씨케미칼', '137950'],
#  ['아이씨디', '040910'],
#  ['제닉', '123330'],
#  ['데일리블록체인', '139050'],
#  ['삼원강재', '023000'],
#  ['상아프론테크', '089980'],
#  ['신세계인터내셔날', '031430'],
#  ['에이리츠', '140910'],
#  ['나이벡', '138610'],
#  ['옵티시스', '109080'],
#  ['대양전기공업', '108380'],
#  ['한국항공우주', '047810'],
#  ['롯데하이마트', '071840'],
#  ['서연탑메탈', '019770'],
#  ['한세엠케이', '069640'],
#  ['코오롱플라스틱', '138490'],
#  ['넥스트아이', '137940'],
#  ['리켐', '131100'],
#  ['이마트', '139480'],
#  ['DGB금융지주', '139130'],
#  ['케이티스카이라이프', '053210'],
#  ['엘아이에스', '138690'],
#  ['세아특수강', '019440'],
#  ['KMH', '122450'],
#  ['골프존뉴딘홀딩스', '121440'],
#  ['메리츠금융지주', '138040'],
#  ['윈스', '136540'],
#  ['하림', '136480'],
#  ['한국종합기술', '023350'],
#  ['이퓨쳐', '134060'],
#  ['티케이케미칼', '104480'],
#  ['BNK금융지주', '138930'],
#  ['일진머티리얼즈', '020150'],
#  ['부스타', '008470'],
#  ['현대위아', '011210'],
#  ['선진', '136490'],
#  ['미원화학', '134380'],
#  ['나노신소재', '121600'],
#  ['케이아이엔엑스', '093320'],
#  ['티피씨글로벌', '130740'],
#  ['딜리', '131180'],
#  ['엘비세미콘', '061970'],
#  ['제이엔케이히터', '126880'],
#  ['블루콤', '033560'],
#  ['인트론바이오', '048530'],
#  ['시디즈', '134790'],
#  ['다나와', '119860'],
#  ['알서포트', '131370'],
#  ['인텍플러스', '064290'],
#  ['티에스이', '131290'],
#  ['HSD엔진', '082740'],
#  ['액트', '131400'],
#  ['대성에너지', '117580'],
#  ['현대에이치씨엔', '126560'],
#  ['대정화금', '120240'],
#  ['케이티스', '058860'],
#  ['한전산업', '130660'],
#  ['피제이메탈', '128660'],
#  ['디에이치피코리아', '131030'],
#  ['제이스테판', '096690'],
#  ['엘브이엠씨', '900140'],
#  ['티비씨', '033830'],
#  ['시그네틱스', '033170'],
#  ['썬텍', '122800'],
#  ['한국전자인증', '041460'],
#  ['디케이락', '105740'],
#  ['코프라', '126600'],
#  ['선데이토즈', '123420'],
#  ['삼본정밀전자', '111870'],
#  ['아나패스', '123860'],
#  ['KNN', '058400'],
#  ['동양네트웍스', '030790'],
#  ['누리플랜', '069140'],
#  ['아이텍반도체', '119830'],
#  ['인화정공', '101930'],
#  ['코렌', '078650'],
#  ['아이씨케이', '068940'],
#  ['한일진공', '123840'],
#  ['휠라코리아', '081660'],
#  ['알파홀딩스', '117670'],
#  ['포메탈', '119500'],
#  ['KTcs', '058850'],
#  ['다원시스', '068240'],
#  ['현대홈쇼핑', '057050'],
#  ['씨젠', '096530'],
#  ['와이솔', '122990'],
#  ['하이비젼시스템', '126700'],
#  ['화신정공', '126640'],
#  ['코리아에프티', '123410'],
#  ['도화엔지니어링', '002150'],
#  ['엠에스오토텍', '123040'],
#  ['이글루시큐리티', '067920'],
#  ['대성산업', '128820'],
#  ['아이마켓코리아', '122900'],
#  ['한미약품', '128940'],
#  ['인터로조', '119610'],
#  ['하이텍팜', '106190'],
#  ['우진', '105840'],
#  ['크루셜텍', '114120'],
#  ['무학', '033920'],
#  ['에스디시스템', '121890'],
#  ['알톤스포츠', '123750'],
#  ['웅진에너지', '103130'],
#  ['유비벨록스', '089850'],
#  ['지와이커머스', '111820'],
#  ['오르비텍', '046120'],
#  ['이연제약', '102460'],
#  ['한솔시큐어', '070300'],
#  ['실리콘웍스', '108320'],
#  ['투비소프트', '079970'],
#  ['한국화장품', '123690'],
#  ['에스제이엠', '123700'],
#  ['인피니트헬스케어', '071200'],
#  ['모바일리더', '100030'],
#  ['서진오토모티브', '122690'],
#  ['한라홀딩스', '060980'],
#  ['삼성생명', '032830'],
#  ['신세계푸드', '031440'],
#  ['이스트아시아홀딩스', '900110'],
#  ['뉴프라이드', '900100'],
#  ['케이씨에스', '115500'],
#  ['씨케이에이치', '900120'],
#  ['지트리비앤티', '115450'],
#  ['삼기오토모티브', '122350'],
#  ['한화생명', '088350'],
#  ['이미지스', '115610'],
#  ['조선선재', '120030'],
#  ['인포바인', '115310'],
#  ['지투하이소닉', '106080'],
#  ['차이나하오란', '900090'],
#  ['모베이스', '101330'],
#  ['지스마트글로벌', '114570'],
#  ['코오롱인더', '120110'],
#  ['KC코트렐', '119650'],
#  ['지역난방공사', '071320'],
#  ['락앤락', '115390'],
#  ['스타플렉스', '115570'],
#  ['우리넷', '115440'],
#  ['아세아텍', '050860'],
#  ['영흥철강', '012160'],
#  ['우노앤컴퍼니', '114630'],
#  ['코디', '080530'],
#  ['우리들휴브레인', '118000'],
#  ['글로벌에스엠', '900070'],
#  ['ITX엠투엠', '099520'],
#  ['KPX생명과학', '114450'],
#  ['동양피엔에프', '104460'],
#  ['멜파스', '096640'],
#  ['위메이드', '112040'],
#  ['한전기술', '052690'],
#  ['셀바스AI', '108860'],
#  ['에스앤씨엔진그룹', '900080'],
#  ['이원컴포텍', '088290'],
#  ['웰크론강원', '114190'],
#  ['GKL', '114090'],
#  ['휴맥스', '115160'],
#  ['에이프로젠 H&G', '109960'],
#  ['SK', '034730'],
#  ['동방선기', '099410'],
#  ['디엠씨', '101000'],
#  ['진매트릭스', '109820'],
#  ['황금에스티', '032560'],
#  ['비츠로셀', '082920'],
#  ['하이트진로', '000080'],
#  ['한스바이오메드', '042520'],
#  ['동양생명', '082640'],
#  ['NHN벅스', '104200'],
#  ['아이앤씨', '052860'],
#  ['유니온머티리얼', '047400'],
#  ['케이엔더블유', '105330'],
#  ['형지엘리트', '093240'],
#  ['디에스케이', '109740'],
#  ['제넥신', '095700'],
#  ['톱텍', '108230'],
#  ['동국S&C', '100130'],
#  ['에스앤더블류', '103230'],
#  ['키움증권', '039490'],
#  ['게임빌', '063080'],
#  ['영원무역', '111770'],
#  ['동일금속', '109860'],
#  ['아주캐피탈', '033660'],
#  ['한미글로벌', '053690'],
#  ['동아지질', '028100'],
#  ['어보브반도체', '102120'],
#  ['조이맥스', '101730'],
#  ['차이나그레이트', '900040'],
#  ['이엔에프테크놀로지', '102710'],
#  ['스맥', '099440'],
#  ['해덕파워웨이', '102210'],
#  ['SDN', '099220'],
#  ['한국정밀기계', '101680'],
#  ['STX중공업', '071970'],
#  ['흥국', '010240'],
#  ['우림기계', '101170'],
#  ['티플랙스', '081150'],
#  ['LG하우시스', '108670'],
#  ['에스티오', '098660'],
#  ['에이테크솔루션', '071670'],
#  ['에스앤에스텍', '101490'],
#  ['뷰웍스', '100120'],
#  ['코오롱생명과학', '102940'],
#  ['엔시트론', '101400'],
#  ['한세실업', '105630'],
#  ['컨버즈', '109070'],
#  ['파인테크닉스', '106240'],
#  ['미원홀딩스', '107590'],
#  ['이수앱지스', '086890'],
#  ['대성파인텍', '104040'],
#  ['유비쿼스홀딩스', '078070'],
#  ['메디톡스', '086900'],
#  ['엠게임', '058630'],
#  ['아이컴포넌트', '059100'],
#  ['NAVER', '035420'],
#  ['에이치엘비생명과학', '067630'],
#  ['이크레더블', '092130'],
#  ['부국철강', '026940'],
#  ['KB금융', '105560'],
#  ['세운메디칼', '100700'],
#  ['한국철강', '104700'],
#  ['마이크로컨텍솔', '098120'],
#  ['KJ프리텍', '083470'],
#  ['삼강엠앤티', '100090'],
#  ['일진전기', '103590'],
#  ['풍산', '103140'],
#  ['LG이노텍', '011070'],
#  ['아이엠', '101390'],
#  ['웰크론한텍', '076080'],
#  ['코리아에스이', '101670'],
#  ['슈프리마에이치큐', '094840'],
#  ['명문제약', '017180'],
#  ['서울옥션', '063170'],
#  ['이스트소프트', '047560'],
#  ['비상교육', '100220'],
#  ['청담러닝', '096240'],
#  ['동성코퍼레이션', '102260'],
#  ['월덱스', '101160'],
#  ['쎄트렉아이', '099320'],
#  ['쌍방울', '102280'],
#  ['브리지텍', '064480'],
#  ['고영', '098460'],
#  ['조이시티', '067000'],
#  ['우진비앤지', '018620'],
#  ['테스', '095610'],
#  ['예스24', '053280'],
#  ['엘디티', '096870'],
#  ['LG유플러스', '032640'],
#  ['메타바이오메드', '059210'],
#  ['효성오앤비', '097870'],
#  ['네패스신소재', '087730'],
#  ['아티스', '101140'],
#  ['아시아나항공', '020560'],
#  ['SBS미디어홀딩스', '101060'],
#  ['S&TC', '100840'],
#  ['진양홀딩스', '100250'],
#  ['텔레필드', '091440'],
#  ['하나니켈1호', '099340'],
#  ...]

# %%
#codeList = []
#for i in range(len(code)):
#    codeList.append([code.iloc[i,0], str(code.iloc[i,1])])

# %%
codeList[0][0]
# Out:
# '엘에이티'

# %%
filepath = "~/mysite/db.sqlite3"
conn = sqlite3.connect(filepath)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-7-6aada372a4ac> in <module>()
#       1 filepath = "~/mysite/db.sqlite3"
# ----> 2 conn = sqlite3.connect(filepath)
#
# OperationalError: unable to open database file

# %%
cur=conn.cursor()

# %%
cur.execute("delete from evComp_company")
conn.commit
# Out:
# <function Connection.commit>

# %%
for i in codeList:
    value = (i[1], i[0])
    print(value)
    cur.execute("insert into evComp_company(code,name) values(?, ?)",value)
    #print(code.iloc[i,0],"+++++++++++++",code.iloc[i,1])
# Out:
# ('311060', '엘에이티')
# ('311840', '대원모방')
# ('298690', '에어부산')
# ('238200', '비피도')
# ('314130', '지놈앤컴퍼니')
# ('311270', '키움제5호스팩')
# ('310840', '엔에이치스팩13호')
# ('263050', '유틸렉스')
# ('290550', '디케이티')
# ('310200', '미래에셋대우스팩2호')
# ('307180', '신영스팩4호')
# ('308700', '테크엔')
# ('309930', '삼성머스트스팩3호')
# ('299900', '위지윅스튜디오')
# ('310870', '한국제8호스팩')
# ('307750', '대신밸런스제6호스팩')
# ('298380', '에이비엘바이오')
# ('303360', '프로테옴텍')
# ('100590', '머큐리')
# ('110020', '전진바이오팜')
# ('270870', '뉴트리')
# ('307870', '골든브릿지이안5호')
# ('302430', '이노메트리')
# ('307070', 'SK4호스팩')
# ('290120', '대유에이피')
# ('307280', '교보8호스팩')
# ('128540', '에코캡')
# ('299910', '베스파')
# ('271780', '비엔에프코퍼레이션')
# ('900340', '윙입푸드')
# ('307160', '하나머스트제6호스팩')
# ('111710', '남화산업')
# ('179290', '엠아이텍')
# ('117730', '티로보틱스')
# ('290660', '네오펙트')
# ('207490', '에이펙스인텍')
# ('246710', '티앤알바이오팹')
# ('288490', '나라소프트')
# ('267850', '아시아나IDT')
# ('263690', '디알젬')
# ('217330', '싸이토젠')
# ('027360', '아주IB투자')
# ('208340', '파멥신')
# ('263020', '디케이앤디')
# ('122050', '아이엘사이언스')
# ('227100', '디자인')
# ('194700', '노바렉스')
# ('268600', '셀리버리')
# ('290670', '대보마그네틱')
# ('285490', '노바텍')
# ('290650', '엘앤씨바이오')
# ('306620', 'DB금융스팩6호')
# ('108490', '로보티즈')
# ('153710', '옵티팜')
# ('288620', '에스퓨얼셀')
# ('306200', '세아제강')
# ('293580', '나우아이비캐피탈')
# ('290720', '푸드나무')
# ('293480', '하나제약')
# ('110790', '크리스에프앤씨')
# ('299170', 'IBKS제10호스팩')
# ('219750', '지티지웰니스')
# ('010400', '우진아이엔에스')
# ('257370', '명성티엔에스')
# ('291230', '삼성스팩2호')
# ('140610', '엔솔바이오사이언스')
# ('197140', '디지캡')
# ('303030', '대신밸런스제5호스팩')
# ('290740', '액트로')
# ('173130', '오파스넷')
# ('089970', '에이피티씨')
# ('086820', '바이오솔루션')
# ('302550', '리메드')
# ('302920', '더콘텐츠온')
# ('290380', '대유')
# ('262760', '엔케이맥스')
# ('293940', '신한알파리츠')
# ('110990', '디아이티')
# ('275630', '에스에스알')
# ('300720', '한일시멘트')
# ('290270', '휴네시온')
# ('091810', '티웨이항공')
# ('286940', '롯데정보통신')
# ('080720', '한국유니온제약')
# ('204020', '엠코르셋')
# ('297570', 'IBKS제9호스팩')
# ('226950', '올릭스')
# ('258050', '테크트랜스')
# ('298040', '효성중공업')
# ('298050', '효성첨단소재')
# ('298020', '효성티앤씨')
# ('298000', '효성화학')
# ('175250', '아이큐어')
# ('289080', 'SV인베스트먼트')
# ('276240', '엘리비젼')
# ('299480', '지앤이헬스케어')
# ('088260', '이리츠코크렙')
# ('245620', 'EDGC')
# ('299670', '에스엠비나')
# ('294870', 'HDC현대산업개발')
# ('284620', '하나금융11호스팩')
# ('037030', '파워넷')
# ('016790', '현대사료')
# ('258830', '세종메디칼')
# ('122310', '제노레이')
# ('163430', '디피코')
# ('291210', '한국제7호스팩')
# ('086080', '다이노나')
# ('287410', '유안타제3호스팩')
# ('217910', '에스제이켐')
# ('950170', 'JTC')
# ('253590', '대신밸런스제3호스팩')
# ('065370', '위세아이텍')
# ('263700', '케어랩스')
# ('018250', '애경산업')
# ('064510', '에코마이스터')
# ('277070', '린드먼아시아')
# ('226400', '오스테오닉')
# ('183490', '엔지켐생명과학')
# ('006620', '동구바이오제약')
# ('154030', '아시아종묘')
# ('260660', '알리코제약')
# ('068270', '셀트리온')
# ('042000', '카페24')
# ('219420', '링크제니시스')
# ('267790', '배럴')
# ('255220', 'SG')
# ('264660', '씨앤지하이테크')
# ('284740', '쿠쿠홈시스')
# ('285130', 'SK케미칼')
# ('269620', '시스웍')
# ('284610', 'TS트릴리온')
# ('285770', '라이프사이언스테크놀로지')
# ('281410', '한국제6호스팩')
# ('187870', '디바이스이엔지')
# ('281310', '바이오시네틱스')
# ('236030', '씨알푸드')
# ('281740', '동부스팩5호')
# ('284420', '휴럼')
# ('282330', 'BGF리테일')
# ('092780', '동양피스톤')
# ('272450', '진에어')
# ('260930', '씨티케이코스메틱스')
# ('241770', '메카로')
# ('234300', '에스트래픽')
# ('281820', '케이씨텍')
# ('066360', '체리부로')
# ('007680', '대원')
# ('138580', '비즈니스온')
# ('282690', '동아타이어')
# ('272550', '삼양패키징')
# ('279410', '한화에이스스팩4호')
# ('253450', '스튜디오드래곤')
# ('276920', 'IBKS제7호스팩')
# ('279600', '미디어젠')
# ('148140', '비디아이')
# ('950160', '코오롱티슈진')
# ('055490', '테이팩스')
# ('278990', '파인이엠텍')
# ('280360', '롯데제과')
# ('277880', '티에스아이')
# ('180060', '탑선')
# ('265560', '영화테크')
# ('234100', '세원')
# ('277480', '신한제4호스팩')
# ('263810', '상신전자')
# ('255440', '야스')
# ('277410', '인산가')
# ('263920', '에스엔피월드')
# ('243840', '신흥에스이씨')
# ('179900', '유티아이')
# ('171090', '선익시스템')
# ('259630', '엠플러스')
# ('174900', '앱클론')
# ('263540', '샘코')
# ('263750', '펄어비스')
# ('270020', '두원석재')
# ('256940', '케이피에스')
# ('260870', '시그넷이브이')
# ('263600', '덕우전자')
# ('267060', '명진홀딩스')
# ('258610', '이더블유케이')
# ('270520', '하나금융10호스팩')
# ('176560', '포인트엔지니어링')
# ('140670', '알에스오토메이션')
# ('900310', '컬러레이')
# ('273060', '엔에이치스팩12호')
# ('118990', '모트렉스')
# ('263800', '데이타솔루션')
# ('263860', '지니언스')
# ('263720', '디앤씨미디어')
# ('091990', '셀트리온헬스케어')
# ('181340', '이즈미디어')
# ('162120', '루켄테크놀러지스')
# ('270660', '에브리봇')
# ('271740', '한국제5호스팩')
# ('238490', '힘스')
# ('271980', '제일약품')
# ('251630', '브이원텍')
# ('227610', '아우딘퓨쳐스')
# ('272290', '이녹스첨단소재')
# ('035720', '카카오')
# ('271400', '알로이스')
# ('271560', '오리온')
# ('003380', '하림지주')
# ('221670', '주노콜렉션')
# ('233250', '메디안디노스틱')
# ('261200', '하나금융9호스팩')
# ('267320', '교보7호스팩')
# ('271850', '다이오진')
# ('270210', '에스알바이오텍')
# ('266170', '앤유엔터테인먼트')
# ('250000', '보라티알')
# ('265920', '한화수성스팩')
# ('267980', '매일유업')
# ('225190', '삼양옵틱스')
# ('264850', 'IBKS제6호스팩')
# ('161580', '필옵틱스')
# ('265480', '미래에셋대우스팩1호')
# ('224880', 'SGA임베디드')
# ('268280', '미원에스씨')
# ('267290', '경동도시가스')
# ('251270', '넷마블')
# ('079440', '오렌지라이프')
# ('267270', '현대건설기계')
# ('267260', '현대일렉트릭')
# ('267250', '현대중공업지주')
# ('256630', '엔에이치스팩10호')
# ('264290', '한화에이스스팩3호')
# ('267810', '앙츠')
# ('166090', '하나머티리얼즈')
# ('251370', '와이엠티')
# ('258790', '케이비제11호스팩')
# ('225860', '엠앤씨생명과학')
# ('266870', '파워풀엑스')
# ('264900', '크라운제과')
# ('265520', 'AP시스템')
# ('263770', '유에스티')
# ('063760', '이엘피')
# ('264450', '유비쿼스')
# ('178320', '서진시스템')
# ('183300', '코미코')
# ('246720', '아스타')
# ('145720', '덴티움')
# ('262830', '대신밸런스제4호스팩')
# ('217480', '에스디생명공학')
# ('002800', '신신제약')
# ('083500', '에프엔에스테크')
# ('087260', '모바일어플라이언스')
# ('257730', '신한제3호스팩')
# ('241820', '피씨엘')
# ('111110', '호전실업')
# ('140070', '서플러스글로벌')
# ('206650', '유바이오로직스')
# ('205290', '케미메디')
# ('260970', '에스앤디')
# ('256840', '엔에이치스팩11호')
# ('227420', '오백볼트')
# ('120780', '전우정밀')
# ('242350', '피엔아이컴퍼니')
# ('195440', '퓨전데이타')
# ('241520', 'DSC인베스트먼트')
# ('246690', '티에스인베스트먼트')
# ('258250', '셀젠텍')
# ('147760', '마이크로프랜드')
# ('204990', '현성바이탈')
# ('199290', '바이오프로테크')
# ('196300', '애니젠')
# ('203450', '유니온커뮤니티')
# ('215600', '신라젠')
# ('254120', 'IBKS제5호스팩')
# ('143210', '핸즈코퍼레이션')
# ('241790', '오션브릿지')
# ('220100', '퓨쳐켐')
# ('144960', '뉴파워프라즈마')
# ('156100', '엘앤케이바이오')
# ('258540', '스템랩')
# ('232830', '시큐센')
# ('176440', '에이치엔티')
# ('220180', '핸디소프트')
# ('241560', '두산밥캣')
# ('232330', 'SK3호스팩')
# ('148780', '비플라이소프트')
# ('253840', '수젠텍')
# ('207940', '삼성바이오로직스')
# ('237880', '클리오')
# ('900300', '오가닉티코스메틱')
# ('238120', '로고스바이오')
# ('252500', '세화피앤씨')
# ('243870', '굿센')
# ('216050', '인크로스')
# ('239610', '에이치엘사이언스')
# ('241710', '코스메카코리아')
# ('234080', 'JW생명과학')
# ('900290', 'GRT')
# ('251280', '안지오랩')
# ('900280', '골든센츄리')
# ('189300', '인텔리안테크')
# ('072990', '에이치시티')
# ('950140', '잉글우드랩')
# ('238090', '앤디포스')
# ('050960', '수산아이앤티')
# ('201490', '미투온')
# ('241590', '화승엔터프라이즈')
# ('252370', '유쎌')
# ('250930', '케이비제10호스팩')
# ('229640', 'LS전선아시아')
# ('204210', '모두투어리츠')
# ('241690', '유니테크노')
# ('250060', '모비스')
# ('251960', '엠에프엠코리아')
# ('242040', '나무기술')
# ('234920', '자이글')
# ('249420', '일동제약')
# ('900270', '헝셩그룹')
# ('239890', '피엔에이치테크')
# ('250300', '제이에스피브이')
# ('248170', '샘표식품')
# ('230360', '에코마케팅')
# ('191600', '티케이씨')
# ('038160', '팍스넷')
# ('016740', '두올')
# ('208860', '엔지스테크널러지')
# ('073560', '우리손에프앤지')
# ('212310', '휴벡셀')
# ('224020', '에스케이씨에스')
# ('123010', '옵토팩')
# ('228760', '지노믹트리')
# ('066830', '제노텍')
# ('026960', '동서')
# ('174880', '장원테크')
# ('071460', '대유위니아')
# ('123890', '한국자산신탁')
# ('034830', '한국토지신탁')
# ('247300', '인프라웨어테크놀러지')
# ('142760', '바이오리더스')
# ('237750', '피앤씨테크')
# ('900260', '로스웰')
# ('246250', '에스엘에스바이오')
# ('245450', '씨앤에스링크')
# ('195870', '해성디에스')
# ('144510', '녹십자랩셀')
# ('237690', '에스티팜')
# ('148250', '알엔투테크놀로지')
# ('208850', '이비테크')
# ('240540', '한국4호스팩')
# ('229480', '줌인터넷')
# ('239340', '미래에셋제5호스팩')
# ('245030', '스페이스솔루션')
# ('243070', '휴온스')
# ('244880', '나눔테크')
# ('112190', 'KC산업')
# ('070960', '용평리조트')
# ('242850', '영현무역')
# ('101530', '해태제과식품')
# ('240810', '원익IPS')
# ('058970', '엠로')
# ('241510', '이에스산업')
# ('240340', '인터코스')
# ('238500', '로보쓰리')
# ('228850', '레이언스')
# ('225330', '씨엠에스에듀')
# ('228340', '동양파일')
# ('004440', '대림씨엔에스')
# ('222110', '팬젠')
# ('222160', '바이옵트로')
# ('211270', 'AP위성')
# ('230980', '솔트웍스')
# ('115180', '큐리언트')
# ('065660', '안트로젠')
# ('236200', '슈프리마')
# ('194370', '제이에스코퍼레이션')
# ('226350', '아이엠텍')
# ('142210', '유니트론텍')
# ('900250', '크리스탈신소재')
# ('221610', '한솔씨앤피')
# ('236340', '메디젠휴먼케어')
# ('067370', '선바이오')
# ('206950', '볼빅')
# ('232530', '이엠티')
# ('109610', '에스와이패널')
# ('233990', '질경이')
# ('224060', '코디엠')
# ('152330', '코리아오토글라스')
# ('226320', '잇츠한불')
# ('135160', '지오씨')
# ('215570', '크로넥스')
# ('232140', '와이아이케이')
# ('191410', '육일씨엔에쓰')
# ('223310', '이에스브이')
# ('145020', '휴젤')
# ('222980', '한국맥널티')
# ('206560', '덱스터')
# ('013310', '아진산업')
# ('217730', '강스템바이오텍')
# ('047920', '씨트리')
# ('234070', '에이원알폼')
# ('133750', '메가엠디')
# ('226610', '한국비엔씨')
# ('225530', '보광산업')
# ('140860', '파크시스템스')
# ('222040', '뉴트리바이오텍')
# ('230240', '에치에프알')
# ('122640', '예스티')
# ('232680', '라온테크')
# ('058110', '멕아이씨에스')
# ('044990', '에이치엔에스하이텍')
# ('225850', '미애부')
# ('217820', '엔에스')
# ('213090', '미래테크놀로지')
# ('075580', '세진중공업')
# ('221840', '하이즈항공')
# ('197210', '리드')
# ('180400', '캔서롭')
# ('127160', '매직마이크로')
# ('221980', '케이디켐')
# ('212560', '네오오토')
# ('227950', '마이크로텍')
# ('230400', '자비스')
# ('214370', '케어젠')
# ('185490', '아이진')
# ('211050', '인카금융서비스')
# ('190510', '나무가')
# ('056090', '유앤아이')
# ('214330', '금호에이치티')
# ('089590', '제주항공')
# ('226340', '본느')
# ('217950', '파마리서치바이오')
# ('192080', '더블유게임즈')
# ('115960', '연우')
# ('092590', '럭스피아')
# ('229500', '노브메타파마')
# ('229000', '젠큐릭스')
# ('182400', '에이티젠')
# ('227840', '현대코퍼레이션홀딩스')
# ('092870', '엑시콘')
# ('226360', '이엑스티')
# ('228180', '티씨엠생명과학')
# ('224810', '엄지하우스')
# ('200580', '메디쎄이')
# ('214870', '에치디프로')
# ('225430', '케이엠제약')
# ('226440', '한송네오텍')
# ('225590', '패션플랫폼')
# ('079550', 'LIG넥스원')
# ('225570', '넷게임즈')
# ('217190', '제너셈')
# ('219130', '타이거일렉')
# ('039570', 'HDC아이콘트롤스')
# ('002690', '동일제강')
# ('175140', '인포마크')
# ('220250', '카이노스메드')
# ('225650', '쿠첸')
# ('222080', '씨아이에스')
# ('220630', '해마로푸드서비스')
# ('224110', '에이텍티앤')
# ('196700', '웹스')
# ('095570', 'AJ네트웍스')
# ('131760', '파인텍')
# ('222810', '한류에이아이센터')
# ('222800', '심텍')
# ('189980', '흥국에프엔비')
# ('222420', '쎄노텍')
# ('094360', '칩스앤미디어')
# ('225220', '제놀루션')
# ('127710', '아시아경제')
# ('224760', '엔에스컴퍼니')
# ('214430', '아이쓰리시스템')
# ('067730', '로지시스')
# ('222670', '플럼라인생명과학')
# ('220260', '켐트로스')
# ('214450', '파마리서치프로덕트')
# ('219550', 'MP한강')
# ('087010', '펩트론')
# ('214320', '이노션')
# ('214420', '토니모리')
# ('086220', '네추럴FNP')
# ('223220', '아이피몬스터')
# ('085620', '미래에셋생명')
# ('218410', 'RFHIC')
# ('094170', '동운아나텍')
# ('214180', '민앤지')
# ('178780', '유테크')
# ('214390', '경보제약')
# ('216400', '바이오코아')
# ('221800', '유투바이오')
# ('160600', '에스엔텍')
# ('217600', '켐온')
# ('166480', '코아스템')
# ('214310', '세미콘라이트')
# ('220110', '드림티엔터테인먼트')
# ('210980', 'SK디앤디')
# ('214610', '미코바이오메드')
# ('103660', '씨앗')
# ('177350', '베셀')
# ('217270', '넵튠')
# ('218150', '미래생명자원')
# ('160980', '싸이맥스')
# ('217500', '러셀')
# ('087600', '픽셀플러스')
# ('217620', '디딤')
# ('187420', '제노포커스')
# ('217880', '틸론')
# ('076340', '관악산업')
# ('215380', '우정바이오')
# ('215480', '토박스코리아')
# ('215790', '이노인스트루먼트')
# ('215360', '우리산업')
# ('215200', '메가스터디교육')
# ('217320', '썬테크')
# ('216280', '원텍')
# ('215090', '한컴유니맥스')
# ('215100', '로보로보')
# ('214680', '디알텍')
# ('195990', '유지인트')
# ('215000', '골프존')
# ('214150', '클래시스')
# ('215050', '비엔디생활건강')
# ('138250', '엔에스쇼핑')
# ('214270', '퓨쳐스트림네트웍스')
# ('145210', '세화아이엠씨')
# ('189690', '포시에스')
# ('213420', '덕산네오룩스')
# ('213500', '한솔제지')
# ('210540', '디와이파워')
# ('060480', '국일신동')
# ('176750', '듀켐바이오')
# ('206640', '바디텍메드')
# ('208640', '썸에이지')
# ('193250', '와이제이엠게임즈')
# ('204630', '화이브라더스코리아')
# ('200470', '하이셈')
# ('200670', '휴메딕스')
# ('200350', '래몽래인')
# ('208710', '바이오로그디바이스')
# ('189860', '서전기전')
# ('067390', '아스트')
# ('080580', '오킨스전자')
# ('208350', '지란지교시큐리티')
# ('160550', 'NEW')
# ('124500', '아이티센')
# ('028260', '삼성물산')
# ('210610', '소프트캠프')
# ('208890', '에듀파트너')
# ('142280', '녹십자엠에스')
# ('187220', '디티앤씨')
# ('135270', '세종머티리얼즈')
# ('208370', '셀바스헬스케어')
# ('208140', '정다운')
# ('149980', '하이로닉')
# ('084650', '랩지노믹스')
# ('210120', '빅텐츠')
# ('200710', '에이디테크놀로지')
# ('200780', '비씨월드제약')
# ('207760', '미스터블루')
# ('196170', '알테오젠')
# ('206400', '엔터메이트')
# ('178920', 'SKC코오롱PI')
# ('140520', '대창스틸')
# ('150440', '피노텍')
# ('173940', '에프엔씨엔터')
# ('205470', '휴마시스')
# ('112610', '씨에스윈드')
# ('200230', '텔콘RF제약')
# ('194510', '파티게임즈')
# ('204840', '지엘팜텍')
# ('204620', '글로벌텍스프리')
# ('196490', '디에이테크놀로지')
# ('000030', '우리은행')
# ('018260', '삼성에스디에스')
# ('149010', '아이케이세미콘')
# ('205500', '액션스퀘어')
# ('205100', '엑셈')
# ('191420', '테고사이언스')
# ('192440', '슈피겐코리아')
# ('182690', '테라셈')
# ('143540', '영우디에스피')
# ('121060', '유니포인트')
# ('203650', '드림시큐리티')
# ('041920', '메디아나')
# ('194480', '데브시스터즈')
# ('204320', '만도')
# ('203690', '프로스테믹스')
# ('192410', '감마누')
# ('198440', '고려시멘트')
# ('202960', '판도라티비')
# ('200880', '서연이화')
# ('187270', '신화콘텍')
# ('192400', '쿠쿠홀딩스')
# ('177830', '파버나인')
# ('090410', '덕신하우징')
# ('004650', '창해에탄올')
# ('192390', '윈하이텍')
# ('059120', '아진엑스텍')
# ('200130', '콜마비앤에이치')
# ('133820', '화인베스틸')
# ('203400', '에이비온')
# ('105550', '트루윈')
# ('136660', '큐엠씨')
# ('199150', '데이터스트림즈')
# ('199800', '툴젠')
# ('196450', '텔루스')
# ('071850', '캐스텍코리아')
# ('027410', 'BGF')
# ('187790', '나노')
# ('192250', '케이사인')
# ('192820', '코스맥스')
# ('138080', '오이솔루션')
# ('108790', '인터파크')
# ('053300', '한국정보인증')
# ('084440', '유비온')
# ('154040', '솔루에타')
# ('090850', '이지웰페어')
# ('140660', '위월드')
# ('189330', '씨이랩')
# ('189540', '씨티네트웍스')
# ('189350', '코셋')
# ('184230', 'SGA솔루션즈')
# ('186230', '그린플러스')
# ('178600', '대동고려삼')
# ('140290', '청광종건')
# ('049080', '기가레인')
# ('150840', '인트로메딕')
# ('107640', '한중엔시에스')
# ('085810', '알티캐스트')
# ('185750', '종근당')
# ('170030', '현대공업')
# ('067570', '엔브이에이치코리아')
# ('134580', '디엠티')
# ('006880', '신송홀딩스')
# ('182360', '큐브엔터')
# ('171120', '라이온켐텍')
# ('171010', '램테크놀러지')
# ('161570', 'THE MIDONG')
# ('183410', '골프존데카')
# ('138360', '에이씨티')
# ('183190', '아세아시멘트')
# ('076610', '해성옵틱스')
# ('168330', '내츄럴엔도텍')
# ('064350', '현대로템')
# ('185190', '수프로')
# ('131970', '테스나')
# ('150900', '파수닷컴')
# ('183350', '엘피케이')
# ('170920', '엘티씨')
# ('119850', '지엔씨에너지')
# ('180640', '한진칼')
# ('092040', '아미코젠')
# ('181710', 'NHN엔터테인먼트')
# ('130500', 'GH신소재')
# ('170790', '파이오링크')
# ('151860', 'KG ETS')
# ('175330', 'JB금융지주')
# ('089600', '나스미디어')
# ('172580', '하이골드12호')
# ('114920', '대주이엔티')
# ('126340', '비나텍')
# ('158300', '에스에이티이엔지')
# ('086460', '에스엔피제네틱스')
# ('064850', '에프앤가이드')
# ('179720', '옐로페이')
# ('101360', '이엔드디')
# ('116100', '태양기계')
# ('950130', '엑세스바이오')
# ('155660', 'DSR')
# ('141080', '레고켐바이오')
# ('168490', '한국패러랠')
# ('170900', '동아에스티')
# ('158310', '인터불스')
# ('097800', '윈팩')
# ('104540', '코렌텍')
# ('159580', '제로투세븐')
# ('114810', '아이원스')
# ('153490', '우리이앤엘')
# ('099190', '아이센스')
# ('141020', '포티스')
# ('159910', '스킨앤스킨')
# ('950110', 'SBI핀테크솔루션즈')
# ('046970', '우리로')
# ('113810', '디젠스')
# ('013870', '지엠비코리아')
# ('141070', '맥스로텍')
# ('155650', '와이엠씨')
# ('037560', 'CJ헬로')
# ('149950', '아바텍')
# ('163560', '동일고무벨트')
# ('161890', '한국콜마')
# ('161390', '한국타이어')
# ('121850', '코이즈')
# ('149940', '모다')
# ('161000', '애경유화')
# ('159650', '하이골드8호')
# ('151910', '나노스')
# ('068400', 'AJ렌터카')
# ('097520', '엠씨넥스')
# ('153460', '네이블커뮤니케이션즈')
# ('106520', '디지탈옵틱')
# ('137400', '피엔티')
# ('155900', '바다로19호')
# ('014710', '사조씨푸드')
# ('141000', '비아트론')
# ('153360', '하이골드3호')
# ('144620', '코오롱머티리얼')
# ('072950', '빛샘전자')
# ('152550', '한국ANKOR유전')
# ('079980', '휴비스')
# ('143240', '사람인에이치알')
# ('126870', '뉴로스')
# ('147830', '제룡산업')
# ('091590', '남화토건')
# ('145270', '케이탑리츠')
# ('140410', '메지온')
# ('104830', '원익머트리얼즈')
# ('127120', '디엔에이링크')
# ('007070', 'GS리테일')
# ('130580', '나이스디앤비')
# ('131090', '시큐브')
# ('100660', '서암기계공업')
# ('129260', '인터지스')
# ('115480', '씨유메디칼')
# ('123260', 'STC')
# ('145990', '삼양사')
# ('139670', '넥스트리밍')
# ('121800', '비덴트')
# ('112240', '에스에프씨')
# ('138070', '신진에스엠')
# ('123570', '이엠넷')
# ('122870', '와이지엔터테인먼트')
# ('136510', '쎄미시스코')
# ('089530', '에이티세미콘')
# ('089030', '테크윙')
# ('101240', '씨큐브')
# ('007820', '에스엠코어')
# ('115530', '씨엔플러스')
# ('123100', '원익테라세미콘')
# ('039130', '하나투어')
# ('043290', '케이맥')
# ('090360', '로보스타')
# ('131220', '대한과학')
# ('140890', '트러스제7호')
# ('131390', '피앤이솔루션')
# ('143160', '아이디스')
# ('078520', '에이블씨엔씨')
# ('134780', '화진')
# ('137950', '제이씨케미칼')
# ('040910', '아이씨디')
# ('123330', '제닉')
# ('139050', '데일리블록체인')
# ('023000', '삼원강재')
# ('089980', '상아프론테크')
# ('031430', '신세계인터내셔날')
# ('140910', '에이리츠')
# ('138610', '나이벡')
# ('109080', '옵티시스')
# ('108380', '대양전기공업')
# ('047810', '한국항공우주')
# ('071840', '롯데하이마트')
# ('019770', '서연탑메탈')
# ('069640', '한세엠케이')
# ('138490', '코오롱플라스틱')
# ('137940', '넥스트아이')
# ('131100', '리켐')
# ('139480', '이마트')
# ('139130', 'DGB금융지주')
# ('053210', '케이티스카이라이프')
# ('138690', '엘아이에스')
# ('019440', '세아특수강')
# ('122450', 'KMH')
# ('121440', '골프존뉴딘홀딩스')
# ('138040', '메리츠금융지주')
# ('136540', '윈스')
# ('136480', '하림')
# ('023350', '한국종합기술')
# ('134060', '이퓨쳐')
# ('104480', '티케이케미칼')
# ('138930', 'BNK금융지주')
# ('020150', '일진머티리얼즈')
# ('008470', '부스타')
# ('011210', '현대위아')
# ('136490', '선진')
# ('134380', '미원화학')
# ('121600', '나노신소재')
# ('093320', '케이아이엔엑스')
# ('130740', '티피씨글로벌')
# ('131180', '딜리')
# ('061970', '엘비세미콘')
# ('126880', '제이엔케이히터')
# ('033560', '블루콤')
# ('048530', '인트론바이오')
# ('134790', '시디즈')
# ('119860', '다나와')
# ('131370', '알서포트')
# ('064290', '인텍플러스')
# ('131290', '티에스이')
# ('082740', 'HSD엔진')
# ('131400', '액트')
# ('117580', '대성에너지')
# ('126560', '현대에이치씨엔')
# ('120240', '대정화금')
# ('058860', '케이티스')
# ('130660', '한전산업')
# ('128660', '피제이메탈')
# ('131030', '디에이치피코리아')
# ('096690', '제이스테판')
# ('900140', '엘브이엠씨')
# ('033830', '티비씨')
# ('033170', '시그네틱스')
# ('122800', '썬텍')
# ('041460', '한국전자인증')
# ('105740', '디케이락')
# ('126600', '코프라')
# ('123420', '선데이토즈')
# ('111870', '삼본정밀전자')
# ('123860', '아나패스')
# ('058400', 'KNN')
# ('030790', '동양네트웍스')
# ('069140', '누리플랜')
# ('119830', '아이텍반도체')
# ('101930', '인화정공')
# ('078650', '코렌')
# ('068940', '아이씨케이')
# ('123840', '한일진공')
# ('081660', '휠라코리아')
# ('117670', '알파홀딩스')
# ('119500', '포메탈')
# ('058850', 'KTcs')
# ('068240', '다원시스')
# ('057050', '현대홈쇼핑')
# ('096530', '씨젠')
# ('122990', '와이솔')
# ('126700', '하이비젼시스템')
# ('126640', '화신정공')
# ('123410', '코리아에프티')
# ('002150', '도화엔지니어링')
# ('123040', '엠에스오토텍')
# ('067920', '이글루시큐리티')
# ('128820', '대성산업')
# ('122900', '아이마켓코리아')
# ('128940', '한미약품')
# ('119610', '인터로조')
# ('106190', '하이텍팜')
# ('105840', '우진')
# ('114120', '크루셜텍')
# ('033920', '무학')
# ('121890', '에스디시스템')
# ('123750', '알톤스포츠')
# ('103130', '웅진에너지')
# ('089850', '유비벨록스')
# ('111820', '지와이커머스')
# ('046120', '오르비텍')
# ('102460', '이연제약')
# ('070300', '한솔시큐어')
# ('108320', '실리콘웍스')
# ('079970', '투비소프트')
# ('123690', '한국화장품')
# ('123700', '에스제이엠')
# ('071200', '인피니트헬스케어')
# ('100030', '모바일리더')
# ('122690', '서진오토모티브')
# ('060980', '한라홀딩스')
# ('032830', '삼성생명')
# ('031440', '신세계푸드')
# ('900110', '이스트아시아홀딩스')
# ('900100', '뉴프라이드')
# ('115500', '케이씨에스')
# ('900120', '씨케이에이치')
# ('115450', '지트리비앤티')
# ('122350', '삼기오토모티브')
# ('088350', '한화생명')
# ('115610', '이미지스')
# ('120030', '조선선재')
# ('115310', '인포바인')
# ('106080', '지투하이소닉')
# ('900090', '차이나하오란')
# ('101330', '모베이스')
# ('114570', '지스마트글로벌')
# ('120110', '코오롱인더')
# ('119650', 'KC코트렐')
# ('071320', '지역난방공사')
# ('115390', '락앤락')
# ('115570', '스타플렉스')
# ('115440', '우리넷')
# ('050860', '아세아텍')
# ('012160', '영흥철강')
# ('114630', '우노앤컴퍼니')
# ('080530', '코디')
# ('118000', '우리들휴브레인')
# ('900070', '글로벌에스엠')
# ('099520', 'ITX엠투엠')
# ('114450', 'KPX생명과학')
# ('104460', '동양피엔에프')
# ('096640', '멜파스')
# ('112040', '위메이드')
# ('052690', '한전기술')
# ('108860', '셀바스AI')
# ('900080', '에스앤씨엔진그룹')
# ('088290', '이원컴포텍')
# ('114190', '웰크론강원')
# ('114090', 'GKL')
# ('115160', '휴맥스')
# ('109960', '에이프로젠 H&G')
# ('034730', 'SK')
# ('099410', '동방선기')
# ('101000', '디엠씨')
# ('109820', '진매트릭스')
# ('032560', '황금에스티')
# ('082920', '비츠로셀')
# ('000080', '하이트진로')
# ('042520', '한스바이오메드')
# ('082640', '동양생명')
# ('104200', 'NHN벅스')
# ('052860', '아이앤씨')
# ('047400', '유니온머티리얼')
# ('105330', '케이엔더블유')
# ('093240', '형지엘리트')
# ('109740', '디에스케이')
# ('095700', '제넥신')
# ('108230', '톱텍')
# ('100130', '동국S&C')
# ('103230', '에스앤더블류')
# ('039490', '키움증권')
# ('063080', '게임빌')
# ('111770', '영원무역')
# ('109860', '동일금속')
# ('033660', '아주캐피탈')
# ('053690', '한미글로벌')
# ('028100', '동아지질')
# ('102120', '어보브반도체')
# ('101730', '조이맥스')
# ('900040', '차이나그레이트')
# ('102710', '이엔에프테크놀로지')
# ('099440', '스맥')
# ('102210', '해덕파워웨이')
# ('099220', 'SDN')
# ('101680', '한국정밀기계')
# ('071970', 'STX중공업')
# ('010240', '흥국')
# ('101170', '우림기계')
# ('081150', '티플랙스')
# ('108670', 'LG하우시스')
# ('098660', '에스티오')
# ('071670', '에이테크솔루션')
# ('101490', '에스앤에스텍')
# ('100120', '뷰웍스')
# ('102940', '코오롱생명과학')
# ('101400', '엔시트론')
# ('105630', '한세실업')
# ('109070', '컨버즈')
# ('106240', '파인테크닉스')
# ('107590', '미원홀딩스')
# ('086890', '이수앱지스')
# ('104040', '대성파인텍')
# ('078070', '유비쿼스홀딩스')
# ('086900', '메디톡스')
# ('058630', '엠게임')
# ('059100', '아이컴포넌트')
# ('035420', 'NAVER')
# ('067630', '에이치엘비생명과학')
# ('092130', '이크레더블')
# ('026940', '부국철강')
# ('105560', 'KB금융')
# ('100700', '세운메디칼')
# ('104700', '한국철강')
# ('098120', '마이크로컨텍솔')
# ('083470', 'KJ프리텍')
# ('100090', '삼강엠앤티')
# ('103590', '일진전기')
# ('103140', '풍산')
# ('011070', 'LG이노텍')
# ('101390', '아이엠')
# ('076080', '웰크론한텍')
# ('101670', '코리아에스이')
# ('094840', '슈프리마에이치큐')
# ('017180', '명문제약')
# ('063170', '서울옥션')
# ('047560', '이스트소프트')
# ('100220', '비상교육')
# ('096240', '청담러닝')
# ('102260', '동성코퍼레이션')
# ('101160', '월덱스')
# ('099320', '쎄트렉아이')
# ('102280', '쌍방울')
# ('064480', '브리지텍')
# ('098460', '고영')
# ('067000', '조이시티')
# ('018620', '우진비앤지')
# ('095610', '테스')
# ('053280', '예스24')
# ('096870', '엘디티')
# ('032640', 'LG유플러스')
# ('059210', '메타바이오메드')
# ('097870', '효성오앤비')
# ('087730', '네패스신소재')
# ('101140', '아티스')
# ('020560', '아시아나항공')
# ('101060', 'SBS미디어홀딩스')
# ('100840', 'S&TC')
# ('100250', '진양홀딩스')
# ('091440', '텔레필드')
# ('099340', '하나니켈1호')
# ('099350', '하나니켈2호')
# ('096040', '이트론')
# ('085310', '엔케이')
# ('097780', '에스맥')
# ('096630', '에스코넥')
# ('068330', '일신바이오')
# ('093920', '서원인텍')
# ('067010', '이씨에스')
# ('096350', '대창솔루션')
# ('051600', '한전KPS')
# ('069920', '아이에스이커머스')
# ('096610', '알에프세미')
# ('092070', '디엔에프')
# ('094820', '일진파워')
# ('086670', '비엠티')
# ('093230', '이아이디')
# ('092440', '기신정기')
# ('094190', '이엘케이')
# ('095190', '이엠코리아')
# ('044450', 'KSS해운')
# ('094280', '효성 ITX')
# ('092300', '현우산업')
# ('033270', '유나이티드')
# ('093640', '다믈멀티미디어')
# ('092200', '디아이씨')
# ('095910', '에스에너지')
# ('081580', '성우전자')
# ('073110', '엘엠에스')
# ('094970', '제이엠티')
# ('080520', '오디텍')
# ('095340', 'ISC')
# ('085910', '네오티스')
# ('095500', '미래나노텍')
# ('027580', '상보')
# ('097950', 'CJ제일제당')
# ('086040', '바이오톡스텍')
# ('028670', '팬오션')
# ('090740', '연이정보통신')
# ('057540', '옴니시스템')
# ('094940', '푸른기술')
# ('095270', '웨이브일렉트로')
# ('097230', '한진중공업')
# ('093190', '빅솔론')
# ('096760', 'JW홀딩스')
# ('091340', 'S&K폴리텍')
# ('096770', 'SK이노베이션')
# ('072770', '네오디안테크놀로지')
# ('094480', '갤럭시아컴즈')
# ('086520', '에코프로')
# ('065150', 'MP그룹')
# ('078340', '컴투스')
# ('095660', '네오위즈')
# ('029780', '삼성카드')
# ('092600', '넥스트칩')
# ('069410', '엔텔스')
# ('096300', '베트남개발1')
# ('001780', '알루코')
# ('093380', '풍강')
# ('095720', '웅진씽크빅')
# ('086450', '동국제약')
# ('064820', '케이프')
# ('091580', '상신이디피')
# ('092460', '한라IMS')
# ('073540', '에프알텍')
# ('091120', '이엠텍')
# ('094850', '참좋은여행')
# ('094860', '코닉글로리')
# ('094800', '맵스리얼티1')
# ('078020', '이베스트투자증권')
# ('093520', '매커스')
# ('048260', '오스템임플란트')
# ('091970', '나노캠텍')
# ('092730', '네오팜')
# ('090460', '비에이치')
# ('039200', '오스코텍')
# ('089010', '켐트로닉스')
# ('090470', '제이스텍')
# ('088130', '동아엘텍')
# ('090370', '메타랩스')
# ('093370', '후성')
# ('084110', '휴온스글로벌')
# ('089150', '케이씨티')
# ('091700', '파트론')
# ('090710', '디에스티로봇')
# ('086390', '유니테스트')
# ('093050', 'LF')
# ('060540', '에스에이티')
# ('066310', '큐에스아이')
# ('067280', '멀티캠퍼스')
# ('044380', '주연테크')
# ('044820', '코스맥스비티아이')
# ('086250', '화신테크')
# ('089890', '코세스')
# ('034590', '인천도시가스')
# ('080470', '성창오토텍')
# ('089140', '넥스턴')
# ('089790', '제이티')
# ('090150', '광진윈텍')
# ('088390', '이녹스')
# ('009770', '삼정펄프')
# ('092220', 'KEC')
# ('092230', 'KPX홀딩스')
# ('089230', 'THE E&M')
# ('043150', '바텍')
# ('086960', '한컴MDS')
# ('089470', 'HDC현대EP')
# ('038060', '루멘스')
# ('091090', '세원셀론텍')
# ('083660', 'CSA 코스믹')
# ('062860', '티엘아이')
# ('063570', '한국전자금융')
# ('086980', '쇼박스')
# ('068050', '팬엔터테인먼트')
# ('085370', '루트로닉')
# ('039290', '인포뱅크')
# ('090350', '노루페인트')
# ('090430', '아모레퍼시픽')
# ('078860', '아이오케이')
# ('088910', '동우팜투테이블')
# ('032350', '롯데관광개발')
# ('054950', '제이브이엠')
# ('090080', '평화산업')
# ('049800', '우진플라임')
# ('084730', '팅크웨어')
# ('035510', '신세계I&C')
# ('086060', '진바이오텍')
# ('022220', '정산애강')
# ('088790', '진도')
# ('088800', '에이스테크')
# ('088980', '맥쿼리인프라')
# ('023530', '롯데쇼핑')
# ('068760', '셀트리온제약')
# ('083450', 'GST')
# ('019990', '에너토크')
# ('079370', '제우스')
# ('046110', '한일네트웍스')
# ('085670', '뉴프렉스')
# ('084370', '유진테크')
# ('083790', '크리스탈')
# ('084990', '바이로메드')
# ('064550', '바이오니아')
# ('083640', '인콘')
# ('085660', '차바이오텍')
# ('086280', '현대글로비스')
# ('078140', '대봉엘에스')
# ('067900', '와이엔텍')
# ('083550', '케이엠')
# ('084870', '티비에이치글로벌')
# ('084180', '수성')
# ('086790', '하나금융지주')
# ('050540', '한국코퍼레이션')
# ('001560', '제일연마')
# ('080420', '모다이노칩')
# ('083650', '비에이치아이')
# ('079190', 'EMW')
# ('045890', 'GV')
# ('079430', '현대리바트')
# ('082800', '루미마이크로')
# ('043910', '자연과환경')
# ('079000', '와토스코리아')
# ('084010', '대한제강')
# ('041020', '인프라웨어')
# ('078590', '두올산업')
# ('038070', '서린바이오')
# ('075180', '새론오토모티브')
# ('083420', '그린케미칼')
# ('079940', '가비아')
# ('077360', '덕산하이메탈')
# ('083930', '아바코')
# ('067310', '하나마이크론')
# ('082660', '삼우엠스')
# ('083310', '엘오티베큠')
# ('080010', '이상네트웍스')
# ('083370', '동북아12호선박투자')
# ('083380', '동북아13호선박투자')
# ('084690', '대상홀딩스')
# ('058220', '아리온')
# ('071950', '코아스')
# ('078160', '메디포스트')
# ('082850', '우리이티아이')
# ('080160', '모두투어')
# ('084680', '이월드')
# ('084670', '동양고속')
# ('042700', '한미반도체')
# ('078890', '가온미디어')
# ('050890', '쏠리드')
# ('004890', '동일산업')
# ('082210', '옵트론텍')
# ('082270', '젬백스')
# ('075130', '플랜티넷')
# ('080440', '에스제이케이')
# ('010960', '삼호개발')
# ('073240', '금호타이어')
# ('073490', '이노와이어리스')
# ('079950', '인베니아')
# ('079960', '동양이엔피')
# ('080220', '제주반도체')
# ('079170', '한창산업')
# ('079810', '디이엔티')
# ('080000', '에스엔유')
# ('052220', 'iMBC')
# ('079650', '서산')
# ('052900', 'KMH하이텍')
# ('066910', '손오공')
# ('049950', '미래컴퍼니')
# ('052460', '아이크래프트')
# ('079160', 'CJ CGV')
# ('081000', '일진다이아')
# ('072870', '메가스터디')
# ('073010', '케이에스피')
# ('046440', 'KG모빌리언스')
# ('078600', '대주전자재료')
# ('054450', '텔레칩스')
# ('078150', 'HB테크놀러지')
# ('067990', '도이치모터스')
# ('014830', '유니드')
# ('051360', '토비스')
# ('072520', '케이디 네이쳐 엔 바이오')
# ('041650', '상신브레이크')
# ('078130', '국일제지')
# ('068790', 'DMS')
# ('079660', '사조해표')
# ('023810', '인팩')
# ('078940', '일경산업개발')
# ('048870', '시너지이노베이션')
# ('065350', '신성델타테크')
# ('078930', 'GS')
# ('077500', '유니퀘스트')
# ('058730', '다스코')
# ('039340', '한국경제TV')
# ('034220', 'LG디스플레이')
# ('064260', '다날')
# ('078000', '텔코웨어')
# ('011080', '형지I&C')
# ('050090', '휘닉스소재')
# ('029960', '코엔텍')
# ('057030', '와이비엠넷')
# ('065770', 'CS')
# ('074430', '아미노로직스')
# ('077280', '한컴지엠디')
# ('066700', '테라젠이텍스')
# ('066900', '디에이피')
# ('078350', '한양디지텍')
# ('077970', 'STX엔진')
# ('075970', '동국알앤에스')
# ('069540', '라이트론')
# ('073190', '듀오백')
# ('054090', '삼진엘앤디')
# ('041910', '에스텍파마')
# ('034310', 'NICE')
# ('019680', '대교')
# ('073070', '에스모')
# ('039670', '스포츠서울')
# ('067770', '세진티에스')
# ('070590', '한솔인티큐브')
# ('073640', '삼원테크')
# ('073570', '피엠지파마')
# ('065680', '우주일렉트로')
# ('057880', '토필드')
# ('024110', '기업은행')
# ('074610', '나노메딕스')
# ('066410', '버킷스튜디오')
# ('060570', '아이리버')
# ('067160', '아프리카TV')
# ('074600', '원익QnC')
# ('071280', '로체시스템즈')
# ('041440', '에버다임')
# ('069510', '에스텍')
# ('067170', '오텍')
# ('054780', '키이스트')
# ('025750', '한솔홈데코')
# ('072020', '중앙백신')
# ('065510', '휴비츠')
# ('072470', '우리산업홀딩스')
# ('068930', '디지털대성')
# ('069110', '코스온')
# ('007660', '이수페타시스')
# ('035250', '강원랜드')
# ('069330', '유아이디')
# ('064760', '티씨케이')
# ('037270', 'YG PLUS')
# ('052710', '아모텍')
# ('072710', '농심홀딩스')
# ('065950', '웰크론')
# ('047310', '파워로직스')
# ('071050', '한국금융지주')
# ('056000', '신스타임즈')
# ('041520', '이라이콤')
# ('065560', '녹원씨엔아이')
# ('072130', '유엔젤')
# ('034120', 'SBS')
# ('064240', '홈캐스트')
# ('066790', '씨씨에스')
# ('069080', '웹젠')
# ('036570', '엔씨소프트')
# ('071090', '하이스틸')
# ('067080', '대화제약')
# ('066590', '우수AMS')
# ('067290', 'JW신약')
# ('066130', '하츠')
# ('046140', 'SBS콘텐츠허브')
# ('065450', '빅텍')
# ('065130', '탑엔지니어링')
# ('069730', 'DSR제강')
# ('065440', '이루온')
# ('006890', '태경화학')
# ('049630', '재영솔루텍')
# ('021650', '한국큐빅')
# ('051370', '인터플렉스')
# ('065650', '메디프론')
# ('065570', '삼영이엔씨')
# ('066980', '브레인콘텐츠')
# ('016100', '리더스코스메틱')
# ('011500', '한농화성')
# ('065940', '바이오빌')
# ('042040', '케이피엠테크')
# ('066970', '엘앤에프')
# ('066670', '디스플레이텍')
# ('066430', '와이오엠')
# ('047820', '초록뱀')
# ('064090', '에프앤리퍼블릭')
# ('049960', '쎌바이오텍')
# ('053290', 'NE능률')
# ('064520', '바른전자')
# ('069960', '현대백화점')
# ('035600', 'KG이니시스')
# ('065170', '넥스트BT')
# ('069460', '대호에이엘')
# ('034230', '파라다이스')
# ('069620', '대웅제약')
# ('041590', '에너전트')
# ('027740', '마니커')
# ('036530', 'S&T홀딩스')
# ('069260', '휴켐스')
# ('042600', '새로닉스')
# ('033530', '세종공업')
# ('065500', '오리엔트정공')
# ('060900', '퍼시픽바이오')
# ('066620', '국보디자인')
# ('065420', '에스아이리소스')
# ('052770', '와이디온라인')
# ('064800', '필링크')
# ('058430', '포스코강판')
# ('039980', '리노스')
# ('048410', '현대바이오')
# ('068290', '삼성출판사')
# ('065160', '에프티이앤이')
# ('067830', '세이브존I&C')
# ('058610', '에스피지')
# ('045340', '토탈소프트')
# ('030610', '교보증권')
# ('065690', '대진디엠피')
# ('065710', '서호전기')
# ('009240', '한샘')
# ('066110', '한프')
# ('043710', '서울리거')
# ('060560', '홈센타홀딩스')
# ('036010', '아비코전자')
# ('060280', '큐렉소')
# ('065620', '제낙스')
# ('060230', '이그잭스')
# ('057680', '옴니텔')
# ('046940', '우원개발')
# ('034300', '신세계건설')
# ('060150', '인선이엔티')
# ('065530', '전파기지국')
# ('063440', 'SM Life Design')
# ('017370', '우신시스템')
# ('051160', '지어소프트')
# ('065060', '지엔코')
# ('049180', '셀루메드')
# ('060720', 'KH바텍')
# ('061040', '알에프텍')
# ('050760', '에스폴리텍')
# ('054210', '이랜텍')
# ('050120', '라이브플렉스')
# ('054410', '케이피티유')
# ('060310', '3S')
# ('066570', 'LG전자')
# ('061250', '화일약품')
# ('053980', '오상자이엘')
# ('024720', '한국콜마홀딩스')
# ('054050', '농우바이오')
# ('039420', '케이엘넷')
# ('064960', 'S&T모티브')
# ('039440', '에스티아이')
# ('049550', '잉크테크')
# ('054670', '대한뉴팜')
# ('060590', '씨티씨바이오')
# ('049070', '인탑스')
# ('060370', 'KT서브마린')
# ('051380', '피씨디렉트')
# ('053660', '현진소재')
# ('037710', '광주신세계')
# ('053270', '구영테크')
# ('034950', '한국기업평가')
# ('060260', '뉴보텍')
# ('060380', '동양에스텍')
# ('046310', '백금T&A')
# ('058530', '슈펙스비앤피')
# ('049720', '고려신용정보')
# ('052670', '제일바이오')
# ('046890', '서울반도체')
# ('013990', '아가방컴퍼니')
# ('058450', '일야')
# ('059090', '미코')
# ('050320', '에이앤티앤')
# ('054930', '유신')
# ('035200', '프럼파스트')
# ('054040', '한국컴퓨터')
# ('048470', '대동스틸')
# ('060300', '레드로버')
# ('042500', '링네트')
# ('058420', '제이웨이')
# ('040350', '큐로컴')
# ('054300', '팬스타엔터프라이즈')
# ('054340', '피앤텔')
# ('047080', '한빛소프트')
# ('020760', '일진디스플')
# ('060250', 'NHN한국사이버결제')
# ('053260', '금강철강')
# ('060240', '룽투코리아')
# ('056730', '포스링크')
# ('057500', 'SKC 솔믹스')
# ('041930', '동아화성')
# ('054220', '비츠로시스')
# ('014940', '오리엔탈정공')
# ('033180', '필룩스')
# ('043590', '크로바하이텍')
# ('058470', '리노공업')
# ('045300', '성우테크론')
# ('056190', '에스에프에이')
# ('056700', '신화인터텍')
# ('054940', '엑사이엔씨')
# ('043370', '평화정공')
# ('063160', '종근당바이오')
# ('054620', 'APS홀딩스')
# ('056360', '코위버')
# ('043260', '성호전자')
# ('038340', 'UCI')
# ('051390', 'YW')
# ('054540', '삼영엠텍')
# ('053350', '이니텍')
# ('054630', '에이디칩스')
# ('056080', '유진로봇')
# ('044490', '태웅')
# ('053950', '경남제약')
# ('053700', '삼보모터스')
# ('003670', '포스코켐텍')
# ('054920', '한컴시큐어')
# ('041960', '코미팜')
# ('053160', '프리엠스')
# ('052400', '코나아이')
# ('054180', '중앙오션')
# ('049470', 'SGA')
# ('053050', '지에스이')
# ('043090', '팜스웰바이오')
# ('053110', '소리바다')
# ('054800', '아이디스홀딩스')
# ('047770', '코데즈컴바인')
# ('053800', '안랩')
# ('055550', '신한지주')
# ('040300', 'YTN')
# ('058820', 'CMG제약')
# ('035900', 'JYP Ent.')
# ('053590', '한국테크놀로지')
# ('021320', 'KCC건설')
# ('053060', '세동')
# ('053610', '프로텍')
# ('052790', '액토즈소프트')
# ('053450', '세코닉스')
# ('053030', '바이넥스')
# ('052420', '오성첨단소재')
# ('021240', '코웨이')
# ('053620', '태양')
# ('052300', 'W홀딩컴퍼니')
# ('049520', '유아이엘')
# ('048910', '대원미디어')
# ('051980', '중앙리빙테크')
# ('058650', '세아홀딩스')
# ('051500', 'CJ프레시웨이')
# ('049120', '파인디앤씨')
# ('043360', '디지아이')
# ('052330', '코텍')
# ('052600', '한네트')
# ('052020', '에스티큐브')
# ('043220', '에이치엘비파워')
# ('033790', '스카이문스테크놀로지')
# ('051780', '큐로홀딩스')
# ('052190', '이에스에이')
# ('051490', '나라엠앤디')
# ('038870', '에코바이오')
# ('045660', '에이텍')
# ('052260', 'SK바이오랜드')
# ('045390', '대아티아이')
# ('050110', '캠시스')
# ('036540', 'SFA반도체')
# ('051900', 'LG생활건강')
# ('051910', 'LG화학')
# ('047040', '대우건설')
# ('047050', '포스코대우')
# ('042660', '대우조선해양')
# ('042670', '두산인프라코어')
# ('038500', '삼표시멘트')
# ('051630', '진양화학')
# ('048550', 'SM C&C')
# ('049830', '승일')
# ('044060', '조광ILI')
# ('024850', '피에스엠씨')
# ('048770', 'TPC')
# ('049430', '코메론')
# ('044480', '바이오제네틱스')
# ('046390', '삼화네트웍스')
# ('014620', '성광벤드')
# ('048430', '유라테크')
# ('017480', '삼현철강')
# ('049480', '오픈베이스')
# ('036670', 'KCI')
# ('042510', '라온시큐어')
# ('039830', '오로라')
# ('036190', '금화피에스시')
# ('046070', '코다코')
# ('041830', '인바디')
# ('014570', '고려제약')
# ('045520', '크린앤사이언스')
# ('022100', '포스코 ICT')
# ('049770', '동원F&B')
# ('033600', '에이코넬')
# ('044180', 'KD건설')
# ('044960', '이글벳')
# ('032080', '아즈텍WB')
# ('034020', '두산중공업')
# ('010470', '오리콤')
# ('044340', '위닉스')
# ('042940', '상지카일룸')
# ('010040', '한국내화')
# ('048830', '엔피케이')
# ('000250', '삼천당제약')
# ('044780', '에이치케이')
# ('045510', '정원엔시스')
# ('045100', '한양이엔지')
# ('040160', '누리텔레콤')
# ('043340', '에쎈테크')
# ('043650', '국순당')
# ('037950', '엘컴텍')
# ('039030', '이오테크닉스')
# ('038540', '상상인')
# ('018680', '서울제약')
# ('039860', '나노엔텍')
# ('046210', '파나진')
# ('045060', '오공')
# ('043100', '솔고바이오')
# ('026180', '현대정보기술')
# ('042370', '비츠로테크')
# ('045970', '코아시아홀딩스')
# ('040420', '정상제이엘에스')
# ('007370', '진양제약')
# ('041140', '넥슨지티')
# ('043610', '지니뮤직')
# ('036890', '진성티이씨')
# ('039010', '현대통신')
# ('009300', '삼아제약')
# ('043200', '파루')
# ('042110', '에스씨디')
# ('039740', '한국정보공학')
# ('039840', '디오')
# ('042420', '네오위즈홀딩스')
# ('039560', '다산네트웍스')
# ('038460', '바이오스마트')
# ('039230', '에이아이비트')
# ('032820', '우리기술')
# ('001540', '안국약품')
# ('038530', '골드퍼시픽')
# ('039310', '세중')
# ('041190', '우리기술투자')
# ('036640', 'HRS')
# ('031330', '에스에이엠티')
# ('030190', 'NICE평가정보')
# ('038620', '위즈코프')
# ('039020', '이건홀딩스')
# ('038950', '파인디지털')
# ('036800', '나이스정보통신')
# ('040610', 'SG&G')
# ('038880', '아이에이')
# ('038680', '에스넷')
# ('041510', '에스엠')
# ('010280', '쌍용정보통신')
# ('037760', '쎄니트')
# ('036480', '대성미생물')
# ('038110', '에코플라스틱')
# ('036420', '제이콘텐트리')
# ('032500', '케이엠더블유')
# ('039610', '화성밸브')
# ('039240', '경남스틸')
# ('038290', '마크로젠')
# ('037440', '희림')
# ('038390', '레드캡투어')
# ('028150', 'GS홈쇼핑')
# ('036830', '솔브레인')
# ('036810', '에프에스티')
# ('036690', '코맥스')
# ('037370', 'EG')
# ('036620', '버추얼텍')
# ('037350', '성도이엔지')
# ('038010', '제일테크노스')
# ('016450', '한세예스24홀딩스')
# ('001810', '무림SP')
# ('036630', '세종텔레콤')
# ('036710', '심텍홀딩스')
# ('037070', '파세코')
# ('036560', '영풍정밀')
# ('016250', '이테크건설')
# ('036030', 'KTH')
# ('035890', '서희건설')
# ('036930', '주성엔지니어링')
# ('016710', '대성홀딩스')
# ('032190', '다우데이타')
# ('005290', '동진쎄미켐')
# ('003100', '선광')
# ('036170', '씨티젠')
# ('036180', '영인프런티어')
# ('026040', '제이에스티나')
# ('037230', '한국팩키지')
# ('037460', '삼지전자')
# ('037400', '우리조명')
# ('003220', '대원제약')
# ('036460', '한국가스공사')
# ('036490', 'SK머티리얼즈')
# ('033640', '네패스')
# ('037330', '인지디스플레')
# ('036090', '위지트')
# ('036200', '유니셈')
# ('024800', '유성티엔에스')
# ('036260', '이매진아시아')
# ('027050', '코리아나')
# ('036120', 'SCI평가정보')
# ('035290', '더블유에프엠')
# ('027040', '서울전자통신')
# ('027830', '대성창투')
# ('036000', '예림당')
# ('007120', '미래아이앤지')
# ('035760', 'CJ ENM')
# ('035810', '이지바이오')
# ('035460', '기산텔레콤')
# ('035480', '마제스타')
# ('000850', '화천기공')
# ('036580', '팜스코')
# ('033780', '케이티앤지')
# ('009540', '현대중공업')
# ('024090', '디씨엠')
# ('035620', '바른손이앤에이')
# ('035610', '솔본')
# ('020710', '시공테크')
# ('012790', '신일제약')
# ('034940', '조아제약')
# ('006840', 'AK홀딩스')
# ('006650', '대한유화')
# ('035150', '백산')
# ('035000', '지투알')
# ('033250', '체시스')
# ('033230', '인성정보')
# ('035080', '인터파크홀딩스')
# ('005160', '동국산업')
# ('005990', '매일홀딩스')
# ('034810', '해성산업')
# ('033240', '자화전자')
# ('030200', '케이티')
# ('019490', '하이트론씨스템즈')
# ('031390', '녹십자셀')
# ('033430', '디에스티')
# ('030000', '제일기획')
# ('025770', '한국정보통신')
# ('033540', '파라텍')
# ('033500', '동성화인텍')
# ('026890', '디피씨')
# ('029460', '케이씨')
# ('030350', '드래곤플라이')
# ('033310', '디케이디앤아이')
# ('033160', '엠케이전자')
# ('033320', '제이씨현시스템')
# ('009520', '포스코엠텍')
# ('013810', '스페코')
# ('033340', '좋은사람들')
# ('024890', '대원화성')
# ('033200', '모아텍')
# ('033290', '코웰패션')
# ('015710', '코콤')
# ('017940', 'E1')
# ('018670', 'SK가스')
# ('023590', '다우기술')
# ('014440', '영보화학')
# ('033110', '이디')
# ('033100', '제룡전기')
# ('033050', '제이엠아이')
# ('033130', '디지틀조선')
# ('032980', '바이온')
# ('019210', '와이지-원')
# ('026150', '특수건설')
# ('031310', '아이즈비전')
# ('011790', 'SKC')
# ('032960', '동일기연')
# ('032680', '소프트센')
# ('032940', '원익')
# ('008290', '원풍물산')
# ('010600', '웰바이오텍')
# ('025890', '한국주강')
# ('032750', '삼진')
# ('032860', 'GMR 머티리얼즈')
# ('032850', '비트컴퓨터')
# ('032790', '엠젠플러스')
# ('032800', '판타지오')
# ('024900', '덕양산업')
# ('015350', '부산도시가스')
# ('023960', '에쓰씨엔지니어링')
# ('023800', '인지컨트롤스')
# ('032620', '유비케어')
# ('032580', '피델릭스')
# ('032540', 'TJ미디어')
# ('028080', '휴맥스홀딩스')
# ('032280', '삼일')
# ('012320', '경동인베스트')
# ('012340', '뉴인텍')
# ('025530', '에스제이엠홀딩스')
# ('031510', '오스템')
# ('031820', '콤텍시스템')
# ('030270', '에스마크')
# ('031860', '엔에스엔')
# ('031980', '피에스케이')
# ('000660', 'SK하이닉스')
# ('023150', 'MH에탄올')
# ('005320', '국동')
# ('023450', '동남합성')
# ('028050', '삼성엔지니어링')
# ('029530', '신도리코')
# ('015360', '예스코홀딩스')
# ('016800', '퍼시스')
# ('011560', '세보엠이씨')
# ('024740', '한일단조')
# ('024070', 'WISCOM')
# ('030720', '동원수산')
# ('025560', '미래산업')
# ('030210', 'KTB투자증권')
# ('030960', '양지사')
# ('012630', 'HDC')
# ('017900', '광전자')
# ('025540', '한국단자공업')
# ('030530', '원익홀딩스')
# ('030520', '한글과컴퓨터')
# ('021880', '메이슨캐피탈')
# ('021040', '대호피앤씨')
# ('029480', '바른테크놀로지')
# ('003160', '디아이')
# ('011930', '신성이엔지')
# ('019180', '티에이치엔')
# ('018880', '한온시스템')
# ('028040', '미래SCI')
# ('028300', '에이치엘비')
# ('027710', '팜스토리')
# ('021820', '세원정공')
# ('027970', '세하')
# ('006740', '영풍제지')
# ('000910', '유니온')
# ('020120', '키다리스튜디오')
# ('020000', '한섬')
# ('017800', '현대엘리베이터')
# ('016580', '환인제약')
# ('023600', '삼보판지')
# ('018310', '삼목에스폼')
# ('003800', '에이스침대')
# ('014190', '원익큐브')
# ('013580', '계룡건설산업')
# ('011160', '두산건설')
# ('021050', '서원')
# ('012750', '에스원')
# ('015890', '태경산업')
# ('027390', '한화갤러리아타임월드')
# ('012700', '리드코프')
# ('018000', '유니슨')
# ('025980', '아난티')
# ('026910', '광진실업')
# ('017250', '인터엠')
# ('016590', '신대양제지')
# ('011690', '유양디앤유')
# ('025860', '남해화학')
# ('018500', '동원금속')
# ('011300', '성안')
# ('015750', '성우하이텍')
# ('020180', '대신정보통신')
# ('006730', '서부T&D')
# ('012610', '경인양행')
# ('017810', '풀무원')
# ('011200', '현대상선')
# ('017390', '서울도시가스')
# ('025820', '이구산업')
# ('025950', '동신건설')
# ('025900', '동화기업')
# ('011090', '에넥스')
# ('007460', '에이프로젠 KIC')
# ('025620', '제이준코스메틱')
# ('017960', '한국카본')
# ('025870', '신라에스지')
# ('025880', '케이씨피드')
# ('002680', '한탑')
# ('025550', '한국선재')
# ('025440', '대성엘텍')
# ('025320', '시노펙스')
# ('024940', 'PN풍년')
# ('024950', '삼천리자전거')
# ('014100', '보령메디앙스')
# ('024840', '갑을메탈')
# ('024910', '경창산업')
# ('004780', '대륙제관')
# ('013120', '동원개발')
# ('024830', '세원물산')
# ('024810', '이화전기')
# ('024880', '케이피에프')
# ('025000', 'KPX케미칼')
# ('010580', '지코')
# ('007980', '태평양물산')
# ('024120', 'KB오토시스')
# ('017000', '신원종합개발')
# ('024060', '흥구석유')
# ('023910', '대한약품')
# ('023890', '아트라스BX')
# ('001840', '이화공영')
# ('023900', '풍국주정')
# ('017650', '대림제지')
# ('010170', '대한광통신')
# ('023790', '동일철강')
# ('023770', '플레이위드')
# ('023760', '한국캐피탈')
# ('005860', '한일사료')
# ('009440', 'KC그린홀딩스')
# ('008420', '문배철강')
# ('016880', '웅진')
# ('012860', '서연전자')
# ('023460', 'CNH')
# ('006050', '국영지앤엠')
# ('023410', '유진기업')
# ('023440', '제일제강')
# ('006910', '보성파워텍')
# ('018290', '지엠피')
# ('023160', '태광')
# ('007310', '오뚜기')
# ('008500', '일정실업')
# ('014790', '한라')
# ('007530', '영신금속')
# ('010120', 'LS산전')
# ('001000', '신라섬유')
# ('012620', '원일특강')
# ('011370', '서한')
# ('009190', '대양금속')
# ('000760', '이화산업')
# ('014820', '동원시스템즈')
# ('018700', '바른손')
# ('014470', '부방')
# ('010140', '삼성중공업')
# ('009680', '모토닉')
# ('010690', '화신')
# ('007720', '대명코퍼레이션')
# ('006580', '대양제지')
# ('011320', '유니크')
# ('018120', '진로발효')
# ('013720', '청보산업')
# ('009620', '삼보산업')
# ('005670', '푸드웰')
# ('007330', '푸른저축은행')
# ('006140', '피제이전자')
# ('019010', '그랜드백화점')
# ('009780', '엠에스씨')
# ('000390', '삼화페인트공업')
# ('017680', '데코앤이')
# ('008800', '행남사')
# ('009450', '경동나비엔')
# ('020400', '대동금속')
# ('014200', '광림')
# ('005710', '대원산업')
# ('016600', '큐캐피탈')
# ('004590', '한국가구')
# ('016670', '포비스티앤씨')
# ('000440', '중앙에너비스')
# ('012030', 'DB')
# ('005090', '삼광글라스')
# ('014970', '삼륭물산')
# ('005750', '대림비앤코')
# ('011040', '경동제약')
# ('008370', '원풍')
# ('007390', '네이처셀')
# ('002290', '삼일기업공사')
# ('019540', '일지테크')
# ('007770', '한일화학')
# ('017890', '한국알콜')
# ('003310', '대주산업')
# ('019660', '글로본')
# ('005880', '대한해운')
# ('008560', '메리츠종금증권')
# ('017510', '세명전기')
# ('005870', '휴니드테크놀러지스')
# ('017550', '수산중공업')
# ('021080', '에이티넘인베스트')
# ('011170', '롯데케미칼')
# ('008830', '대동기어')
# ('001430', '세아베스틸')
# ('008770', '호텔신라')
# ('014580', '백광소재')
# ('013520', '화승알앤에이')
# ('004080', '신흥')
# ('006060', '화승인더스트리')
# ('014530', '극동유화')
# ('002140', '고려산업')
# ('002230', '피에스텍')
# ('016090', '대현')
# ('001620', '동국실업')
# ('017040', '광명전기')
# ('011390', '부산산업')
# ('011810', 'STX')
# ('010130', '고려아연')
# ('009730', '코센')
# ('012600', '청호컴넷')
# ('004720', '우리들제약')
# ('009200', '무림페이퍼')
# ('001500', '현대차증권')
# ('008870', '금비')
# ('008110', '대동전자')
# ('005820', '원림')
# ('008490', '서흥')
# ('014910', '성문전자')
# ('003580', '넥스트사이언스')
# ('015860', '일진홀딩스')
# ('014160', '대영포장')
# ('012280', '영화금속')
# ('019170', '신풍제약')
# ('002210', '동성제약')
# ('016920', '카스')
# ('012170', '키위미디어그룹')
# ('009420', '한올바이오파마')
# ('013030', '하이록코리아')
# ('011330', '유니켐')
# ('012800', '대창')
# ('001140', '국보')
# ('013360', '일성건설')
# ('013700', '까뮤이앤씨')
# ('002760', '보락')
# ('007610', '선도전기')
# ('004920', '씨아이테크')
# ('009290', '광동제약')
# ('011420', '갤럭시아에스엠')
# ('004270', '남성')
# ('001940', 'KISCO홀딩스')
# ('009410', '태영건설')
# ('007280', '한국특수형강')
# ('009180', '한솔로지스틱스')
# ('002170', '삼양통상')
# ('017670', 'SK텔레콤')
# ('010640', '진양폴리우레탄')
# ('003650', '미창석유공업')
# ('004380', '삼익THK')
# ('002840', '미원상사')
# ('007860', '서연')
# ('019550', 'SBI인베스트먼트')
# ('013000', '세우글로벌')
# ('012330', '현대모비스')
# ('015540', '메디플란트')
# ('001390', 'KG케미칼')
# ('009320', '대우부품')
# ('001450', '현대해상')
# ('005440', '현대그린푸드')
# ('015760', '한국전력공사')
# ('007690', '국도화학')
# ('006280', '녹십자')
# ('009160', 'SIMPAC')
# ('008600', '윌비스')
# ('015230', '대창단조')
# ('007160', '사조산업')
# ('014130', '한익스프레스')
# ('008040', '사조동아원')
# ('009140', '경인전자')
# ('009580', '무림P&P')
# ('014990', '인디에프')
# ('010420', '한솔피엔에스')
# ('013570', '디와이')
# ('003610', '방림')
# ('015590', '큐로')
# ('014680', '한솔케미칼')
# ('010820', '퍼스텍')
# ('019590', '엠벤처투자')
# ('019570', '제미니투자')
# ('006040', '동원산업')
# ('008060', '대덕전자')
# ('003680', '한성기업')
# ('006920', '모헨즈')
# ('015020', '이스타코')
# ('011280', '태림포장')
# ('002310', '아세아제지')
# ('010660', '화천기계')
# ('011150', 'CJ씨푸드')
# ('001770', '신화실업')
# ('018470', '조일알미늄')
# ('005850', '에스엘')
# ('009970', '영원무역홀딩스')
# ('012510', '더존비즈온')
# ('003850', '보령제약')
# ('007630', '폴루스바이오팜')
# ('008250', '이건산업')
# ('012690', '모나리자')
# ('006370', '대구백화점')
# ('006980', '우성사료')
# ('002920', '유성기업')
# ('002220', '한일철강')
# ('002450', '삼익악기')
# ('002460', '화성산업')
# ('007340', '디티알오토모티브')
# ('001290', '골든브릿지증권')
# ('000890', '보해양조')
# ('003010', '혜인')
# ('014280', '금강공업')
# ('009810', '엔케이물산')
# ('008730', '율촌화학')
# ('009270', '신원')
# ('004140', '동방')
# ('002960', '한국쉘석유')
# ('003000', '부광약품')
# ('005810', '풍산홀딩스')
# ('001270', '부국증권')
# ('012200', '계양전기')
# ('004710', '한솔테크닉스')
# ('005190', '동성화학')
# ('016610', 'DB금융투자')
# ('008930', '한미사이언스')
# ('005500', '삼진제약')
# ('005490', '포스코')
# ('002410', '범양건영')
# ('005690', '파미셀')
# ('001230', '동국제강')
# ('006340', '대원전선')
# ('005950', '이수화학')
# ('016360', '삼성증권')
# ('002810', '삼영무역')
# ('001750', '한양증권')
# ('011780', '금호석유화학')
# ('003470', '유안타증권')
# ('002620', '제일파마홀딩스')
# ('015260', '에이엔피')
# ('009460', '한창제지')
# ('005720', '넥센')
# ('006660', '삼성공조')
# ('004490', '세방전지')
# ('011000', '진원생명과학')
# ('009310', '참엔지니어링')
# ('010100', '한국프랜지공업')
# ('005070', '코스모신소재')
# ('004830', '덕성')
# ('001720', '신영증권')
# ('001200', '유진증권')
# ('003460', '유화증권')
# ('011700', '한신기계공업')
# ('005420', '코스모화학')
# ('000500', '가온전선')
# ('010950', 'S-Oil')
# ('012450', '한화에어로스페이스')
# ('011230', '삼화전자공업')
# ('004020', '현대제철')
# ('004770', '써니전자')
# ('004560', '현대비앤지스틸')
# ('006090', '사조오양')
# ('003530', '한화투자증권')
# ('009470', '삼화전기')
# ('001510', 'SK증권')
# ('010770', '평화홀딩스')
# ('007110', '일신석재')
# ('016380', '동부제철')
# ('010780', '아이에스동서')
# ('002360', 'SH에너지화학')
# ('003830', '대한화섬')
# ('007810', '코리아써키트')
# ('004170', '신세계')
# ('010060', 'OCI')
# ('000520', '삼일제약')
# ('006490', '인스코비')
# ('003120', '일성신약')
# ('000720', '현대건설')
# ('002710', 'TCC동양')
# ('003060', '에이프로젠제약')
# ('007700', 'F&F')
# ('008700', '아남전자')
# ('010620', '현대미포조선')
# ('006360', 'GS건설')
# ('006110', '삼아알미늄')
# ('006200', '한국전자홀딩스')
# ('006400', '삼성SDI')
# ('009150', '삼성전기')
# ('004200', '고려개발')
# ('005960', '동부건설')
# ('009070', '케이씨티시')
# ('003070', '코오롱글로벌')
# ('005180', '빙그레')
# ('005250', '녹십자홀딩스')
# ('005450', '신한')
# ('000480', '조선내화')
# ('004310', '현대약품')
# ('003920', '남양유업')
# ('008350', '남선알미늄')
# ('003350', '한국화장품제조')
# ('001880', '삼호')
# ('011760', '현대종합상사')
# ('006260', 'LS')
# ('001740', 'SK네트웍스')
# ('002100', '경농')
# ('004870', '티웨이홀딩스')
# ('007590', '동방아그로')
# ('004430', '송원산업')
# ('002780', '진흥기업')
# ('004090', '한국석유공업')
# ('000650', '천일고속')
# ('000430', '대원강업')
# ('001080', '만호제강')
# ('004700', '조광피혁')
# ('004360', '세방')
# ('008970', '동양철관')
# ('002880', '대유에이텍')
# ('001260', '남광토건')
# ('005680', '삼영전자공업')
# ('005800', '신영와코루')
# ('002630', '오리엔트바이오')
# ('001550', '조비')
# ('005430', '한국공항')
# ('004910', '조광페인트')
# ('004690', '삼천리')
# ('003080', '성보화학')
# ('002600', '조흥')
# ('001570', '금양')
# ('003960', '사조대림')
# ('002070', '남영비비안')
# ('003570', 'S&T중공업')
# ('004960', '한신공영')
# ('004370', '농심')
# ('003720', '삼영화학공업')
# ('004980', '성신양회')
# ('004970', '신라교역')
# ('002870', '신풍제지')
# ('001630', '종근당홀딩스')
# ('005740', '크라운해태홀딩스')
# ('002390', '한독')
# ('001380', 'SG충방')
# ('006120', 'SK디스커버리')
# ('007540', '샘표')
# ('003280', '흥아해운')
# ('001250', 'GS글로벌')
# ('002990', '금호산업')
# ('001470', '삼부토건')
# ('001820', '삼화콘덴서공업')
# ('001020', '페이퍼코리아')
# ('001520', '동양')
# ('000880', '한화')
# ('001060', 'JW중외제약')
# ('000670', '영풍')
# ('001340', '백광산업')
# ('000180', '성창기업지주')
# ('005110', '한창')
# ('004450', '삼화왕관')
# ('000040', 'KR모터스')
# ('002240', '고려제강')
# ('004100', '태양금속공업')
# ('002820', '선창산업')
# ('004840', 'DRB동일')
# ('002350', '넥센타이어')
# ('004060', 'SG세계물산')
# ('004000', '롯데정밀화학')
# ('000020', '동화약품')
# ('000210', '대림산업')
# ('001120', 'LG상사')
# ('002720', '국제약품')
# ('003240', '태광산업')
# ('005030', '부산주공')
# ('006390', '한일현대시멘트')
# ('000590', 'CS홀딩스')
# ('005390', '신성통상')
# ('000990', 'DB하이텍')
# ('006570', '대림통상')
# ('000220', '유유제약')
# ('000860', '강남제비스코')
# ('003540', '대신증권')
# ('005940', 'NH투자증권')
# ('006800', '미래에셋대우')
# ('002700', '신일산업')
# ('001360', '삼성제약')
# ('000810', '삼성화재해상보험')
# ('003230', '삼양식품')
# ('000370', '한화손해보험')
# ('008260', 'NI스틸')
# ('000230', '일동홀딩스')
# ('000490', '대동공업')
# ('001800', '오리온홀딩스')
# ('004540', '깨끗한나라')
# ('001420', '태원물산')
# ('002020', '코오롱')
# ('005930', '삼성전자')
# ('000300', '대유플러스')
# ('001460', 'BYC')
# ('003620', '쌍용자동차')
# ('003410', '쌍용양회공업')
# ('005610', 'SPC삼립')
# ('000540', '흥국화재')
# ('010050', '우리종금')
# ('007570', '일양약품')
# ('002320', '한진')
# ('002200', '한국수출포장공업')
# ('005380', '현대자동차')
# ('005360', '모나미')
# ('009830', '한화케미칼')
# ('002030', '아세아')
# ('006380', '카프로')
# ('004990', '롯데지주')
# ('001070', '대한방직')
# ('004410', '서울식품공업')
# ('003560', '아이에이치큐')
# ('000680', 'LS네트웍스')
# ('001210', '금호전기')
# ('002250', '알보젠코리아')
# ('000140', '하이트진로홀딩스')
# ('000320', '노루홀딩스')
# ('000270', '기아자동차')
# ('004800', '효성')
# ('001040', 'CJ')
# ('000150', '두산')
# ('005010', '휴스틸')
# ('005830', 'DB손해보험')
# ('003090', '대웅')
# ('002900', '동양물산기업')
# ('003780', '진양산업')
# ('003520', '영진약품')
# ('002380', '케이씨씨')
# ('005300', '롯데칠성음료')
# ('003200', '일신방직')
# ('002270', '롯데푸드')
# ('002790', '아모레퍼시픽그룹')
# ('006220', '제주은행')
# ('004150', '한솔홀딩스')
# ('007210', '벽산')
# ('002300', '한국제지')
# ('000400', '롯데손해보험')
# ('001130', '대한제분')
# ('001680', '대상')
# ('003550', 'LG')
# ('000640', '동아쏘시오홀딩스')
# ('003690', '코리안리')
# ('000970', '한국주철관공업')
# ('003300', '한일홀딩스')
# ('004250', '엔피씨')
# ('003030', '세아제강지주')
# ('001440', '대한전선')
# ('001790', '대한제당')
# ('000070', '삼양홀딩스')
# ('002420', '세기상사')
# ('000240', '한국타이어월드와이드')
# ('000950', '전방')
# ('003490', '대한항공')
# ('001530', '동일방직')
# ('000100', '유한양행')
# ('000120', 'CJ대한통운')
# ('000060', '메리츠화재')
# ('000050', '경방')
# ('000700', '유수홀딩스')
# ('003480', '한진중공업홀딩스')

# %%
conn.commit
# Out:
# <function Connection.commit>

# %%
cur.execute("select * from evComp_company")
for data in cur.fetchall():
    print(data)
# Out:
# (1, '311060', '엘에이티')
# (2, '311840', '대원모방')
# (3, '298690', '에어부산')
# (4, '238200', '비피도')
# (5, '314130', '지놈앤컴퍼니')
# (6, '311270', '키움제5호스팩')
# (7, '310840', '엔에이치스팩13호')
# (8, '263050', '유틸렉스')
# (9, '290550', '디케이티')
# (10, '310200', '미래에셋대우스팩2호')
# (11, '307180', '신영스팩4호')
# (12, '308700', '테크엔')
# (13, '309930', '삼성머스트스팩3호')
# (14, '299900', '위지윅스튜디오')
# (15, '310870', '한국제8호스팩')
# (16, '307750', '대신밸런스제6호스팩')
# (17, '298380', '에이비엘바이오')
# (18, '303360', '프로테옴텍')
# (19, '100590', '머큐리')
# (20, '110020', '전진바이오팜')
# (21, '270870', '뉴트리')
# (22, '307870', '골든브릿지이안5호')
# (23, '302430', '이노메트리')
# (24, '307070', 'SK4호스팩')
# (25, '290120', '대유에이피')
# (26, '307280', '교보8호스팩')
# (27, '128540', '에코캡')
# (28, '299910', '베스파')
# (29, '271780', '비엔에프코퍼레이션')
# (30, '900340', '윙입푸드')
# (31, '307160', '하나머스트제6호스팩')
# (32, '111710', '남화산업')
# (33, '179290', '엠아이텍')
# (34, '117730', '티로보틱스')
# (35, '290660', '네오펙트')
# (36, '207490', '에이펙스인텍')
# (37, '246710', '티앤알바이오팹')
# (38, '288490', '나라소프트')
# (39, '267850', '아시아나IDT')
# (40, '263690', '디알젬')
# (41, '217330', '싸이토젠')
# (42, '027360', '아주IB투자')
# (43, '208340', '파멥신')
# (44, '263020', '디케이앤디')
# (45, '122050', '아이엘사이언스')
# (46, '227100', '디자인')
# (47, '194700', '노바렉스')
# (48, '268600', '셀리버리')
# (49, '290670', '대보마그네틱')
# (50, '285490', '노바텍')
# (51, '290650', '엘앤씨바이오')
# (52, '306620', 'DB금융스팩6호')
# (53, '108490', '로보티즈')
# (54, '153710', '옵티팜')
# (55, '288620', '에스퓨얼셀')
# (56, '306200', '세아제강')
# (57, '293580', '나우아이비캐피탈')
# (58, '290720', '푸드나무')
# (59, '293480', '하나제약')
# (60, '110790', '크리스에프앤씨')
# (61, '299170', 'IBKS제10호스팩')
# (62, '219750', '지티지웰니스')
# (63, '010400', '우진아이엔에스')
# (64, '257370', '명성티엔에스')
# (65, '291230', '삼성스팩2호')
# (66, '140610', '엔솔바이오사이언스')
# (67, '197140', '디지캡')
# (68, '303030', '대신밸런스제5호스팩')
# (69, '290740', '액트로')
# (70, '173130', '오파스넷')
# (71, '089970', '에이피티씨')
# (72, '086820', '바이오솔루션')
# (73, '302550', '리메드')
# (74, '302920', '더콘텐츠온')
# (75, '290380', '대유')
# (76, '262760', '엔케이맥스')
# (77, '293940', '신한알파리츠')
# (78, '110990', '디아이티')
# (79, '275630', '에스에스알')
# (80, '300720', '한일시멘트')
# (81, '290270', '휴네시온')
# (82, '091810', '티웨이항공')
# (83, '286940', '롯데정보통신')
# (84, '080720', '한국유니온제약')
# (85, '204020', '엠코르셋')
# (86, '297570', 'IBKS제9호스팩')
# (87, '226950', '올릭스')
# (88, '258050', '테크트랜스')
# (89, '298040', '효성중공업')
# (90, '298050', '효성첨단소재')
# (91, '298020', '효성티앤씨')
# (92, '298000', '효성화학')
# (93, '175250', '아이큐어')
# (94, '289080', 'SV인베스트먼트')
# (95, '276240', '엘리비젼')
# (96, '299480', '지앤이헬스케어')
# (97, '088260', '이리츠코크렙')
# (98, '245620', 'EDGC')
# (99, '299670', '에스엠비나')
# (100, '294870', 'HDC현대산업개발')
# (101, '284620', '하나금융11호스팩')
# (102, '037030', '파워넷')
# (103, '016790', '현대사료')
# (104, '258830', '세종메디칼')
# (105, '122310', '제노레이')
# (106, '163430', '디피코')
# (107, '291210', '한국제7호스팩')
# (108, '086080', '다이노나')
# (109, '287410', '유안타제3호스팩')
# (110, '217910', '에스제이켐')
# (111, '950170', 'JTC')
# (112, '253590', '대신밸런스제3호스팩')
# (113, '065370', '위세아이텍')
# (114, '263700', '케어랩스')
# (115, '018250', '애경산업')
# (116, '064510', '에코마이스터')
# (117, '277070', '린드먼아시아')
# (118, '226400', '오스테오닉')
# (119, '183490', '엔지켐생명과학')
# (120, '006620', '동구바이오제약')
# (121, '154030', '아시아종묘')
# (122, '260660', '알리코제약')
# (123, '068270', '셀트리온')
# (124, '042000', '카페24')
# (125, '219420', '링크제니시스')
# (126, '267790', '배럴')
# (127, '255220', 'SG')
# (128, '264660', '씨앤지하이테크')
# (129, '284740', '쿠쿠홈시스')
# (130, '285130', 'SK케미칼')
# (131, '269620', '시스웍')
# (132, '284610', 'TS트릴리온')
# (133, '285770', '라이프사이언스테크놀로지')
# (134, '281410', '한국제6호스팩')
# (135, '187870', '디바이스이엔지')
# (136, '281310', '바이오시네틱스')
# (137, '236030', '씨알푸드')
# (138, '281740', '동부스팩5호')
# (139, '284420', '휴럼')
# (140, '282330', 'BGF리테일')
# (141, '092780', '동양피스톤')
# (142, '272450', '진에어')
# (143, '260930', '씨티케이코스메틱스')
# (144, '241770', '메카로')
# (145, '234300', '에스트래픽')
# (146, '281820', '케이씨텍')
# (147, '066360', '체리부로')
# (148, '007680', '대원')
# (149, '138580', '비즈니스온')
# (150, '282690', '동아타이어')
# (151, '272550', '삼양패키징')
# (152, '279410', '한화에이스스팩4호')
# (153, '253450', '스튜디오드래곤')
# (154, '276920', 'IBKS제7호스팩')
# (155, '279600', '미디어젠')
# (156, '148140', '비디아이')
# (157, '950160', '코오롱티슈진')
# (158, '055490', '테이팩스')
# (159, '278990', '파인이엠텍')
# (160, '280360', '롯데제과')
# (161, '277880', '티에스아이')
# (162, '180060', '탑선')
# (163, '265560', '영화테크')
# (164, '234100', '세원')
# (165, '277480', '신한제4호스팩')
# (166, '263810', '상신전자')
# (167, '255440', '야스')
# (168, '277410', '인산가')
# (169, '263920', '에스엔피월드')
# (170, '243840', '신흥에스이씨')
# (171, '179900', '유티아이')
# (172, '171090', '선익시스템')
# (173, '259630', '엠플러스')
# (174, '174900', '앱클론')
# (175, '263540', '샘코')
# (176, '263750', '펄어비스')
# (177, '270020', '두원석재')
# (178, '256940', '케이피에스')
# (179, '260870', '시그넷이브이')
# (180, '263600', '덕우전자')
# (181, '267060', '명진홀딩스')
# (182, '258610', '이더블유케이')
# (183, '270520', '하나금융10호스팩')
# (184, '176560', '포인트엔지니어링')
# (185, '140670', '알에스오토메이션')
# (186, '900310', '컬러레이')
# (187, '273060', '엔에이치스팩12호')
# (188, '118990', '모트렉스')
# (189, '263800', '데이타솔루션')
# (190, '263860', '지니언스')
# (191, '263720', '디앤씨미디어')
# (192, '091990', '셀트리온헬스케어')
# (193, '181340', '이즈미디어')
# (194, '162120', '루켄테크놀러지스')
# (195, '270660', '에브리봇')
# (196, '271740', '한국제5호스팩')
# (197, '238490', '힘스')
# (198, '271980', '제일약품')
# (199, '251630', '브이원텍')
# (200, '227610', '아우딘퓨쳐스')
# (201, '272290', '이녹스첨단소재')
# (202, '035720', '카카오')
# (203, '271400', '알로이스')
# (204, '271560', '오리온')
# (205, '003380', '하림지주')
# (206, '221670', '주노콜렉션')
# (207, '233250', '메디안디노스틱')
# (208, '261200', '하나금융9호스팩')
# (209, '267320', '교보7호스팩')
# (210, '271850', '다이오진')
# (211, '270210', '에스알바이오텍')
# (212, '266170', '앤유엔터테인먼트')
# (213, '250000', '보라티알')
# (214, '265920', '한화수성스팩')
# (215, '267980', '매일유업')
# (216, '225190', '삼양옵틱스')
# (217, '264850', 'IBKS제6호스팩')
# (218, '161580', '필옵틱스')
# (219, '265480', '미래에셋대우스팩1호')
# (220, '224880', 'SGA임베디드')
# (221, '268280', '미원에스씨')
# (222, '267290', '경동도시가스')
# (223, '251270', '넷마블')
# (224, '079440', '오렌지라이프')
# (225, '267270', '현대건설기계')
# (226, '267260', '현대일렉트릭')
# (227, '267250', '현대중공업지주')
# (228, '256630', '엔에이치스팩10호')
# (229, '264290', '한화에이스스팩3호')
# (230, '267810', '앙츠')
# (231, '166090', '하나머티리얼즈')
# (232, '251370', '와이엠티')
# (233, '258790', '케이비제11호스팩')
# (234, '225860', '엠앤씨생명과학')
# (235, '266870', '파워풀엑스')
# (236, '264900', '크라운제과')
# (237, '265520', 'AP시스템')
# (238, '263770', '유에스티')
# (239, '063760', '이엘피')
# (240, '264450', '유비쿼스')
# (241, '178320', '서진시스템')
# (242, '183300', '코미코')
# (243, '246720', '아스타')
# (244, '145720', '덴티움')
# (245, '262830', '대신밸런스제4호스팩')
# (246, '217480', '에스디생명공학')
# (247, '002800', '신신제약')
# (248, '083500', '에프엔에스테크')
# (249, '087260', '모바일어플라이언스')
# (250, '257730', '신한제3호스팩')
# (251, '241820', '피씨엘')
# (252, '111110', '호전실업')
# (253, '140070', '서플러스글로벌')
# (254, '206650', '유바이오로직스')
# (255, '205290', '케미메디')
# (256, '260970', '에스앤디')
# (257, '256840', '엔에이치스팩11호')
# (258, '227420', '오백볼트')
# (259, '120780', '전우정밀')
# (260, '242350', '피엔아이컴퍼니')
# (261, '195440', '퓨전데이타')
# (262, '241520', 'DSC인베스트먼트')
# (263, '246690', '티에스인베스트먼트')
# (264, '258250', '셀젠텍')
# (265, '147760', '마이크로프랜드')
# (266, '204990', '현성바이탈')
# (267, '199290', '바이오프로테크')
# (268, '196300', '애니젠')
# (269, '203450', '유니온커뮤니티')
# (270, '215600', '신라젠')
# (271, '254120', 'IBKS제5호스팩')
# (272, '143210', '핸즈코퍼레이션')
# (273, '241790', '오션브릿지')
# (274, '220100', '퓨쳐켐')
# (275, '144960', '뉴파워프라즈마')
# (276, '156100', '엘앤케이바이오')
# (277, '258540', '스템랩')
# (278, '232830', '시큐센')
# (279, '176440', '에이치엔티')
# (280, '220180', '핸디소프트')
# (281, '241560', '두산밥캣')
# (282, '232330', 'SK3호스팩')
# (283, '148780', '비플라이소프트')
# (284, '253840', '수젠텍')
# (285, '207940', '삼성바이오로직스')
# (286, '237880', '클리오')
# (287, '900300', '오가닉티코스메틱')
# (288, '238120', '로고스바이오')
# (289, '252500', '세화피앤씨')
# (290, '243870', '굿센')
# (291, '216050', '인크로스')
# (292, '239610', '에이치엘사이언스')
# (293, '241710', '코스메카코리아')
# (294, '234080', 'JW생명과학')
# (295, '900290', 'GRT')
# (296, '251280', '안지오랩')
# (297, '900280', '골든센츄리')
# (298, '189300', '인텔리안테크')
# (299, '072990', '에이치시티')
# (300, '950140', '잉글우드랩')
# (301, '238090', '앤디포스')
# (302, '050960', '수산아이앤티')
# (303, '201490', '미투온')
# (304, '241590', '화승엔터프라이즈')
# (305, '252370', '유쎌')
# (306, '250930', '케이비제10호스팩')
# (307, '229640', 'LS전선아시아')
# (308, '204210', '모두투어리츠')
# (309, '241690', '유니테크노')
# (310, '250060', '모비스')
# (311, '251960', '엠에프엠코리아')
# (312, '242040', '나무기술')
# (313, '234920', '자이글')
# (314, '249420', '일동제약')
# (315, '900270', '헝셩그룹')
# (316, '239890', '피엔에이치테크')
# (317, '250300', '제이에스피브이')
# (318, '248170', '샘표식품')
# (319, '230360', '에코마케팅')
# (320, '191600', '티케이씨')
# (321, '038160', '팍스넷')
# (322, '016740', '두올')
# (323, '208860', '엔지스테크널러지')
# (324, '073560', '우리손에프앤지')
# (325, '212310', '휴벡셀')
# (326, '224020', '에스케이씨에스')
# (327, '123010', '옵토팩')
# (328, '228760', '지노믹트리')
# (329, '066830', '제노텍')
# (330, '026960', '동서')
# (331, '174880', '장원테크')
# (332, '071460', '대유위니아')
# (333, '123890', '한국자산신탁')
# (334, '034830', '한국토지신탁')
# (335, '247300', '인프라웨어테크놀러지')
# (336, '142760', '바이오리더스')
# (337, '237750', '피앤씨테크')
# (338, '900260', '로스웰')
# (339, '246250', '에스엘에스바이오')
# (340, '245450', '씨앤에스링크')
# (341, '195870', '해성디에스')
# (342, '144510', '녹십자랩셀')
# (343, '237690', '에스티팜')
# (344, '148250', '알엔투테크놀로지')
# (345, '208850', '이비테크')
# (346, '240540', '한국4호스팩')
# (347, '229480', '줌인터넷')
# (348, '239340', '미래에셋제5호스팩')
# (349, '245030', '스페이스솔루션')
# (350, '243070', '휴온스')
# (351, '244880', '나눔테크')
# (352, '112190', 'KC산업')
# (353, '070960', '용평리조트')
# (354, '242850', '영현무역')
# (355, '101530', '해태제과식품')
# (356, '240810', '원익IPS')
# (357, '058970', '엠로')
# (358, '241510', '이에스산업')
# (359, '240340', '인터코스')
# (360, '238500', '로보쓰리')
# (361, '228850', '레이언스')
# (362, '225330', '씨엠에스에듀')
# (363, '228340', '동양파일')
# (364, '004440', '대림씨엔에스')
# (365, '222110', '팬젠')
# (366, '222160', '바이옵트로')
# (367, '211270', 'AP위성')
# (368, '230980', '솔트웍스')
# (369, '115180', '큐리언트')
# (370, '065660', '안트로젠')
# (371, '236200', '슈프리마')
# (372, '194370', '제이에스코퍼레이션')
# (373, '226350', '아이엠텍')
# (374, '142210', '유니트론텍')
# (375, '900250', '크리스탈신소재')
# (376, '221610', '한솔씨앤피')
# (377, '236340', '메디젠휴먼케어')
# (378, '067370', '선바이오')
# (379, '206950', '볼빅')
# (380, '232530', '이엠티')
# (381, '109610', '에스와이패널')
# (382, '233990', '질경이')
# (383, '224060', '코디엠')
# (384, '152330', '코리아오토글라스')
# (385, '226320', '잇츠한불')
# (386, '135160', '지오씨')
# (387, '215570', '크로넥스')
# (388, '232140', '와이아이케이')
# (389, '191410', '육일씨엔에쓰')
# (390, '223310', '이에스브이')
# (391, '145020', '휴젤')
# (392, '222980', '한국맥널티')
# (393, '206560', '덱스터')
# (394, '013310', '아진산업')
# (395, '217730', '강스템바이오텍')
# (396, '047920', '씨트리')
# (397, '234070', '에이원알폼')
# (398, '133750', '메가엠디')
# (399, '226610', '한국비엔씨')
# (400, '225530', '보광산업')
# (401, '140860', '파크시스템스')
# (402, '222040', '뉴트리바이오텍')
# (403, '230240', '에치에프알')
# (404, '122640', '예스티')
# (405, '232680', '라온테크')
# (406, '058110', '멕아이씨에스')
# (407, '044990', '에이치엔에스하이텍')
# (408, '225850', '미애부')
# (409, '217820', '엔에스')
# (410, '213090', '미래테크놀로지')
# (411, '075580', '세진중공업')
# (412, '221840', '하이즈항공')
# (413, '197210', '리드')
# (414, '180400', '캔서롭')
# (415, '127160', '매직마이크로')
# (416, '221980', '케이디켐')
# (417, '212560', '네오오토')
# (418, '227950', '마이크로텍')
# (419, '230400', '자비스')
# (420, '214370', '케어젠')
# (421, '185490', '아이진')
# (422, '211050', '인카금융서비스')
# (423, '190510', '나무가')
# (424, '056090', '유앤아이')
# (425, '214330', '금호에이치티')
# (426, '089590', '제주항공')
# (427, '226340', '본느')
# (428, '217950', '파마리서치바이오')
# (429, '192080', '더블유게임즈')
# (430, '115960', '연우')
# (431, '092590', '럭스피아')
# (432, '229500', '노브메타파마')
# (433, '229000', '젠큐릭스')
# (434, '182400', '에이티젠')
# (435, '227840', '현대코퍼레이션홀딩스')
# (436, '092870', '엑시콘')
# (437, '226360', '이엑스티')
# (438, '228180', '티씨엠생명과학')
# (439, '224810', '엄지하우스')
# (440, '200580', '메디쎄이')
# (441, '214870', '에치디프로')
# (442, '225430', '케이엠제약')
# (443, '226440', '한송네오텍')
# (444, '225590', '패션플랫폼')
# (445, '079550', 'LIG넥스원')
# (446, '225570', '넷게임즈')
# (447, '217190', '제너셈')
# (448, '219130', '타이거일렉')
# (449, '039570', 'HDC아이콘트롤스')
# (450, '002690', '동일제강')
# (451, '175140', '인포마크')
# (452, '220250', '카이노스메드')
# (453, '225650', '쿠첸')
# (454, '222080', '씨아이에스')
# (455, '220630', '해마로푸드서비스')
# (456, '224110', '에이텍티앤')
# (457, '196700', '웹스')
# (458, '095570', 'AJ네트웍스')
# (459, '131760', '파인텍')
# (460, '222810', '한류에이아이센터')
# (461, '222800', '심텍')
# (462, '189980', '흥국에프엔비')
# (463, '222420', '쎄노텍')
# (464, '094360', '칩스앤미디어')
# (465, '225220', '제놀루션')
# (466, '127710', '아시아경제')
# (467, '224760', '엔에스컴퍼니')
# (468, '214430', '아이쓰리시스템')
# (469, '067730', '로지시스')
# (470, '222670', '플럼라인생명과학')
# (471, '220260', '켐트로스')
# (472, '214450', '파마리서치프로덕트')
# (473, '219550', 'MP한강')
# (474, '087010', '펩트론')
# (475, '214320', '이노션')
# (476, '214420', '토니모리')
# (477, '086220', '네추럴FNP')
# (478, '223220', '아이피몬스터')
# (479, '085620', '미래에셋생명')
# (480, '218410', 'RFHIC')
# (481, '094170', '동운아나텍')
# (482, '214180', '민앤지')
# (483, '178780', '유테크')
# (484, '214390', '경보제약')
# (485, '216400', '바이오코아')
# (486, '221800', '유투바이오')
# (487, '160600', '에스엔텍')
# (488, '217600', '켐온')
# (489, '166480', '코아스템')
# (490, '214310', '세미콘라이트')
# (491, '220110', '드림티엔터테인먼트')
# (492, '210980', 'SK디앤디')
# (493, '214610', '미코바이오메드')
# (494, '103660', '씨앗')
# (495, '177350', '베셀')
# (496, '217270', '넵튠')
# (497, '218150', '미래생명자원')
# (498, '160980', '싸이맥스')
# (499, '217500', '러셀')
# (500, '087600', '픽셀플러스')
# (501, '217620', '디딤')
# (502, '187420', '제노포커스')
# (503, '217880', '틸론')
# (504, '076340', '관악산업')
# (505, '215380', '우정바이오')
# (506, '215480', '토박스코리아')
# (507, '215790', '이노인스트루먼트')
# (508, '215360', '우리산업')
# (509, '215200', '메가스터디교육')
# (510, '217320', '썬테크')
# (511, '216280', '원텍')
# (512, '215090', '한컴유니맥스')
# (513, '215100', '로보로보')
# (514, '214680', '디알텍')
# (515, '195990', '유지인트')
# (516, '215000', '골프존')
# (517, '214150', '클래시스')
# (518, '215050', '비엔디생활건강')
# (519, '138250', '엔에스쇼핑')
# (520, '214270', '퓨쳐스트림네트웍스')
# (521, '145210', '세화아이엠씨')
# (522, '189690', '포시에스')
# (523, '213420', '덕산네오룩스')
# (524, '213500', '한솔제지')
# (525, '210540', '디와이파워')
# (526, '060480', '국일신동')
# (527, '176750', '듀켐바이오')
# (528, '206640', '바디텍메드')
# (529, '208640', '썸에이지')
# (530, '193250', '와이제이엠게임즈')
# (531, '204630', '화이브라더스코리아')
# (532, '200470', '하이셈')
# (533, '200670', '휴메딕스')
# (534, '200350', '래몽래인')
# (535, '208710', '바이오로그디바이스')
# (536, '189860', '서전기전')
# (537, '067390', '아스트')
# (538, '080580', '오킨스전자')
# (539, '208350', '지란지교시큐리티')
# (540, '160550', 'NEW')
# (541, '124500', '아이티센')
# (542, '028260', '삼성물산')
# (543, '210610', '소프트캠프')
# (544, '208890', '에듀파트너')
# (545, '142280', '녹십자엠에스')
# (546, '187220', '디티앤씨')
# (547, '135270', '세종머티리얼즈')
# (548, '208370', '셀바스헬스케어')
# (549, '208140', '정다운')
# (550, '149980', '하이로닉')
# (551, '084650', '랩지노믹스')
# (552, '210120', '빅텐츠')
# (553, '200710', '에이디테크놀로지')
# (554, '200780', '비씨월드제약')
# (555, '207760', '미스터블루')
# (556, '196170', '알테오젠')
# (557, '206400', '엔터메이트')
# (558, '178920', 'SKC코오롱PI')
# (559, '140520', '대창스틸')
# (560, '150440', '피노텍')
# (561, '173940', '에프엔씨엔터')
# (562, '205470', '휴마시스')
# (563, '112610', '씨에스윈드')
# (564, '200230', '텔콘RF제약')
# (565, '194510', '파티게임즈')
# (566, '204840', '지엘팜텍')
# (567, '204620', '글로벌텍스프리')
# (568, '196490', '디에이테크놀로지')
# (569, '000030', '우리은행')
# (570, '018260', '삼성에스디에스')
# (571, '149010', '아이케이세미콘')
# (572, '205500', '액션스퀘어')
# (573, '205100', '엑셈')
# (574, '191420', '테고사이언스')
# (575, '192440', '슈피겐코리아')
# (576, '182690', '테라셈')
# (577, '143540', '영우디에스피')
# (578, '121060', '유니포인트')
# (579, '203650', '드림시큐리티')
# (580, '041920', '메디아나')
# (581, '194480', '데브시스터즈')
# (582, '204320', '만도')
# (583, '203690', '프로스테믹스')
# (584, '192410', '감마누')
# (585, '198440', '고려시멘트')
# (586, '202960', '판도라티비')
# (587, '200880', '서연이화')
# (588, '187270', '신화콘텍')
# (589, '192400', '쿠쿠홀딩스')
# (590, '177830', '파버나인')
# (591, '090410', '덕신하우징')
# (592, '004650', '창해에탄올')
# (593, '192390', '윈하이텍')
# (594, '059120', '아진엑스텍')
# (595, '200130', '콜마비앤에이치')
# (596, '133820', '화인베스틸')
# (597, '203400', '에이비온')
# (598, '105550', '트루윈')
# (599, '136660', '큐엠씨')
# (600, '199150', '데이터스트림즈')
# (601, '199800', '툴젠')
# (602, '196450', '텔루스')
# (603, '071850', '캐스텍코리아')
# (604, '027410', 'BGF')
# (605, '187790', '나노')
# (606, '192250', '케이사인')
# (607, '192820', '코스맥스')
# (608, '138080', '오이솔루션')
# (609, '108790', '인터파크')
# (610, '053300', '한국정보인증')
# (611, '084440', '유비온')
# (612, '154040', '솔루에타')
# (613, '090850', '이지웰페어')
# (614, '140660', '위월드')
# (615, '189330', '씨이랩')
# (616, '189540', '씨티네트웍스')
# (617, '189350', '코셋')
# (618, '184230', 'SGA솔루션즈')
# (619, '186230', '그린플러스')
# (620, '178600', '대동고려삼')
# (621, '140290', '청광종건')
# (622, '049080', '기가레인')
# (623, '150840', '인트로메딕')
# (624, '107640', '한중엔시에스')
# (625, '085810', '알티캐스트')
# (626, '185750', '종근당')
# (627, '170030', '현대공업')
# (628, '067570', '엔브이에이치코리아')
# (629, '134580', '디엠티')
# (630, '006880', '신송홀딩스')
# (631, '182360', '큐브엔터')
# (632, '171120', '라이온켐텍')
# (633, '171010', '램테크놀러지')
# (634, '161570', 'THE MIDONG')
# (635, '183410', '골프존데카')
# (636, '138360', '에이씨티')
# (637, '183190', '아세아시멘트')
# (638, '076610', '해성옵틱스')
# (639, '168330', '내츄럴엔도텍')
# (640, '064350', '현대로템')
# (641, '185190', '수프로')
# (642, '131970', '테스나')
# (643, '150900', '파수닷컴')
# (644, '183350', '엘피케이')
# (645, '170920', '엘티씨')
# (646, '119850', '지엔씨에너지')
# (647, '180640', '한진칼')
# (648, '092040', '아미코젠')
# (649, '181710', 'NHN엔터테인먼트')
# (650, '130500', 'GH신소재')
# (651, '170790', '파이오링크')
# (652, '151860', 'KG ETS')
# (653, '175330', 'JB금융지주')
# (654, '089600', '나스미디어')
# (655, '172580', '하이골드12호')
# (656, '114920', '대주이엔티')
# (657, '126340', '비나텍')
# (658, '158300', '에스에이티이엔지')
# (659, '086460', '에스엔피제네틱스')
# (660, '064850', '에프앤가이드')
# (661, '179720', '옐로페이')
# (662, '101360', '이엔드디')
# (663, '116100', '태양기계')
# (664, '950130', '엑세스바이오')
# (665, '155660', 'DSR')
# (666, '141080', '레고켐바이오')
# (667, '168490', '한국패러랠')
# (668, '170900', '동아에스티')
# (669, '158310', '인터불스')
# (670, '097800', '윈팩')
# (671, '104540', '코렌텍')
# (672, '159580', '제로투세븐')
# (673, '114810', '아이원스')
# (674, '153490', '우리이앤엘')
# (675, '099190', '아이센스')
# (676, '141020', '포티스')
# (677, '159910', '스킨앤스킨')
# (678, '950110', 'SBI핀테크솔루션즈')
# (679, '046970', '우리로')
# (680, '113810', '디젠스')
# (681, '013870', '지엠비코리아')
# (682, '141070', '맥스로텍')
# (683, '155650', '와이엠씨')
# (684, '037560', 'CJ헬로')
# (685, '149950', '아바텍')
# (686, '163560', '동일고무벨트')
# (687, '161890', '한국콜마')
# (688, '161390', '한국타이어')
# (689, '121850', '코이즈')
# (690, '149940', '모다')
# (691, '161000', '애경유화')
# (692, '159650', '하이골드8호')
# (693, '151910', '나노스')
# (694, '068400', 'AJ렌터카')
# (695, '097520', '엠씨넥스')
# (696, '153460', '네이블커뮤니케이션즈')
# (697, '106520', '디지탈옵틱')
# (698, '137400', '피엔티')
# (699, '155900', '바다로19호')
# (700, '014710', '사조씨푸드')
# (701, '141000', '비아트론')
# (702, '153360', '하이골드3호')
# (703, '144620', '코오롱머티리얼')
# (704, '072950', '빛샘전자')
# (705, '152550', '한국ANKOR유전')
# (706, '079980', '휴비스')
# (707, '143240', '사람인에이치알')
# (708, '126870', '뉴로스')
# (709, '147830', '제룡산업')
# (710, '091590', '남화토건')
# (711, '145270', '케이탑리츠')
# (712, '140410', '메지온')
# (713, '104830', '원익머트리얼즈')
# (714, '127120', '디엔에이링크')
# (715, '007070', 'GS리테일')
# (716, '130580', '나이스디앤비')
# (717, '131090', '시큐브')
# (718, '100660', '서암기계공업')
# (719, '129260', '인터지스')
# (720, '115480', '씨유메디칼')
# (721, '123260', 'STC')
# (722, '145990', '삼양사')
# (723, '139670', '넥스트리밍')
# (724, '121800', '비덴트')
# (725, '112240', '에스에프씨')
# (726, '138070', '신진에스엠')
# (727, '123570', '이엠넷')
# (728, '122870', '와이지엔터테인먼트')
# (729, '136510', '쎄미시스코')
# (730, '089530', '에이티세미콘')
# (731, '089030', '테크윙')
# (732, '101240', '씨큐브')
# (733, '007820', '에스엠코어')
# (734, '115530', '씨엔플러스')
# (735, '123100', '원익테라세미콘')
# (736, '039130', '하나투어')
# (737, '043290', '케이맥')
# (738, '090360', '로보스타')
# (739, '131220', '대한과학')
# (740, '140890', '트러스제7호')
# (741, '131390', '피앤이솔루션')
# (742, '143160', '아이디스')
# (743, '078520', '에이블씨엔씨')
# (744, '134780', '화진')
# (745, '137950', '제이씨케미칼')
# (746, '040910', '아이씨디')
# (747, '123330', '제닉')
# (748, '139050', '데일리블록체인')
# (749, '023000', '삼원강재')
# (750, '089980', '상아프론테크')
# (751, '031430', '신세계인터내셔날')
# (752, '140910', '에이리츠')
# (753, '138610', '나이벡')
# (754, '109080', '옵티시스')
# (755, '108380', '대양전기공업')
# (756, '047810', '한국항공우주')
# (757, '071840', '롯데하이마트')
# (758, '019770', '서연탑메탈')
# (759, '069640', '한세엠케이')
# (760, '138490', '코오롱플라스틱')
# (761, '137940', '넥스트아이')
# (762, '131100', '리켐')
# (763, '139480', '이마트')
# (764, '139130', 'DGB금융지주')
# (765, '053210', '케이티스카이라이프')
# (766, '138690', '엘아이에스')
# (767, '019440', '세아특수강')
# (768, '122450', 'KMH')
# (769, '121440', '골프존뉴딘홀딩스')
# (770, '138040', '메리츠금융지주')
# (771, '136540', '윈스')
# (772, '136480', '하림')
# (773, '023350', '한국종합기술')
# (774, '134060', '이퓨쳐')
# (775, '104480', '티케이케미칼')
# (776, '138930', 'BNK금융지주')
# (777, '020150', '일진머티리얼즈')
# (778, '008470', '부스타')
# (779, '011210', '현대위아')
# (780, '136490', '선진')
# (781, '134380', '미원화학')
# (782, '121600', '나노신소재')
# (783, '093320', '케이아이엔엑스')
# (784, '130740', '티피씨글로벌')
# (785, '131180', '딜리')
# (786, '061970', '엘비세미콘')
# (787, '126880', '제이엔케이히터')
# (788, '033560', '블루콤')
# (789, '048530', '인트론바이오')
# (790, '134790', '시디즈')
# (791, '119860', '다나와')
# (792, '131370', '알서포트')
# (793, '064290', '인텍플러스')
# (794, '131290', '티에스이')
# (795, '082740', 'HSD엔진')
# (796, '131400', '액트')
# (797, '117580', '대성에너지')
# (798, '126560', '현대에이치씨엔')
# (799, '120240', '대정화금')
# (800, '058860', '케이티스')
# (801, '130660', '한전산업')
# (802, '128660', '피제이메탈')
# (803, '131030', '디에이치피코리아')
# (804, '096690', '제이스테판')
# (805, '900140', '엘브이엠씨')
# (806, '033830', '티비씨')
# (807, '033170', '시그네틱스')
# (808, '122800', '썬텍')
# (809, '041460', '한국전자인증')
# (810, '105740', '디케이락')
# (811, '126600', '코프라')
# (812, '123420', '선데이토즈')
# (813, '111870', '삼본정밀전자')
# (814, '123860', '아나패스')
# (815, '058400', 'KNN')
# (816, '030790', '동양네트웍스')
# (817, '069140', '누리플랜')
# (818, '119830', '아이텍반도체')
# (819, '101930', '인화정공')
# (820, '078650', '코렌')
# (821, '068940', '아이씨케이')
# (822, '123840', '한일진공')
# (823, '081660', '휠라코리아')
# (824, '117670', '알파홀딩스')
# (825, '119500', '포메탈')
# (826, '058850', 'KTcs')
# (827, '068240', '다원시스')
# (828, '057050', '현대홈쇼핑')
# (829, '096530', '씨젠')
# (830, '122990', '와이솔')
# (831, '126700', '하이비젼시스템')
# (832, '126640', '화신정공')
# (833, '123410', '코리아에프티')
# (834, '002150', '도화엔지니어링')
# (835, '123040', '엠에스오토텍')
# (836, '067920', '이글루시큐리티')
# (837, '128820', '대성산업')
# (838, '122900', '아이마켓코리아')
# (839, '128940', '한미약품')
# (840, '119610', '인터로조')
# (841, '106190', '하이텍팜')
# (842, '105840', '우진')
# (843, '114120', '크루셜텍')
# (844, '033920', '무학')
# (845, '121890', '에스디시스템')
# (846, '123750', '알톤스포츠')
# (847, '103130', '웅진에너지')
# (848, '089850', '유비벨록스')
# (849, '111820', '지와이커머스')
# (850, '046120', '오르비텍')
# (851, '102460', '이연제약')
# (852, '070300', '한솔시큐어')
# (853, '108320', '실리콘웍스')
# (854, '079970', '투비소프트')
# (855, '123690', '한국화장품')
# (856, '123700', '에스제이엠')
# (857, '071200', '인피니트헬스케어')
# (858, '100030', '모바일리더')
# (859, '122690', '서진오토모티브')
# (860, '060980', '한라홀딩스')
# (861, '032830', '삼성생명')
# (862, '031440', '신세계푸드')
# (863, '900110', '이스트아시아홀딩스')
# (864, '900100', '뉴프라이드')
# (865, '115500', '케이씨에스')
# (866, '900120', '씨케이에이치')
# (867, '115450', '지트리비앤티')
# (868, '122350', '삼기오토모티브')
# (869, '088350', '한화생명')
# (870, '115610', '이미지스')
# (871, '120030', '조선선재')
# (872, '115310', '인포바인')
# (873, '106080', '지투하이소닉')
# (874, '900090', '차이나하오란')
# (875, '101330', '모베이스')
# (876, '114570', '지스마트글로벌')
# (877, '120110', '코오롱인더')
# (878, '119650', 'KC코트렐')
# (879, '071320', '지역난방공사')
# (880, '115390', '락앤락')
# (881, '115570', '스타플렉스')
# (882, '115440', '우리넷')
# (883, '050860', '아세아텍')
# (884, '012160', '영흥철강')
# (885, '114630', '우노앤컴퍼니')
# (886, '080530', '코디')
# (887, '118000', '우리들휴브레인')
# (888, '900070', '글로벌에스엠')
# (889, '099520', 'ITX엠투엠')
# (890, '114450', 'KPX생명과학')
# (891, '104460', '동양피엔에프')
# (892, '096640', '멜파스')
# (893, '112040', '위메이드')
# (894, '052690', '한전기술')
# (895, '108860', '셀바스AI')
# (896, '900080', '에스앤씨엔진그룹')
# (897, '088290', '이원컴포텍')
# (898, '114190', '웰크론강원')
# (899, '114090', 'GKL')
# (900, '115160', '휴맥스')
# (901, '109960', '에이프로젠 H&G')
# (902, '034730', 'SK')
# (903, '099410', '동방선기')
# (904, '101000', '디엠씨')
# (905, '109820', '진매트릭스')
# (906, '032560', '황금에스티')
# (907, '082920', '비츠로셀')
# (908, '000080', '하이트진로')
# (909, '042520', '한스바이오메드')
# (910, '082640', '동양생명')
# (911, '104200', 'NHN벅스')
# (912, '052860', '아이앤씨')
# (913, '047400', '유니온머티리얼')
# (914, '105330', '케이엔더블유')
# (915, '093240', '형지엘리트')
# (916, '109740', '디에스케이')
# (917, '095700', '제넥신')
# (918, '108230', '톱텍')
# (919, '100130', '동국S&C')
# (920, '103230', '에스앤더블류')
# (921, '039490', '키움증권')
# (922, '063080', '게임빌')
# (923, '111770', '영원무역')
# (924, '109860', '동일금속')
# (925, '033660', '아주캐피탈')
# (926, '053690', '한미글로벌')
# (927, '028100', '동아지질')
# (928, '102120', '어보브반도체')
# (929, '101730', '조이맥스')
# (930, '900040', '차이나그레이트')
# (931, '102710', '이엔에프테크놀로지')
# (932, '099440', '스맥')
# (933, '102210', '해덕파워웨이')
# (934, '099220', 'SDN')
# (935, '101680', '한국정밀기계')
# (936, '071970', 'STX중공업')
# (937, '010240', '흥국')
# (938, '101170', '우림기계')
# (939, '081150', '티플랙스')
# (940, '108670', 'LG하우시스')
# (941, '098660', '에스티오')
# (942, '071670', '에이테크솔루션')
# (943, '101490', '에스앤에스텍')
# (944, '100120', '뷰웍스')
# (945, '102940', '코오롱생명과학')
# (946, '101400', '엔시트론')
# (947, '105630', '한세실업')
# (948, '109070', '컨버즈')
# (949, '106240', '파인테크닉스')
# (950, '107590', '미원홀딩스')
# (951, '086890', '이수앱지스')
# (952, '104040', '대성파인텍')
# (953, '078070', '유비쿼스홀딩스')
# (954, '086900', '메디톡스')
# (955, '058630', '엠게임')
# (956, '059100', '아이컴포넌트')
# (957, '035420', 'NAVER')
# (958, '067630', '에이치엘비생명과학')
# (959, '092130', '이크레더블')
# (960, '026940', '부국철강')
# (961, '105560', 'KB금융')
# (962, '100700', '세운메디칼')
# (963, '104700', '한국철강')
# (964, '098120', '마이크로컨텍솔')
# (965, '083470', 'KJ프리텍')
# (966, '100090', '삼강엠앤티')
# (967, '103590', '일진전기')
# (968, '103140', '풍산')
# (969, '011070', 'LG이노텍')
# (970, '101390', '아이엠')
# (971, '076080', '웰크론한텍')
# (972, '101670', '코리아에스이')
# (973, '094840', '슈프리마에이치큐')
# (974, '017180', '명문제약')
# (975, '063170', '서울옥션')
# (976, '047560', '이스트소프트')
# (977, '100220', '비상교육')
# (978, '096240', '청담러닝')
# (979, '102260', '동성코퍼레이션')
# (980, '101160', '월덱스')
# (981, '099320', '쎄트렉아이')
# (982, '102280', '쌍방울')
# (983, '064480', '브리지텍')
# (984, '098460', '고영')
# (985, '067000', '조이시티')
# (986, '018620', '우진비앤지')
# (987, '095610', '테스')
# (988, '053280', '예스24')
# (989, '096870', '엘디티')
# (990, '032640', 'LG유플러스')
# (991, '059210', '메타바이오메드')
# (992, '097870', '효성오앤비')
# (993, '087730', '네패스신소재')
# (994, '101140', '아티스')
# (995, '020560', '아시아나항공')
# (996, '101060', 'SBS미디어홀딩스')
# (997, '100840', 'S&TC')
# (998, '100250', '진양홀딩스')
# (999, '091440', '텔레필드')
# (1000, '099340', '하나니켈1호')
# (1001, '099350', '하나니켈2호')
# (1002, '096040', '이트론')
# (1003, '085310', '엔케이')
# (1004, '097780', '에스맥')
# (1005, '096630', '에스코넥')
# (1006, '068330', '일신바이오')
# (1007, '093920', '서원인텍')
# (1008, '067010', '이씨에스')
# (1009, '096350', '대창솔루션')
# (1010, '051600', '한전KPS')
# (1011, '069920', '아이에스이커머스')
# (1012, '096610', '알에프세미')
# (1013, '092070', '디엔에프')
# (1014, '094820', '일진파워')
# (1015, '086670', '비엠티')
# (1016, '093230', '이아이디')
# (1017, '092440', '기신정기')
# (1018, '094190', '이엘케이')
# (1019, '095190', '이엠코리아')
# (1020, '044450', 'KSS해운')
# (1021, '094280', '효성 ITX')
# (1022, '092300', '현우산업')
# (1023, '033270', '유나이티드')
# (1024, '093640', '다믈멀티미디어')
# (1025, '092200', '디아이씨')
# (1026, '095910', '에스에너지')
# (1027, '081580', '성우전자')
# (1028, '073110', '엘엠에스')
# (1029, '094970', '제이엠티')
# (1030, '080520', '오디텍')
# (1031, '095340', 'ISC')
# (1032, '085910', '네오티스')
# (1033, '095500', '미래나노텍')
# (1034, '027580', '상보')
# (1035, '097950', 'CJ제일제당')
# (1036, '086040', '바이오톡스텍')
# (1037, '028670', '팬오션')
# (1038, '090740', '연이정보통신')
# (1039, '057540', '옴니시스템')
# (1040, '094940', '푸른기술')
# (1041, '095270', '웨이브일렉트로')
# (1042, '097230', '한진중공업')
# (1043, '093190', '빅솔론')
# (1044, '096760', 'JW홀딩스')
# (1045, '091340', 'S&K폴리텍')
# (1046, '096770', 'SK이노베이션')
# (1047, '072770', '네오디안테크놀로지')
# (1048, '094480', '갤럭시아컴즈')
# (1049, '086520', '에코프로')
# (1050, '065150', 'MP그룹')
# (1051, '078340', '컴투스')
# (1052, '095660', '네오위즈')
# (1053, '029780', '삼성카드')
# (1054, '092600', '넥스트칩')
# (1055, '069410', '엔텔스')
# (1056, '096300', '베트남개발1')
# (1057, '001780', '알루코')
# (1058, '093380', '풍강')
# (1059, '095720', '웅진씽크빅')
# (1060, '086450', '동국제약')
# (1061, '064820', '케이프')
# (1062, '091580', '상신이디피')
# (1063, '092460', '한라IMS')
# (1064, '073540', '에프알텍')
# (1065, '091120', '이엠텍')
# (1066, '094850', '참좋은여행')
# (1067, '094860', '코닉글로리')
# (1068, '094800', '맵스리얼티1')
# (1069, '078020', '이베스트투자증권')
# (1070, '093520', '매커스')
# (1071, '048260', '오스템임플란트')
# (1072, '091970', '나노캠텍')
# (1073, '092730', '네오팜')
# (1074, '090460', '비에이치')
# (1075, '039200', '오스코텍')
# (1076, '089010', '켐트로닉스')
# (1077, '090470', '제이스텍')
# (1078, '088130', '동아엘텍')
# (1079, '090370', '메타랩스')
# (1080, '093370', '후성')
# (1081, '084110', '휴온스글로벌')
# (1082, '089150', '케이씨티')
# (1083, '091700', '파트론')
# (1084, '090710', '디에스티로봇')
# (1085, '086390', '유니테스트')
# (1086, '093050', 'LF')
# (1087, '060540', '에스에이티')
# (1088, '066310', '큐에스아이')
# (1089, '067280', '멀티캠퍼스')
# (1090, '044380', '주연테크')
# (1091, '044820', '코스맥스비티아이')
# (1092, '086250', '화신테크')
# (1093, '089890', '코세스')
# (1094, '034590', '인천도시가스')
# (1095, '080470', '성창오토텍')
# (1096, '089140', '넥스턴')
# (1097, '089790', '제이티')
# (1098, '090150', '광진윈텍')
# (1099, '088390', '이녹스')
# (1100, '009770', '삼정펄프')
# (1101, '092220', 'KEC')
# (1102, '092230', 'KPX홀딩스')
# (1103, '089230', 'THE E&M')
# (1104, '043150', '바텍')
# (1105, '086960', '한컴MDS')
# (1106, '089470', 'HDC현대EP')
# (1107, '038060', '루멘스')
# (1108, '091090', '세원셀론텍')
# (1109, '083660', 'CSA 코스믹')
# (1110, '062860', '티엘아이')
# (1111, '063570', '한국전자금융')
# (1112, '086980', '쇼박스')
# (1113, '068050', '팬엔터테인먼트')
# (1114, '085370', '루트로닉')
# (1115, '039290', '인포뱅크')
# (1116, '090350', '노루페인트')
# (1117, '090430', '아모레퍼시픽')
# (1118, '078860', '아이오케이')
# (1119, '088910', '동우팜투테이블')
# (1120, '032350', '롯데관광개발')
# (1121, '054950', '제이브이엠')
# (1122, '090080', '평화산업')
# (1123, '049800', '우진플라임')
# (1124, '084730', '팅크웨어')
# (1125, '035510', '신세계I&C')
# (1126, '086060', '진바이오텍')
# (1127, '022220', '정산애강')
# (1128, '088790', '진도')
# (1129, '088800', '에이스테크')
# (1130, '088980', '맥쿼리인프라')
# (1131, '023530', '롯데쇼핑')
# (1132, '068760', '셀트리온제약')
# (1133, '083450', 'GST')
# (1134, '019990', '에너토크')
# (1135, '079370', '제우스')
# (1136, '046110', '한일네트웍스')
# (1137, '085670', '뉴프렉스')
# (1138, '084370', '유진테크')
# (1139, '083790', '크리스탈')
# (1140, '084990', '바이로메드')
# (1141, '064550', '바이오니아')
# (1142, '083640', '인콘')
# (1143, '085660', '차바이오텍')
# (1144, '086280', '현대글로비스')
# (1145, '078140', '대봉엘에스')
# (1146, '067900', '와이엔텍')
# (1147, '083550', '케이엠')
# (1148, '084870', '티비에이치글로벌')
# (1149, '084180', '수성')
# (1150, '086790', '하나금융지주')
# (1151, '050540', '한국코퍼레이션')
# (1152, '001560', '제일연마')
# (1153, '080420', '모다이노칩')
# (1154, '083650', '비에이치아이')
# (1155, '079190', 'EMW')
# (1156, '045890', 'GV')
# (1157, '079430', '현대리바트')
# (1158, '082800', '루미마이크로')
# (1159, '043910', '자연과환경')
# (1160, '079000', '와토스코리아')
# (1161, '084010', '대한제강')
# (1162, '041020', '인프라웨어')
# (1163, '078590', '두올산업')
# (1164, '038070', '서린바이오')
# (1165, '075180', '새론오토모티브')
# (1166, '083420', '그린케미칼')
# (1167, '079940', '가비아')
# (1168, '077360', '덕산하이메탈')
# (1169, '083930', '아바코')
# (1170, '067310', '하나마이크론')
# (1171, '082660', '삼우엠스')
# (1172, '083310', '엘오티베큠')
# (1173, '080010', '이상네트웍스')
# (1174, '083370', '동북아12호선박투자')
# (1175, '083380', '동북아13호선박투자')
# (1176, '084690', '대상홀딩스')
# (1177, '058220', '아리온')
# (1178, '071950', '코아스')
# (1179, '078160', '메디포스트')
# (1180, '082850', '우리이티아이')
# (1181, '080160', '모두투어')
# (1182, '084680', '이월드')
# (1183, '084670', '동양고속')
# (1184, '042700', '한미반도체')
# (1185, '078890', '가온미디어')
# (1186, '050890', '쏠리드')
# (1187, '004890', '동일산업')
# (1188, '082210', '옵트론텍')
# (1189, '082270', '젬백스')
# (1190, '075130', '플랜티넷')
# (1191, '080440', '에스제이케이')
# (1192, '010960', '삼호개발')
# (1193, '073240', '금호타이어')
# (1194, '073490', '이노와이어리스')
# (1195, '079950', '인베니아')
# (1196, '079960', '동양이엔피')
# (1197, '080220', '제주반도체')
# (1198, '079170', '한창산업')
# (1199, '079810', '디이엔티')
# (1200, '080000', '에스엔유')
# (1201, '052220', 'iMBC')
# (1202, '079650', '서산')
# (1203, '052900', 'KMH하이텍')
# (1204, '066910', '손오공')
# (1205, '049950', '미래컴퍼니')
# (1206, '052460', '아이크래프트')
# (1207, '079160', 'CJ CGV')
# (1208, '081000', '일진다이아')
# (1209, '072870', '메가스터디')
# (1210, '073010', '케이에스피')
# (1211, '046440', 'KG모빌리언스')
# (1212, '078600', '대주전자재료')
# (1213, '054450', '텔레칩스')
# (1214, '078150', 'HB테크놀러지')
# (1215, '067990', '도이치모터스')
# (1216, '014830', '유니드')
# (1217, '051360', '토비스')
# (1218, '072520', '케이디 네이쳐 엔 바이오')
# (1219, '041650', '상신브레이크')
# (1220, '078130', '국일제지')
# (1221, '068790', 'DMS')
# (1222, '079660', '사조해표')
# (1223, '023810', '인팩')
# (1224, '078940', '일경산업개발')
# (1225, '048870', '시너지이노베이션')
# (1226, '065350', '신성델타테크')
# (1227, '078930', 'GS')
# (1228, '077500', '유니퀘스트')
# (1229, '058730', '다스코')
# (1230, '039340', '한국경제TV')
# (1231, '034220', 'LG디스플레이')
# (1232, '064260', '다날')
# (1233, '078000', '텔코웨어')
# (1234, '011080', '형지I&C')
# (1235, '050090', '휘닉스소재')
# (1236, '029960', '코엔텍')
# (1237, '057030', '와이비엠넷')
# (1238, '065770', 'CS')
# (1239, '074430', '아미노로직스')
# (1240, '077280', '한컴지엠디')
# (1241, '066700', '테라젠이텍스')
# (1242, '066900', '디에이피')
# (1243, '078350', '한양디지텍')
# (1244, '077970', 'STX엔진')
# (1245, '075970', '동국알앤에스')
# (1246, '069540', '라이트론')
# (1247, '073190', '듀오백')
# (1248, '054090', '삼진엘앤디')
# (1249, '041910', '에스텍파마')
# (1250, '034310', 'NICE')
# (1251, '019680', '대교')
# (1252, '073070', '에스모')
# (1253, '039670', '스포츠서울')
# (1254, '067770', '세진티에스')
# (1255, '070590', '한솔인티큐브')
# (1256, '073640', '삼원테크')
# (1257, '073570', '피엠지파마')
# (1258, '065680', '우주일렉트로')
# (1259, '057880', '토필드')
# (1260, '024110', '기업은행')
# (1261, '074610', '나노메딕스')
# (1262, '066410', '버킷스튜디오')
# (1263, '060570', '아이리버')
# (1264, '067160', '아프리카TV')
# (1265, '074600', '원익QnC')
# (1266, '071280', '로체시스템즈')
# (1267, '041440', '에버다임')
# (1268, '069510', '에스텍')
# (1269, '067170', '오텍')
# (1270, '054780', '키이스트')
# (1271, '025750', '한솔홈데코')
# (1272, '072020', '중앙백신')
# (1273, '065510', '휴비츠')
# (1274, '072470', '우리산업홀딩스')
# (1275, '068930', '디지털대성')
# (1276, '069110', '코스온')
# (1277, '007660', '이수페타시스')
# (1278, '035250', '강원랜드')
# (1279, '069330', '유아이디')
# (1280, '064760', '티씨케이')
# (1281, '037270', 'YG PLUS')
# (1282, '052710', '아모텍')
# (1283, '072710', '농심홀딩스')
# (1284, '065950', '웰크론')
# (1285, '047310', '파워로직스')
# (1286, '071050', '한국금융지주')
# (1287, '056000', '신스타임즈')
# (1288, '041520', '이라이콤')
# (1289, '065560', '녹원씨엔아이')
# (1290, '072130', '유엔젤')
# (1291, '034120', 'SBS')
# (1292, '064240', '홈캐스트')
# (1293, '066790', '씨씨에스')
# (1294, '069080', '웹젠')
# (1295, '036570', '엔씨소프트')
# (1296, '071090', '하이스틸')
# (1297, '067080', '대화제약')
# (1298, '066590', '우수AMS')
# (1299, '067290', 'JW신약')
# (1300, '066130', '하츠')
# (1301, '046140', 'SBS콘텐츠허브')
# (1302, '065450', '빅텍')
# (1303, '065130', '탑엔지니어링')
# (1304, '069730', 'DSR제강')
# (1305, '065440', '이루온')
# (1306, '006890', '태경화학')
# (1307, '049630', '재영솔루텍')
# (1308, '021650', '한국큐빅')
# (1309, '051370', '인터플렉스')
# (1310, '065650', '메디프론')
# (1311, '065570', '삼영이엔씨')
# (1312, '066980', '브레인콘텐츠')
# (1313, '016100', '리더스코스메틱')
# (1314, '011500', '한농화성')
# (1315, '065940', '바이오빌')
# (1316, '042040', '케이피엠테크')
# (1317, '066970', '엘앤에프')
# (1318, '066670', '디스플레이텍')
# (1319, '066430', '와이오엠')
# (1320, '047820', '초록뱀')
# (1321, '064090', '에프앤리퍼블릭')
# (1322, '049960', '쎌바이오텍')
# (1323, '053290', 'NE능률')
# (1324, '064520', '바른전자')
# (1325, '069960', '현대백화점')
# (1326, '035600', 'KG이니시스')
# (1327, '065170', '넥스트BT')
# (1328, '069460', '대호에이엘')
# (1329, '034230', '파라다이스')
# (1330, '069620', '대웅제약')
# (1331, '041590', '에너전트')
# (1332, '027740', '마니커')
# (1333, '036530', 'S&T홀딩스')
# (1334, '069260', '휴켐스')
# (1335, '042600', '새로닉스')
# (1336, '033530', '세종공업')
# (1337, '065500', '오리엔트정공')
# (1338, '060900', '퍼시픽바이오')
# (1339, '066620', '국보디자인')
# (1340, '065420', '에스아이리소스')
# (1341, '052770', '와이디온라인')
# (1342, '064800', '필링크')
# (1343, '058430', '포스코강판')
# (1344, '039980', '리노스')
# (1345, '048410', '현대바이오')
# (1346, '068290', '삼성출판사')
# (1347, '065160', '에프티이앤이')
# (1348, '067830', '세이브존I&C')
# (1349, '058610', '에스피지')
# (1350, '045340', '토탈소프트')
# (1351, '030610', '교보증권')
# (1352, '065690', '대진디엠피')
# (1353, '065710', '서호전기')
# (1354, '009240', '한샘')
# (1355, '066110', '한프')
# (1356, '043710', '서울리거')
# (1357, '060560', '홈센타홀딩스')
# (1358, '036010', '아비코전자')
# (1359, '060280', '큐렉소')
# (1360, '065620', '제낙스')
# (1361, '060230', '이그잭스')
# (1362, '057680', '옴니텔')
# (1363, '046940', '우원개발')
# (1364, '034300', '신세계건설')
# (1365, '060150', '인선이엔티')
# (1366, '065530', '전파기지국')
# (1367, '063440', 'SM Life Design')
# (1368, '017370', '우신시스템')
# (1369, '051160', '지어소프트')
# (1370, '065060', '지엔코')
# (1371, '049180', '셀루메드')
# (1372, '060720', 'KH바텍')
# (1373, '061040', '알에프텍')
# (1374, '050760', '에스폴리텍')
# (1375, '054210', '이랜텍')
# (1376, '050120', '라이브플렉스')
# (1377, '054410', '케이피티유')
# (1378, '060310', '3S')
# (1379, '066570', 'LG전자')
# (1380, '061250', '화일약품')
# (1381, '053980', '오상자이엘')
# (1382, '024720', '한국콜마홀딩스')
# (1383, '054050', '농우바이오')
# (1384, '039420', '케이엘넷')
# (1385, '064960', 'S&T모티브')
# (1386, '039440', '에스티아이')
# (1387, '049550', '잉크테크')
# (1388, '054670', '대한뉴팜')
# (1389, '060590', '씨티씨바이오')
# (1390, '049070', '인탑스')
# (1391, '060370', 'KT서브마린')
# (1392, '051380', '피씨디렉트')
# (1393, '053660', '현진소재')
# (1394, '037710', '광주신세계')
# (1395, '053270', '구영테크')
# (1396, '034950', '한국기업평가')
# (1397, '060260', '뉴보텍')
# (1398, '060380', '동양에스텍')
# (1399, '046310', '백금T&A')
# (1400, '058530', '슈펙스비앤피')
# (1401, '049720', '고려신용정보')
# (1402, '052670', '제일바이오')
# (1403, '046890', '서울반도체')
# (1404, '013990', '아가방컴퍼니')
# (1405, '058450', '일야')
# (1406, '059090', '미코')
# (1407, '050320', '에이앤티앤')
# (1408, '054930', '유신')
# (1409, '035200', '프럼파스트')
# (1410, '054040', '한국컴퓨터')
# (1411, '048470', '대동스틸')
# (1412, '060300', '레드로버')
# (1413, '042500', '링네트')
# (1414, '058420', '제이웨이')
# (1415, '040350', '큐로컴')
# (1416, '054300', '팬스타엔터프라이즈')
# (1417, '054340', '피앤텔')
# (1418, '047080', '한빛소프트')
# (1419, '020760', '일진디스플')
# (1420, '060250', 'NHN한국사이버결제')
# (1421, '053260', '금강철강')
# (1422, '060240', '룽투코리아')
# (1423, '056730', '포스링크')
# (1424, '057500', 'SKC 솔믹스')
# (1425, '041930', '동아화성')
# (1426, '054220', '비츠로시스')
# (1427, '014940', '오리엔탈정공')
# (1428, '033180', '필룩스')
# (1429, '043590', '크로바하이텍')
# (1430, '058470', '리노공업')
# (1431, '045300', '성우테크론')
# (1432, '056190', '에스에프에이')
# (1433, '056700', '신화인터텍')
# (1434, '054940', '엑사이엔씨')
# (1435, '043370', '평화정공')
# (1436, '063160', '종근당바이오')
# (1437, '054620', 'APS홀딩스')
# (1438, '056360', '코위버')
# (1439, '043260', '성호전자')
# (1440, '038340', 'UCI')
# (1441, '051390', 'YW')
# (1442, '054540', '삼영엠텍')
# (1443, '053350', '이니텍')
# (1444, '054630', '에이디칩스')
# (1445, '056080', '유진로봇')
# (1446, '044490', '태웅')
# (1447, '053950', '경남제약')
# (1448, '053700', '삼보모터스')
# (1449, '003670', '포스코켐텍')
# (1450, '054920', '한컴시큐어')
# (1451, '041960', '코미팜')
# (1452, '053160', '프리엠스')
# (1453, '052400', '코나아이')
# (1454, '054180', '중앙오션')
# (1455, '049470', 'SGA')
# (1456, '053050', '지에스이')
# (1457, '043090', '팜스웰바이오')
# (1458, '053110', '소리바다')
# (1459, '054800', '아이디스홀딩스')
# (1460, '047770', '코데즈컴바인')
# (1461, '053800', '안랩')
# (1462, '055550', '신한지주')
# (1463, '040300', 'YTN')
# (1464, '058820', 'CMG제약')
# (1465, '035900', 'JYP Ent.')
# (1466, '053590', '한국테크놀로지')
# (1467, '021320', 'KCC건설')
# (1468, '053060', '세동')
# (1469, '053610', '프로텍')
# (1470, '052790', '액토즈소프트')
# (1471, '053450', '세코닉스')
# (1472, '053030', '바이넥스')
# (1473, '052420', '오성첨단소재')
# (1474, '021240', '코웨이')
# (1475, '053620', '태양')
# (1476, '052300', 'W홀딩컴퍼니')
# (1477, '049520', '유아이엘')
# (1478, '048910', '대원미디어')
# (1479, '051980', '중앙리빙테크')
# (1480, '058650', '세아홀딩스')
# (1481, '051500', 'CJ프레시웨이')
# (1482, '049120', '파인디앤씨')
# (1483, '043360', '디지아이')
# (1484, '052330', '코텍')
# (1485, '052600', '한네트')
# (1486, '052020', '에스티큐브')
# (1487, '043220', '에이치엘비파워')
# (1488, '033790', '스카이문스테크놀로지')
# (1489, '051780', '큐로홀딩스')
# (1490, '052190', '이에스에이')
# (1491, '051490', '나라엠앤디')
# (1492, '038870', '에코바이오')
# (1493, '045660', '에이텍')
# (1494, '052260', 'SK바이오랜드')
# (1495, '045390', '대아티아이')
# (1496, '050110', '캠시스')
# (1497, '036540', 'SFA반도체')
# (1498, '051900', 'LG생활건강')
# (1499, '051910', 'LG화학')
# (1500, '047040', '대우건설')
# (1501, '047050', '포스코대우')
# (1502, '042660', '대우조선해양')
# (1503, '042670', '두산인프라코어')
# (1504, '038500', '삼표시멘트')
# (1505, '051630', '진양화학')
# (1506, '048550', 'SM C&C')
# (1507, '049830', '승일')
# (1508, '044060', '조광ILI')
# (1509, '024850', '피에스엠씨')
# (1510, '048770', 'TPC')
# (1511, '049430', '코메론')
# (1512, '044480', '바이오제네틱스')
# (1513, '046390', '삼화네트웍스')
# (1514, '014620', '성광벤드')
# (1515, '048430', '유라테크')
# (1516, '017480', '삼현철강')
# (1517, '049480', '오픈베이스')
# (1518, '036670', 'KCI')
# (1519, '042510', '라온시큐어')
# (1520, '039830', '오로라')
# (1521, '036190', '금화피에스시')
# (1522, '046070', '코다코')
# (1523, '041830', '인바디')
# (1524, '014570', '고려제약')
# (1525, '045520', '크린앤사이언스')
# (1526, '022100', '포스코 ICT')
# (1527, '049770', '동원F&B')
# (1528, '033600', '에이코넬')
# (1529, '044180', 'KD건설')
# (1530, '044960', '이글벳')
# (1531, '032080', '아즈텍WB')
# (1532, '034020', '두산중공업')
# (1533, '010470', '오리콤')
# (1534, '044340', '위닉스')
# (1535, '042940', '상지카일룸')
# (1536, '010040', '한국내화')
# (1537, '048830', '엔피케이')
# (1538, '000250', '삼천당제약')
# (1539, '044780', '에이치케이')
# (1540, '045510', '정원엔시스')
# (1541, '045100', '한양이엔지')
# (1542, '040160', '누리텔레콤')
# (1543, '043340', '에쎈테크')
# (1544, '043650', '국순당')
# (1545, '037950', '엘컴텍')
# (1546, '039030', '이오테크닉스')
# (1547, '038540', '상상인')
# (1548, '018680', '서울제약')
# (1549, '039860', '나노엔텍')
# (1550, '046210', '파나진')
# (1551, '045060', '오공')
# (1552, '043100', '솔고바이오')
# (1553, '026180', '현대정보기술')
# (1554, '042370', '비츠로테크')
# (1555, '045970', '코아시아홀딩스')
# (1556, '040420', '정상제이엘에스')
# (1557, '007370', '진양제약')
# (1558, '041140', '넥슨지티')
# (1559, '043610', '지니뮤직')
# (1560, '036890', '진성티이씨')
# (1561, '039010', '현대통신')
# (1562, '009300', '삼아제약')
# (1563, '043200', '파루')
# (1564, '042110', '에스씨디')
# (1565, '039740', '한국정보공학')
# (1566, '039840', '디오')
# (1567, '042420', '네오위즈홀딩스')
# (1568, '039560', '다산네트웍스')
# (1569, '038460', '바이오스마트')
# (1570, '039230', '에이아이비트')
# (1571, '032820', '우리기술')
# (1572, '001540', '안국약품')
# (1573, '038530', '골드퍼시픽')
# (1574, '039310', '세중')
# (1575, '041190', '우리기술투자')
# (1576, '036640', 'HRS')
# (1577, '031330', '에스에이엠티')
# (1578, '030190', 'NICE평가정보')
# (1579, '038620', '위즈코프')
# (1580, '039020', '이건홀딩스')
# (1581, '038950', '파인디지털')
# (1582, '036800', '나이스정보통신')
# (1583, '040610', 'SG&G')
# (1584, '038880', '아이에이')
# (1585, '038680', '에스넷')
# (1586, '041510', '에스엠')
# (1587, '010280', '쌍용정보통신')
# (1588, '037760', '쎄니트')
# (1589, '036480', '대성미생물')
# (1590, '038110', '에코플라스틱')
# (1591, '036420', '제이콘텐트리')
# (1592, '032500', '케이엠더블유')
# (1593, '039610', '화성밸브')
# (1594, '039240', '경남스틸')
# (1595, '038290', '마크로젠')
# (1596, '037440', '희림')
# (1597, '038390', '레드캡투어')
# (1598, '028150', 'GS홈쇼핑')
# (1599, '036830', '솔브레인')
# (1600, '036810', '에프에스티')
# (1601, '036690', '코맥스')
# (1602, '037370', 'EG')
# (1603, '036620', '버추얼텍')
# (1604, '037350', '성도이엔지')
# (1605, '038010', '제일테크노스')
# (1606, '016450', '한세예스24홀딩스')
# (1607, '001810', '무림SP')
# (1608, '036630', '세종텔레콤')
# (1609, '036710', '심텍홀딩스')
# (1610, '037070', '파세코')
# (1611, '036560', '영풍정밀')
# (1612, '016250', '이테크건설')
# (1613, '036030', 'KTH')
# (1614, '035890', '서희건설')
# (1615, '036930', '주성엔지니어링')
# (1616, '016710', '대성홀딩스')
# (1617, '032190', '다우데이타')
# (1618, '005290', '동진쎄미켐')
# (1619, '003100', '선광')
# (1620, '036170', '씨티젠')
# (1621, '036180', '영인프런티어')
# (1622, '026040', '제이에스티나')
# (1623, '037230', '한국팩키지')
# (1624, '037460', '삼지전자')
# (1625, '037400', '우리조명')
# (1626, '003220', '대원제약')
# (1627, '036460', '한국가스공사')
# (1628, '036490', 'SK머티리얼즈')
# (1629, '033640', '네패스')
# (1630, '037330', '인지디스플레')
# (1631, '036090', '위지트')
# (1632, '036200', '유니셈')
# (1633, '024800', '유성티엔에스')
# (1634, '036260', '이매진아시아')
# (1635, '027050', '코리아나')
# (1636, '036120', 'SCI평가정보')
# (1637, '035290', '더블유에프엠')
# (1638, '027040', '서울전자통신')
# (1639, '027830', '대성창투')
# (1640, '036000', '예림당')
# (1641, '007120', '미래아이앤지')
# (1642, '035760', 'CJ ENM')
# (1643, '035810', '이지바이오')
# (1644, '035460', '기산텔레콤')
# (1645, '035480', '마제스타')
# (1646, '000850', '화천기공')
# (1647, '036580', '팜스코')
# (1648, '033780', '케이티앤지')
# (1649, '009540', '현대중공업')
# (1650, '024090', '디씨엠')
# (1651, '035620', '바른손이앤에이')
# (1652, '035610', '솔본')
# (1653, '020710', '시공테크')
# (1654, '012790', '신일제약')
# (1655, '034940', '조아제약')
# (1656, '006840', 'AK홀딩스')
# (1657, '006650', '대한유화')
# (1658, '035150', '백산')
# (1659, '035000', '지투알')
# (1660, '033250', '체시스')
# (1661, '033230', '인성정보')
# (1662, '035080', '인터파크홀딩스')
# (1663, '005160', '동국산업')
# (1664, '005990', '매일홀딩스')
# (1665, '034810', '해성산업')
# (1666, '033240', '자화전자')
# (1667, '030200', '케이티')
# (1668, '019490', '하이트론씨스템즈')
# (1669, '031390', '녹십자셀')
# (1670, '033430', '디에스티')
# (1671, '030000', '제일기획')
# (1672, '025770', '한국정보통신')
# (1673, '033540', '파라텍')
# (1674, '033500', '동성화인텍')
# (1675, '026890', '디피씨')
# (1676, '029460', '케이씨')
# (1677, '030350', '드래곤플라이')
# (1678, '033310', '디케이디앤아이')
# (1679, '033160', '엠케이전자')
# (1680, '033320', '제이씨현시스템')
# (1681, '009520', '포스코엠텍')
# (1682, '013810', '스페코')
# (1683, '033340', '좋은사람들')
# (1684, '024890', '대원화성')
# (1685, '033200', '모아텍')
# (1686, '033290', '코웰패션')
# (1687, '015710', '코콤')
# (1688, '017940', 'E1')
# (1689, '018670', 'SK가스')
# (1690, '023590', '다우기술')
# (1691, '014440', '영보화학')
# (1692, '033110', '이디')
# (1693, '033100', '제룡전기')
# (1694, '033050', '제이엠아이')
# (1695, '033130', '디지틀조선')
# (1696, '032980', '바이온')
# (1697, '019210', '와이지-원')
# (1698, '026150', '특수건설')
# (1699, '031310', '아이즈비전')
# (1700, '011790', 'SKC')
# (1701, '032960', '동일기연')
# (1702, '032680', '소프트센')
# (1703, '032940', '원익')
# (1704, '008290', '원풍물산')
# (1705, '010600', '웰바이오텍')
# (1706, '025890', '한국주강')
# (1707, '032750', '삼진')
# (1708, '032860', 'GMR 머티리얼즈')
# (1709, '032850', '비트컴퓨터')
# (1710, '032790', '엠젠플러스')
# (1711, '032800', '판타지오')
# (1712, '024900', '덕양산업')
# (1713, '015350', '부산도시가스')
# (1714, '023960', '에쓰씨엔지니어링')
# (1715, '023800', '인지컨트롤스')
# (1716, '032620', '유비케어')
# (1717, '032580', '피델릭스')
# (1718, '032540', 'TJ미디어')
# (1719, '028080', '휴맥스홀딩스')
# (1720, '032280', '삼일')
# (1721, '012320', '경동인베스트')
# (1722, '012340', '뉴인텍')
# (1723, '025530', '에스제이엠홀딩스')
# (1724, '031510', '오스템')
# (1725, '031820', '콤텍시스템')
# (1726, '030270', '에스마크')
# (1727, '031860', '엔에스엔')
# (1728, '031980', '피에스케이')
# (1729, '000660', 'SK하이닉스')
# (1730, '023150', 'MH에탄올')
# (1731, '005320', '국동')
# (1732, '023450', '동남합성')
# (1733, '028050', '삼성엔지니어링')
# (1734, '029530', '신도리코')
# (1735, '015360', '예스코홀딩스')
# (1736, '016800', '퍼시스')
# (1737, '011560', '세보엠이씨')
# (1738, '024740', '한일단조')
# (1739, '024070', 'WISCOM')
# (1740, '030720', '동원수산')
# (1741, '025560', '미래산업')
# (1742, '030210', 'KTB투자증권')
# (1743, '030960', '양지사')
# (1744, '012630', 'HDC')
# (1745, '017900', '광전자')
# (1746, '025540', '한국단자공업')
# (1747, '030530', '원익홀딩스')
# (1748, '030520', '한글과컴퓨터')
# (1749, '021880', '메이슨캐피탈')
# (1750, '021040', '대호피앤씨')
# (1751, '029480', '바른테크놀로지')
# (1752, '003160', '디아이')
# (1753, '011930', '신성이엔지')
# (1754, '019180', '티에이치엔')
# (1755, '018880', '한온시스템')
# (1756, '028040', '미래SCI')
# (1757, '028300', '에이치엘비')
# (1758, '027710', '팜스토리')
# (1759, '021820', '세원정공')
# (1760, '027970', '세하')
# (1761, '006740', '영풍제지')
# (1762, '000910', '유니온')
# (1763, '020120', '키다리스튜디오')
# (1764, '020000', '한섬')
# (1765, '017800', '현대엘리베이터')
# (1766, '016580', '환인제약')
# (1767, '023600', '삼보판지')
# (1768, '018310', '삼목에스폼')
# (1769, '003800', '에이스침대')
# (1770, '014190', '원익큐브')
# (1771, '013580', '계룡건설산업')
# (1772, '011160', '두산건설')
# (1773, '021050', '서원')
# (1774, '012750', '에스원')
# (1775, '015890', '태경산업')
# (1776, '027390', '한화갤러리아타임월드')
# (1777, '012700', '리드코프')
# (1778, '018000', '유니슨')
# (1779, '025980', '아난티')
# (1780, '026910', '광진실업')
# (1781, '017250', '인터엠')
# (1782, '016590', '신대양제지')
# (1783, '011690', '유양디앤유')
# (1784, '025860', '남해화학')
# (1785, '018500', '동원금속')
# (1786, '011300', '성안')
# (1787, '015750', '성우하이텍')
# (1788, '020180', '대신정보통신')
# (1789, '006730', '서부T&D')
# (1790, '012610', '경인양행')
# (1791, '017810', '풀무원')
# (1792, '011200', '현대상선')
# (1793, '017390', '서울도시가스')
# (1794, '025820', '이구산업')
# (1795, '025950', '동신건설')
# (1796, '025900', '동화기업')
# (1797, '011090', '에넥스')
# (1798, '007460', '에이프로젠 KIC')
# (1799, '025620', '제이준코스메틱')
# (1800, '017960', '한국카본')
# (1801, '025870', '신라에스지')
# (1802, '025880', '케이씨피드')
# (1803, '002680', '한탑')
# (1804, '025550', '한국선재')
# (1805, '025440', '대성엘텍')
# (1806, '025320', '시노펙스')
# (1807, '024940', 'PN풍년')
# (1808, '024950', '삼천리자전거')
# (1809, '014100', '보령메디앙스')
# (1810, '024840', '갑을메탈')
# (1811, '024910', '경창산업')
# (1812, '004780', '대륙제관')
# (1813, '013120', '동원개발')
# (1814, '024830', '세원물산')
# (1815, '024810', '이화전기')
# (1816, '024880', '케이피에프')
# (1817, '025000', 'KPX케미칼')
# (1818, '010580', '지코')
# (1819, '007980', '태평양물산')
# (1820, '024120', 'KB오토시스')
# (1821, '017000', '신원종합개발')
# (1822, '024060', '흥구석유')
# (1823, '023910', '대한약품')
# (1824, '023890', '아트라스BX')
# (1825, '001840', '이화공영')
# (1826, '023900', '풍국주정')
# (1827, '017650', '대림제지')
# (1828, '010170', '대한광통신')
# (1829, '023790', '동일철강')
# (1830, '023770', '플레이위드')
# (1831, '023760', '한국캐피탈')
# (1832, '005860', '한일사료')
# (1833, '009440', 'KC그린홀딩스')
# (1834, '008420', '문배철강')
# (1835, '016880', '웅진')
# (1836, '012860', '서연전자')
# (1837, '023460', 'CNH')
# (1838, '006050', '국영지앤엠')
# (1839, '023410', '유진기업')
# (1840, '023440', '제일제강')
# (1841, '006910', '보성파워텍')
# (1842, '018290', '지엠피')
# (1843, '023160', '태광')
# (1844, '007310', '오뚜기')
# (1845, '008500', '일정실업')
# (1846, '014790', '한라')
# (1847, '007530', '영신금속')
# (1848, '010120', 'LS산전')
# (1849, '001000', '신라섬유')
# (1850, '012620', '원일특강')
# (1851, '011370', '서한')
# (1852, '009190', '대양금속')
# (1853, '000760', '이화산업')
# (1854, '014820', '동원시스템즈')
# (1855, '018700', '바른손')
# (1856, '014470', '부방')
# (1857, '010140', '삼성중공업')
# (1858, '009680', '모토닉')
# (1859, '010690', '화신')
# (1860, '007720', '대명코퍼레이션')
# (1861, '006580', '대양제지')
# (1862, '011320', '유니크')
# (1863, '018120', '진로발효')
# (1864, '013720', '청보산업')
# (1865, '009620', '삼보산업')
# (1866, '005670', '푸드웰')
# (1867, '007330', '푸른저축은행')
# (1868, '006140', '피제이전자')
# (1869, '019010', '그랜드백화점')
# (1870, '009780', '엠에스씨')
# (1871, '000390', '삼화페인트공업')
# (1872, '017680', '데코앤이')
# (1873, '008800', '행남사')
# (1874, '009450', '경동나비엔')
# (1875, '020400', '대동금속')
# (1876, '014200', '광림')
# (1877, '005710', '대원산업')
# (1878, '016600', '큐캐피탈')
# (1879, '004590', '한국가구')
# (1880, '016670', '포비스티앤씨')
# (1881, '000440', '중앙에너비스')
# (1882, '012030', 'DB')
# (1883, '005090', '삼광글라스')
# (1884, '014970', '삼륭물산')
# (1885, '005750', '대림비앤코')
# (1886, '011040', '경동제약')
# (1887, '008370', '원풍')
# (1888, '007390', '네이처셀')
# (1889, '002290', '삼일기업공사')
# (1890, '019540', '일지테크')
# (1891, '007770', '한일화학')
# (1892, '017890', '한국알콜')
# (1893, '003310', '대주산업')
# (1894, '019660', '글로본')
# (1895, '005880', '대한해운')
# (1896, '008560', '메리츠종금증권')
# (1897, '017510', '세명전기')
# (1898, '005870', '휴니드테크놀러지스')
# (1899, '017550', '수산중공업')
# (1900, '021080', '에이티넘인베스트')
# (1901, '011170', '롯데케미칼')
# (1902, '008830', '대동기어')
# (1903, '001430', '세아베스틸')
# (1904, '008770', '호텔신라')
# (1905, '014580', '백광소재')
# (1906, '013520', '화승알앤에이')
# (1907, '004080', '신흥')
# (1908, '006060', '화승인더스트리')
# (1909, '014530', '극동유화')
# (1910, '002140', '고려산업')
# (1911, '002230', '피에스텍')
# (1912, '016090', '대현')
# (1913, '001620', '동국실업')
# (1914, '017040', '광명전기')
# (1915, '011390', '부산산업')
# (1916, '011810', 'STX')
# (1917, '010130', '고려아연')
# (1918, '009730', '코센')
# (1919, '012600', '청호컴넷')
# (1920, '004720', '우리들제약')
# (1921, '009200', '무림페이퍼')
# (1922, '001500', '현대차증권')
# (1923, '008870', '금비')
# (1924, '008110', '대동전자')
# (1925, '005820', '원림')
# (1926, '008490', '서흥')
# (1927, '014910', '성문전자')
# (1928, '003580', '넥스트사이언스')
# (1929, '015860', '일진홀딩스')
# (1930, '014160', '대영포장')
# (1931, '012280', '영화금속')
# (1932, '019170', '신풍제약')
# (1933, '002210', '동성제약')
# (1934, '016920', '카스')
# (1935, '012170', '키위미디어그룹')
# (1936, '009420', '한올바이오파마')
# (1937, '013030', '하이록코리아')
# (1938, '011330', '유니켐')
# (1939, '012800', '대창')
# (1940, '001140', '국보')
# (1941, '013360', '일성건설')
# (1942, '013700', '까뮤이앤씨')
# (1943, '002760', '보락')
# (1944, '007610', '선도전기')
# (1945, '004920', '씨아이테크')
# (1946, '009290', '광동제약')
# (1947, '011420', '갤럭시아에스엠')
# (1948, '004270', '남성')
# (1949, '001940', 'KISCO홀딩스')
# (1950, '009410', '태영건설')
# (1951, '007280', '한국특수형강')
# (1952, '009180', '한솔로지스틱스')
# (1953, '002170', '삼양통상')
# (1954, '017670', 'SK텔레콤')
# (1955, '010640', '진양폴리우레탄')
# (1956, '003650', '미창석유공업')
# (1957, '004380', '삼익THK')
# (1958, '002840', '미원상사')
# (1959, '007860', '서연')
# (1960, '019550', 'SBI인베스트먼트')
# (1961, '013000', '세우글로벌')
# (1962, '012330', '현대모비스')
# (1963, '015540', '메디플란트')
# (1964, '001390', 'KG케미칼')
# (1965, '009320', '대우부품')
# (1966, '001450', '현대해상')
# (1967, '005440', '현대그린푸드')
# (1968, '015760', '한국전력공사')
# (1969, '007690', '국도화학')
# (1970, '006280', '녹십자')
# (1971, '009160', 'SIMPAC')
# (1972, '008600', '윌비스')
# (1973, '015230', '대창단조')
# (1974, '007160', '사조산업')
# (1975, '014130', '한익스프레스')
# (1976, '008040', '사조동아원')
# (1977, '009140', '경인전자')
# (1978, '009580', '무림P&P')
# (1979, '014990', '인디에프')
# (1980, '010420', '한솔피엔에스')
# (1981, '013570', '디와이')
# (1982, '003610', '방림')
# (1983, '015590', '큐로')
# (1984, '014680', '한솔케미칼')
# (1985, '010820', '퍼스텍')
# (1986, '019590', '엠벤처투자')
# (1987, '019570', '제미니투자')
# (1988, '006040', '동원산업')
# (1989, '008060', '대덕전자')
# (1990, '003680', '한성기업')
# (1991, '006920', '모헨즈')
# (1992, '015020', '이스타코')
# (1993, '011280', '태림포장')
# (1994, '002310', '아세아제지')
# (1995, '010660', '화천기계')
# (1996, '011150', 'CJ씨푸드')
# (1997, '001770', '신화실업')
# (1998, '018470', '조일알미늄')
# (1999, '005850', '에스엘')
# (2000, '009970', '영원무역홀딩스')
# (2001, '012510', '더존비즈온')
# (2002, '003850', '보령제약')
# (2003, '007630', '폴루스바이오팜')
# (2004, '008250', '이건산업')
# (2005, '012690', '모나리자')
# (2006, '006370', '대구백화점')
# (2007, '006980', '우성사료')
# (2008, '002920', '유성기업')
# (2009, '002220', '한일철강')
# (2010, '002450', '삼익악기')
# (2011, '002460', '화성산업')
# (2012, '007340', '디티알오토모티브')
# (2013, '001290', '골든브릿지증권')
# (2014, '000890', '보해양조')
# (2015, '003010', '혜인')
# (2016, '014280', '금강공업')
# (2017, '009810', '엔케이물산')
# (2018, '008730', '율촌화학')
# (2019, '009270', '신원')
# (2020, '004140', '동방')
# (2021, '002960', '한국쉘석유')
# (2022, '003000', '부광약품')
# (2023, '005810', '풍산홀딩스')
# (2024, '001270', '부국증권')
# (2025, '012200', '계양전기')
# (2026, '004710', '한솔테크닉스')
# (2027, '005190', '동성화학')
# (2028, '016610', 'DB금융투자')
# (2029, '008930', '한미사이언스')
# (2030, '005500', '삼진제약')
# (2031, '005490', '포스코')
# (2032, '002410', '범양건영')
# (2033, '005690', '파미셀')
# (2034, '001230', '동국제강')
# (2035, '006340', '대원전선')
# (2036, '005950', '이수화학')
# (2037, '016360', '삼성증권')
# (2038, '002810', '삼영무역')
# (2039, '001750', '한양증권')
# (2040, '011780', '금호석유화학')
# (2041, '003470', '유안타증권')
# (2042, '002620', '제일파마홀딩스')
# (2043, '015260', '에이엔피')
# (2044, '009460', '한창제지')
# (2045, '005720', '넥센')
# (2046, '006660', '삼성공조')
# (2047, '004490', '세방전지')
# (2048, '011000', '진원생명과학')
# (2049, '009310', '참엔지니어링')
# (2050, '010100', '한국프랜지공업')
# (2051, '005070', '코스모신소재')
# (2052, '004830', '덕성')
# (2053, '001720', '신영증권')
# (2054, '001200', '유진증권')
# (2055, '003460', '유화증권')
# (2056, '011700', '한신기계공업')
# (2057, '005420', '코스모화학')
# (2058, '000500', '가온전선')
# (2059, '010950', 'S-Oil')
# (2060, '012450', '한화에어로스페이스')
# (2061, '011230', '삼화전자공업')
# (2062, '004020', '현대제철')
# (2063, '004770', '써니전자')
# (2064, '004560', '현대비앤지스틸')
# (2065, '006090', '사조오양')
# (2066, '003530', '한화투자증권')
# (2067, '009470', '삼화전기')
# (2068, '001510', 'SK증권')
# (2069, '010770', '평화홀딩스')
# (2070, '007110', '일신석재')
# (2071, '016380', '동부제철')
# (2072, '010780', '아이에스동서')
# (2073, '002360', 'SH에너지화학')
# (2074, '003830', '대한화섬')
# (2075, '007810', '코리아써키트')
# (2076, '004170', '신세계')
# (2077, '010060', 'OCI')
# (2078, '000520', '삼일제약')
# (2079, '006490', '인스코비')
# (2080, '003120', '일성신약')
# (2081, '000720', '현대건설')
# (2082, '002710', 'TCC동양')
# (2083, '003060', '에이프로젠제약')
# (2084, '007700', 'F&F')
# (2085, '008700', '아남전자')
# (2086, '010620', '현대미포조선')
# (2087, '006360', 'GS건설')
# (2088, '006110', '삼아알미늄')
# (2089, '006200', '한국전자홀딩스')
# (2090, '006400', '삼성SDI')
# (2091, '009150', '삼성전기')
# (2092, '004200', '고려개발')
# (2093, '005960', '동부건설')
# (2094, '009070', '케이씨티시')
# (2095, '003070', '코오롱글로벌')
# (2096, '005180', '빙그레')
# (2097, '005250', '녹십자홀딩스')
# (2098, '005450', '신한')
# (2099, '000480', '조선내화')
# (2100, '004310', '현대약품')
# (2101, '003920', '남양유업')
# (2102, '008350', '남선알미늄')
# (2103, '003350', '한국화장품제조')
# (2104, '001880', '삼호')
# (2105, '011760', '현대종합상사')
# (2106, '006260', 'LS')
# (2107, '001740', 'SK네트웍스')
# (2108, '002100', '경농')
# (2109, '004870', '티웨이홀딩스')
# (2110, '007590', '동방아그로')
# (2111, '004430', '송원산업')
# (2112, '002780', '진흥기업')
# (2113, '004090', '한국석유공업')
# (2114, '000650', '천일고속')
# (2115, '000430', '대원강업')
# (2116, '001080', '만호제강')
# (2117, '004700', '조광피혁')
# (2118, '004360', '세방')
# (2119, '008970', '동양철관')
# (2120, '002880', '대유에이텍')
# (2121, '001260', '남광토건')
# (2122, '005680', '삼영전자공업')
# (2123, '005800', '신영와코루')
# (2124, '002630', '오리엔트바이오')
# (2125, '001550', '조비')
# (2126, '005430', '한국공항')
# (2127, '004910', '조광페인트')
# (2128, '004690', '삼천리')
# (2129, '003080', '성보화학')
# (2130, '002600', '조흥')
# (2131, '001570', '금양')
# (2132, '003960', '사조대림')
# (2133, '002070', '남영비비안')
# (2134, '003570', 'S&T중공업')
# (2135, '004960', '한신공영')
# (2136, '004370', '농심')
# (2137, '003720', '삼영화학공업')
# (2138, '004980', '성신양회')
# (2139, '004970', '신라교역')
# (2140, '002870', '신풍제지')
# (2141, '001630', '종근당홀딩스')
# (2142, '005740', '크라운해태홀딩스')
# (2143, '002390', '한독')
# (2144, '001380', 'SG충방')
# (2145, '006120', 'SK디스커버리')
# (2146, '007540', '샘표')
# (2147, '003280', '흥아해운')
# (2148, '001250', 'GS글로벌')
# (2149, '002990', '금호산업')
# (2150, '001470', '삼부토건')
# (2151, '001820', '삼화콘덴서공업')
# (2152, '001020', '페이퍼코리아')
# (2153, '001520', '동양')
# (2154, '000880', '한화')
# (2155, '001060', 'JW중외제약')
# (2156, '000670', '영풍')
# (2157, '001340', '백광산업')
# (2158, '000180', '성창기업지주')
# (2159, '005110', '한창')
# (2160, '004450', '삼화왕관')
# (2161, '000040', 'KR모터스')
# (2162, '002240', '고려제강')
# (2163, '004100', '태양금속공업')
# (2164, '002820', '선창산업')
# (2165, '004840', 'DRB동일')
# (2166, '002350', '넥센타이어')
# (2167, '004060', 'SG세계물산')
# (2168, '004000', '롯데정밀화학')
# (2169, '000020', '동화약품')
# (2170, '000210', '대림산업')
# (2171, '001120', 'LG상사')
# (2172, '002720', '국제약품')
# (2173, '003240', '태광산업')
# (2174, '005030', '부산주공')
# (2175, '006390', '한일현대시멘트')
# (2176, '000590', 'CS홀딩스')
# (2177, '005390', '신성통상')
# (2178, '000990', 'DB하이텍')
# (2179, '006570', '대림통상')
# (2180, '000220', '유유제약')
# (2181, '000860', '강남제비스코')
# (2182, '003540', '대신증권')
# (2183, '005940', 'NH투자증권')
# (2184, '006800', '미래에셋대우')
# (2185, '002700', '신일산업')
# (2186, '001360', '삼성제약')
# (2187, '000810', '삼성화재해상보험')
# (2188, '003230', '삼양식품')
# (2189, '000370', '한화손해보험')
# (2190, '008260', 'NI스틸')
# (2191, '000230', '일동홀딩스')
# (2192, '000490', '대동공업')
# (2193, '001800', '오리온홀딩스')
# (2194, '004540', '깨끗한나라')
# (2195, '001420', '태원물산')
# (2196, '002020', '코오롱')
# (2197, '005930', '삼성전자')
# (2198, '000300', '대유플러스')
# (2199, '001460', 'BYC')
# (2200, '003620', '쌍용자동차')
# (2201, '003410', '쌍용양회공업')
# (2202, '005610', 'SPC삼립')
# (2203, '000540', '흥국화재')
# (2204, '010050', '우리종금')
# (2205, '007570', '일양약품')
# (2206, '002320', '한진')
# (2207, '002200', '한국수출포장공업')
# (2208, '005380', '현대자동차')
# (2209, '005360', '모나미')
# (2210, '009830', '한화케미칼')
# (2211, '002030', '아세아')
# (2212, '006380', '카프로')
# (2213, '004990', '롯데지주')
# (2214, '001070', '대한방직')
# (2215, '004410', '서울식품공업')
# (2216, '003560', '아이에이치큐')
# (2217, '000680', 'LS네트웍스')
# (2218, '001210', '금호전기')
# (2219, '002250', '알보젠코리아')
# (2220, '000140', '하이트진로홀딩스')
# (2221, '000320', '노루홀딩스')
# (2222, '000270', '기아자동차')
# (2223, '004800', '효성')
# (2224, '001040', 'CJ')
# (2225, '000150', '두산')
# (2226, '005010', '휴스틸')
# (2227, '005830', 'DB손해보험')
# (2228, '003090', '대웅')
# (2229, '002900', '동양물산기업')
# (2230, '003780', '진양산업')
# (2231, '003520', '영진약품')
# (2232, '002380', '케이씨씨')
# (2233, '005300', '롯데칠성음료')
# (2234, '003200', '일신방직')
# (2235, '002270', '롯데푸드')
# (2236, '002790', '아모레퍼시픽그룹')
# (2237, '006220', '제주은행')
# (2238, '004150', '한솔홀딩스')
# (2239, '007210', '벽산')
# (2240, '002300', '한국제지')
# (2241, '000400', '롯데손해보험')
# (2242, '001130', '대한제분')
# (2243, '001680', '대상')
# (2244, '003550', 'LG')
# (2245, '000640', '동아쏘시오홀딩스')
# (2246, '003690', '코리안리')
# (2247, '000970', '한국주철관공업')
# (2248, '003300', '한일홀딩스')
# (2249, '004250', '엔피씨')
# (2250, '003030', '세아제강지주')
# (2251, '001440', '대한전선')
# (2252, '001790', '대한제당')
# (2253, '000070', '삼양홀딩스')
# (2254, '002420', '세기상사')
# (2255, '000240', '한국타이어월드와이드')
# (2256, '000950', '전방')
# (2257, '003490', '대한항공')
# (2258, '001530', '동일방직')
# (2259, '000100', '유한양행')
# (2260, '000120', 'CJ대한통운')
# (2261, '000060', '메리츠화재')
# (2262, '000050', '경방')
# (2263, '000700', '유수홀딩스')
# (2264, '003480', '한진중공업홀딩스')

# %%
conn.close
# Out:
# <function Connection.close>
