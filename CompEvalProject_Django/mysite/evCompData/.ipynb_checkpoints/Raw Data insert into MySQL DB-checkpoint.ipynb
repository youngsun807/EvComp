# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine= create_engine('mysql+pymysql://root:root@192.168.1.3:3315/evComp?charset=utf8mb4')

# %%
train_data = pd.read_csv('D:/encore/finalproject/data/train.csv')

# %%
train_data.to_sql(name = 'train', con = engine , if_exists = 'append', index = False)
# Out:
# C:\Users\jmj80\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
train_data
# Out:
#              key  apartment_id  city  transaction_year_month transaction_date  \
# 0              0          5584     1                  200601            11~20
# 1              1          5584     1                  200601            11~20
# 2              2          5059     1                  200601            11~20
# 3              3          2816     1                  200601            11~20
# 4              4          2816     1                  200601            11~20
# 5              5          2815     1                  200601            11~20
# 6              6          2815     1                  200601            11~20
# 7              7          9867     1                  200601            11~20
# 8              8          2818     1                  200601            11~20
# 9              9          2817     1                  200601            11~20
# 10            10          2819     1                  200601            11~20
# ...
